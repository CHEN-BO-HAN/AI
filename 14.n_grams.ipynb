# %% [markdown]
# # N-Grams
# - 了解單一字詞表示方式，接下來則是語言模型的表示。語言模型是由"字詞/字句"所構成，所以要透過組合單一字詞成為其他有意義的"字詞/字句"
# - 組合的過程稱之為n-grams，單一字詞為1-gram，兩個字詞組成有意義的"字詞/字句"稱之為2-grams，依此類推
# - 本範例利用情緒分析範例，示範如何把評論詞切成n-grams的前處理過程
# - 前處理過程包含：1. 去除標點符號(punctuation) 2. 去除停用詞(stopwords，無意義之詞，例如"的"、"了"...之類)
# - 接下來產生單字詞unigram，雙字詞bigram，三字詞trigram

# %% [markdown]
# **SENTIMENT ANALYSIS FOR FINANCIAL NEWS FROM THE PERSPECTIVE OF A RETIAL INVESTOR**
#
# **->3 categories:**
#
#
# -positive
#
# -negative
#
# -neutral
#
# DATASET:
#
# https://www.kaggle.com/ankurzing/sentiment-analysis-for-financial-news

# %% [markdown]
# **要先上傳3_0(ngram).ipynb檔跟all-data.csv檔**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

plt.style.use(style='seaborn')
# %matplotlib inline

# %%
df=pd.read_csv('all-data.csv',encoding = "ISO-8859-1", header=None, names = ['Sentiment', 'News Headline'])
df.head()
# Out:
#   Sentiment                                      News Headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sentiment      4846 non-null   object
#  1   News Headline  4846 non-null   object
# dtypes: object(2)
# memory usage: 75.8+ KB

# %%
df.isna().sum()
# Out:
# Sentiment        0
# News Headline    0
# dtype: int64

# %%
df['Sentiment'].value_counts()
# Out:
# neutral     2879
# positive    1363
# negative     604
# Name: Sentiment, dtype: int64

# %% [markdown]
# **Feature extraction**

# %%
y=df['Sentiment'].values
y.shape
# Out:
# (4846,)

# %%
x=df['News Headline'].values
x.shape
# Out:
# (4846,)

# %% [markdown]
# **Train-test split**

# %%
from sklearn.model_selection import train_test_split

# %%
(x_train,x_test,y_train,y_test)=train_test_split(x,y,test_size=0.4)

# %%
x_train.shape
# Out:
# (2907,)

# %%
y_train.shape
# Out:
# (2907,)

# %%
x_test.shape
# Out:
# (1939,)

# %%
y_test.shape
# Out:
# (1939,)

# %%
x_train
# Out:
# array(['The contract involves refurbishing the bathrooms of 189 units as well as re-plumbing their water and sewer pipes .',
#        "GeoSentric 's flagship product is the GyPSii platform , which uses pioneering geo-location software technology to connect people to people , and people to places with new and exciting social community and location-specific services .",
#        "Harold W. Young is an independent broker working closely with several retailers including Ahold USA , Market Basket , CVS , BJ 's Wholesale Club , Hannaford and Cumberland Farms .",
#        ..., 'Yvonne Jones is owner of Chameleon Interiors .',
#        'M2 Communications disclaims all liability for information provided within information on on the world wide web .',
#        "Renzo Piano 's building design will be a wonderful addition to London 's skyline , '' says Noud Veeger , EVP and Area Director for Central and North Europe at KONE ."],
#       dtype=object)

# %%
df1=pd.DataFrame(x_train)
df1=df1.rename(columns={0:'news'})

df2=pd.DataFrame(y_train)
df2=df2.rename(columns={0:'sentiment'})
df_train=pd.concat([df1,df2],axis=1)

df_train.head()
# Out:
#                                                 news sentiment
# 0  The contract involves refurbishing the bathroo...   neutral
# 1  GeoSentric 's flagship product is the GyPSii p...   neutral
# 2  Harold W. Young is an independent broker worki...   neutral
# 3  Finnish consumer packaging manufacturer Huhtam...  positive
# 4  As a result of the cancellation , the maximum ...   neutral

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   news       2907 non-null   object
#  1   sentiment  2907 non-null   object
# dtypes: object(2)
# memory usage: 45.5+ KB

# %%
df3=pd.DataFrame(x_test)
df3=df3.rename(columns={0:'news'})

df4=pd.DataFrame(y_test)
df4=df2.rename(columns={0:'sentiment'})
df_test=pd.concat([df3,df4],axis=1)

df_test.head()
# Out:
#                                                 news sentiment
# 0                No pricing details were disclosed .   neutral
# 1  President and CEO Mika Vehvil+Æinen says the p...   neutral
# 2  Apart from Nordea , also Ergo is competing for...   neutral
# 3  The event can also be viewed as a live audio w...  positive
# 4  Operating profit fell to EUR 20.3 mn from EUR ...   neutral

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   news       1939 non-null   object
#  1   sentiment  2907 non-null   object
# dtypes: object(2)
# memory usage: 45.5+ KB

# %% [markdown]
# **Pre-processing**

# %%
#removing punctuations
#library that contains punctuation
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
  if(type(text)==float):
    return text
  ans=""  
  for i in text:     
    if i not in string.punctuation:
      ans+=i    
  return ans

#storing the puntuation free text in a new column called clean_msg
df_train['news']= df_train['news'].apply(lambda x:remove_punctuation(x))
df_test['news']= df_test['news'].apply(lambda x:remove_punctuation(x))

# %%
df_train.head()
#punctuations are removed from news column in train dataset
# Out:
#                                                 news sentiment
# 0  The contract involves refurbishing the bathroo...   neutral
# 1  GeoSentric s flagship product is the GyPSii pl...   neutral
# 2  Harold W Young is an independent broker workin...   neutral
# 3  Finnish consumer packaging manufacturer Huhtam...  positive
# 4  As a result of the cancellation  the maximum i...   neutral

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#method to generate n-grams:
#params:
#text-the text for which we have to generate n-grams
#ngram-number of grams to be generated from the text(1,2,3,4 etc., default value=1)


def generate_N_grams(text,ngram=1):
  words=[word for word in text.split(" ") if word not in set(stopwords.words('english'))]  
  print("Sentence after removing stopwords:",words)
  temp=zip(*[words[i:] for i in range(0,ngram)])
  ans=[' '.join(ngram) for ngram in temp]
  return ans

# %%
#sample!
generate_N_grams("The sun rises in the east",3)
# Out:
# Sentence after removing stopwords: ['The', 'sun', 'rises', 'east']
# ['The sun rises', 'sun rises east']

# %% [markdown]
# **Create unigrams**

# %%
from collections import defaultdict

# %%
positiveValues=defaultdict(int)
negativeValues=defaultdict(int)
neutralValues=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text):
    positiveValues[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text):
    negativeValues[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text):
    neutralValues[word]+=1
# Out:
# Sentence after removing stopwords: ['Finnish', 'consumer', 'packaging', 'manufacturer', 'Huhtamaki', 'Oyj', 'said', 'swung', 'net', 'profit', '841', 'mln', 'euro', '', '1056', 'mln', 'first', 'nine', 'months', '2006', 'net', 'loss', '26', 'mln', 'euro', '', '33', 'mln', 'period', '2005', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'welcome', 'Elisa', 'Board', 'Directors', '', '', 'said', 'Garry', 'McGuire', '', 'CEO', 'RMG', 'Networks', '']
# Sentence after removing stopwords: ['com', '', 'constantly', 'planning', 'new', 'ways', 'serve', 'customers', 'online', 'comprehensive', 'basis', '', '', 'says', 'Matti', 'Leminen', '', 'President', 'Anttila', 'Oy', '']
# Sentence after removing stopwords: ['', 'The', 'stable', 'outlook', 'reflects', 'Nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', '', 'strong', 'cash', 'flow', 'generation', '', 'conservative', 'balance', 'sheet', '', '', 'said', 'Raab', '']
# Sentence after removing stopwords: ['In', 'first', 'quarter', '2010', '', 'marktomarket', 'result', 'pretax', 'profit', 'EUR', '133', 'million', 'versus', 'loss', 'EUR', '32', 'million', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Previously', 'company', 'estimated', 'operating', 'profit', 'reach', 'level', '2005', '']
# Sentence after removing stopwords: ['In', 'autumn', '', 'plans', 'expand', 'service', 'St', 'Petersburg', 'Moscow', 'launch', 'service', 'Yekaterinburg', '', 'Russia', '', 'flying', 'three', 'times', 'week', '']
# Sentence after removing stopwords: ['Upgrades', 'include', 'five', 'megapixel', 'camera', '', 'voice', 'control', '', 'looks', 'optical', 'mouse', 'instead', 'Dpad', '', 'upgrade', 'clickhappy', 'S60', 'needed', 'forever', '']
# Sentence after removing stopwords: ['In', 'fourth', 'quarter', '2009', '', 'Orion', 'net', 'profit', 'went', '338', '', 'yearonyear', 'EUR33m', '']
# Sentence after removing stopwords: ['As', 'result', '', 'distribution', 'companies', 'start', 'distribute', '', 'addition', 'current', 'product', 'offering', '', 'Shimano', 'reels', '', 'rods', 'Shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis', '']
# Sentence after removing stopwords: ['Rory', 'Fitzgerald', '', 'general', 'manager', '', 'operations', '', 'Bristol', 'Port', '', 'said', '', '', 'With', 'use', 'low', 'maintenance', 'technology', 'save', '30', 'per', 'cent', 'servicing', '', 'plus', 'load', 'sensing', 'hydraulics', 'save', 'us', 'extra', '15', '30', 'per', 'cent', 'fuel', 'consumption', '', '']
# Sentence after removing stopwords: ['', 'The', 'announced', 'investment', 'carmaker', 'Hyundai', 'example', 'sounds', 'optimistically', 'us', 'course', 'new', 'cars', 'mean', 'new', 'tires', '', '']
# Sentence after removing stopwords: ['According', 'Finnish', 'Aktia', 'Bank', 'Managing', 'Director', 'Jussi', 'Laitinen', '', 'bank', 'aim', 'triple', 'number', 'customers', 'Finland', 'next', 'five', 'years', '']
# Sentence after removing stopwords: ['Profit', 'taxes', 'period', 'EUR0', '9', '', 'EUR0', '01', 'last', 'year', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['Shares', 'Nokia', 'Corp', 'rose', 'Thursday', 'cell', 'phone', 'maker', 'said', 'thirdquarter', 'earnings', 'almost', 'doubled', 'share', 'global', 'handset', 'market', 'increased', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '06', 'mn', 'EUR', '04', 'mn', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Advertising', 'circulation', 'revenues', 'grew', '34', '', '04', '', '', 'respectively', '']
# Sentence after removing stopwords: ['According', 'CEO', 'Matti', 'Karppinen', '', 'Frozen', 'Foods', 'posted', 'good', 'result', '2010', '', '2009', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['We', 'hope', 'increase', 'traffic', 'volumes', 'opening', 'Freight', 'One', 'Scandinavia', '', '']
# Sentence after removing stopwords: ['Neste', 'Oil', 'Corp', 'signed', 'longterm', 'procurement', 'contracts', 'Honkajoki', 'Oy', 'Findest', 'Protein', 'Oy', '', 'owned', 'Finnish', 'food', 'manufacturers', '', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'Neste', '200000', 'bcd', 'Porvoo', '', 'Finland', '', 'refinery', '']
# Sentence after removing stopwords: ['2010', '16', 'July', '2010', '', 'Finnish', 'steel', 'maker', 'Rautaruukki', 'Oyj', 'HEL', '', 'RTRKS', '', 'Ruukki', '', 'said', 'today', 'turned', 'net', 'profit', 'EUR20m', 'second', 'quarter', '2010', 'net', 'loss', 'EUR94m', 'corresponding', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '04', 'mn', '', 'operating', 'loss', 'EUR', '08', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', '27', '', 'EUR', '5798', 'mn', 'EUR', '4572', 'mn', '2006', '']
# Sentence after removing stopwords: ['', 'This', 'contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', '', 'oil', 'shale', 'processing', '']
# Sentence after removing stopwords: ['Nevertheless', '', 'Fitch', 'notes', 'business', 'fundamentals', 'three', 'banks', 'currently', 'remain', 'sound', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'Paper', 'awarded', 'contract', 'rebuild', 'Sabah', 'Forest', 'Industries', '', '', 'SFI', '', 'pulp', 'mill', 'Sabah', '', 'Malaysia', '']
# Sentence after removing stopwords: ['Finnish', 'Aldata', 'Solution', 'signed', 'contract', 'supply', 'GOLD', 'system', 'two', 'French', 'retail', 'chains', '']
# Sentence after removing stopwords: ['HELSINKI', 'Thomson', 'Financial', 'Kemira', 'GrowHow', 'swung', 'profit', 'first', 'quarter', 'earnings', 'improved', 'sales', '', 'especially', 'fertilizer', 'business', 'Europe', '', 'normally', 'stronger', 'first', 'quarter', '']
# Sentence after removing stopwords: ['Finnish', 'KCI', 'Konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'Indian', 'steel', 'producer', 'Bhushan', 'Steel', '', 'Strips', 'delivered', '2007', '']
# Sentence after removing stopwords: ['The', 'talks', 'aimed', 'restructuring', 'operations', 'cutting', 'costs', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['Uponor', 'improved', 'performance', 'spite', 'decrease', 'residential', 'construction', 'US', '']
# Sentence after removing stopwords: ['Both', 'operating', 'profit', 'net', 'sales', 'sixmonth', 'period', 'increased', '', 'respectively', 'EUR7', '5', 'EUR655', '5', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', '', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'Klabin', 'Tel\x97maco', 'Borba', 'mill', 'Brazilian', 'state', 'Paranè', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'world', 'biggest', 'magazine', 'paper', 'maker', 'said', 'program', 'improve', 'efficiency', 'include', 'closing', 'several', 'least', 'competitive', 'mills', 'would', 'cover', 'company', 'operations', 'resulting', 'annual', 'savings', 'euro200', 'million', 'US', '240', 'million', '']
# Sentence after removing stopwords: ['Suominen', 'Corporation', 'estimates', 'costcutting', 'program', 'started', 'autumn', '2005', '', 'higher', 'sales', 'prices', '', 'expected', 'growth', 'volume', 'Wet', 'Wipes', '', 'make', 'company', 'operations', 'profitable', '']
# Sentence after removing stopwords: ['Net', 'sales', 'rose', '255', '', 'yearonyear', 'EUR59', '6', '', 'number', 'chargers', 'delivered', 'went', '41', '', '659', 'million', 'pieces', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Eesti', '', 'retailer', 'wholesaler', 'grain', '', 'agricultural', 'warehousing', 'machinery', 'accessories', '', 'net', 'sales', '81', 'million', 'euros', '2007', '', 'increase', 'onetenth', 'preceding', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'handling', 'systems', 'company', 'Cargotec', 'Oyj', '', 'HEL', '', 'CGCBV', '', 'said', 'today', 'EUR', '13', 'million', '', 'USD', '166', '', 'contract', 'deliver', 'MacGregor', 'hatch', 'covers', 'ships', 'ordered', 'Norwegian', 'shipowner', 'Grieg', 'Shipping', '']
# Sentence after removing stopwords: ['', 'Our', 'extensive', 'cooperation', 'also', 'bolster', 'SysOpen', 'Digia', 'position', 'domestic', 'operator', 'market', '', '', 'Kallioranta', 'adds', '']
# Sentence after removing stopwords: ['', 'Our', 'strategic', 'cooperation', 'Rentakran', 'brings', 'us', 'new', 'customers', 'alreadyworking', 'relationships', 'authorities', 'new', 'territories', '', '', 'said', 'Jarmo', 'Laasanen', '', 'senior', 'manager', 'Cramo', '']
# Sentence after removing stopwords: ['A', 'portion', '', '', '125', 'million', '', 'recorded', 'part', 'winnings', 'prior', 'patent', 'dispute', 'Finnish', 'phone', 'maker', 'Nokia', 'Oyj', '']
# Sentence after removing stopwords: ['Q1', '10', '19', 'April', '2010', '', 'Finnish', 'forest', 'machinery', 'equipment', 'maker', 'Ponsse', 'Oyj', 'HEL', '', 'PON1V', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'EUR6', '3', 'first', 'quarter', '2010', '', 'EUR9', '6', 'loss', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Finlandbased', 'Elcoteq', 'SE', '', 'privately', 'held', 'provider', 'electronics', 'manufacturing', 'services', 'communications', 'companies', '', 'said', 'Thursday', 'signed', 'longterm', 'manufacturing', 'supply', 'deal', 'communications', 'equipment', 'company', 'Andrew', 'Corp', '']
# Sentence after removing stopwords: ['', 'Lidskoe', 'Pivo', 'investment', 'program', 'foresees', 'integrated', 'modernization', 'production', '', 'updating', 'transport', 'logistics', 'infrastructure', 'developing', 'new', 'marketing', 'instruments', '', '', 'Mikshis', 'said', '']
# Sentence after removing stopwords: ['This', 'Done', 'Logistics', '', 'largest', 'order', 'Norway', '', 'diversified', 'group', 'said', '']
# Sentence after removing stopwords: ['Finland', 'Nokian', 'Tyres', 'Kazakhstan', 'Ordabasy', 'Corporation', 'signed', 'agreement', 'build', 'plant', 'Astana', 'produce', 'car', 'tires', '', 'Ordabasy', 'chairman', 'Dinmukhamet', 'Idrisov', 'said', 'press', 'conference', '']
# Sentence after removing stopwords: ['At', 'seminar', '', 'memorandum', 'understanding', 'cooperation', 'signed', 'Finnish', 'Kemira', 'Company', 'Vietnam', 'National', 'Chemical', 'Corporation', '']
# Sentence after removing stopwords: ['', 'The', 'priority', '2009', 'strengthen', 'company', 'balance', 'sheet', 'increase', 'cash', 'flow', '', '', 'CEO', 'Hannu', 'Krook', 'said', '']
# Sentence after removing stopwords: ['The', 'economic', 'occupancy', 'rate', 'Sponda', 'property', 'portfolio', 'rose', '912', '', '888', '', '2006', '']
# Sentence after removing stopwords: ['The', 'Ministry', 'Water', 'Tanzania', 'awarded', 'Poyry', 'water', 'sanitation', 'engineering', 'assignment', 'rehabilitation', 'extension', 'water', 'supply', 'sanitation', 'infrastructure', 'Bukoba', 'Musoma', '', 'situated', 'Lake', 'Victoria', 'northern', 'Tanzania', '']
# Sentence after removing stopwords: ['Nokia', 'bought', 'Chicagobased', 'Navteq', '2008', '', 'acquiring', 'maps', 'database', 'compete', 'Google', 'maps', 'well', 'navigation', 'device', 'companies', 'TomTom', 'NV', 'Garmin', 'Ltd', '']
# Sentence after removing stopwords: ['Uponor', 'made', 'operating', 'profit', 'EUR', '1510', 'mn', '', 'EUR', '1437', 'mn', '', 'made', '2007', 'record', 'year', '']
# Sentence after removing stopwords: ['It', 'also', 'strengthen', 'Ruukki', 'offshore', 'business', '']
# Sentence after removing stopwords: ['There', 'recovery', 'base', 'metals', 'prices', 'increased', 'demand', 'metals', 'China', '', 'however', '']
# Sentence after removing stopwords: ['Finnish', 'GeoSentric', '', 'developer', 'provider', 'solutions', '', 'products', '', 'technologies', 'location', 'based', 'services', '', 'preliminary', 'agreed', 'EUR', '6mn', 'shortterm', 'funding', 'leading', 'investor', '']
# Sentence after removing stopwords: ['', 'UPM', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', '', 'efficiency', 'operations', 'improved', '', '', 'Chief', 'Executive', 'Jussi', 'Pesonen', 'said', '']
# Sentence after removing stopwords: ['In', 'end', '2006', '', 'number', 'outlets', 'rise', '6070', '']
# Sentence after removing stopwords: ['Kesko', 'car', 'import', 'retailing', 'business', '', 'VVAuto', '', 'saw', 'sales', 'grow', '171', 'pct', '']
# Sentence after removing stopwords: ['I', 'looking', 'forward', 'contribute', 'SRV', 'success', 'competence', '', '', 'says', 'Taneli', 'Hassinen', '']
# Sentence after removing stopwords: ['It', 'combines', 'perfect', 'price', 'performance', 'sophisticated', 'management', 'facilities', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'company', 'net', 'profit', 'rose', '114', '', 'year', '822', 'million', 'euros', '2005', 'sales', '6865', 'million', 'euros', '', '138', '', 'year', '', 'company', 'said', 'earlier', '']
# Sentence after removing stopwords: ['We', 'also', 'strengthen', 'existing', 'partnership', 'Cybercom', '', '', 'says', 'Teleste', 'CTO', 'Esko', 'Myllyla', '']
# Sentence after removing stopwords: ['Nordea', 'sees', 'return', 'positive', 'growth', 'Baltic', 'countries', '2011', '']
# Sentence after removing stopwords: ['These', 'moderate', 'significant', 'changes', 'resulted', 'significant', '2432', '', 'reduction', 'estimated', 'CVD', 'risk', '']
# Sentence after removing stopwords: ['In', 'Sweden', '', 'operating', 'profit', 'period', 'review', 'totaled', 'EUR', '34', 'mn', '', '308', '', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['First', 'quarter', 'underlying', 'operating', 'profit', 'rose', '41', 'mln', 'eur', '33', 'mln', 'year', 'earlier', '']
# Sentence after removing stopwords: ['MANAVIGATORSeptember', '7', '', '2010Kemira', 'unveils', 'Indian', 'JV', 'IVRCL', 'Finnish', 'chemicals', 'group', 'Kemira', '', 'HEL', '', 'KRA1V', '', 'Tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'India', 'local', 'construction', 'firm', 'IVRCL', 'Infrastructure', 'Projects', 'Ltd', '', 'BOM', '530773', '', '']
# Sentence after removing stopwords: ['Alma', 'Media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously', '']
# Sentence after removing stopwords: ['Adanac', 'Molybdenum', 'Canada', 'ordered', 'grinding', 'technology', 'molybdenum', 'project', 'British', 'Columbia', '', 'Canada', '', 'Shalkiya', 'Zinc', 'Kazakhstan', 'awarded', 'contract', 'grinding', 'technology', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'EUR', '06', 'mn', '', 'loss', 'EUR', '19mn', 'year', 'earlier', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'property', 'portfolio', 'doubled', 'result', 'Kapiteeli', 'acquisition', 'totalled', 'EUR', '26862', '12597', 'million', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '135', 'mn', 'EUR', '97', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['The', 'soapstone', 'deposits', 'Medvezhyegorsk', 'area', 'expected', 'increase', 'Tulikivi', 'current', 'reserves', 'considerably', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['The', 'company', 'estimates', 'net', 'sales', '2010', 'increase', 'considerably', '2009', 'operating', 'result', 'clearly', 'positive', '']
# Sentence after removing stopwords: ['', 'I', 'pleased', 'proud', 'performance', 'last', 'year', '', '', 'Chief', 'Executive', 'Juha', 'Rantanen', 'said', 'statement', '']
# Sentence after removing stopwords: ['This', 'acquisition', 'supports', 'strategy', 'close', 'customers', 'around', 'world', 'offering', 'equipment', 'related', 'services', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Oct', '31', '', '2008', '', 'Finnish', 'food', 'company', 'Raisio', 'Oyj', '', 'OMX', '', 'RAIVV', '', 'said', 'today', 'net', 'profit', 'jumped', 'EUR', '164', 'million', '', 'USD', '209', '', 'first', 'nine', 'months', '2008', 'EUR', '11', 'million', 'period', '2']
# Sentence after removing stopwords: ['This', 'second', 'successful', 'effort', 'financial', 'investor', 'year', '']
# Sentence after removing stopwords: ['', 'We', 'feeling', 'quite', 'positive', 'region', 'whole', '']
# Sentence after removing stopwords: ['Its', 'main', 'business', 'area', '', 'Glass', 'Machinery', 'Group', 'Glaston', 'Technologies', '', 'global', 'market', 'leader', 'glass', 'processing', 'machines', '']
# Sentence after removing stopwords: ['TeliaSonera', 'said', '', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', '', 'Nepal', 'population', '']
# Sentence after removing stopwords: ['India', 'trade', 'Russia', 'currently', 'stands', 'four', 'billion', 'dollars', '', 'growing', '96', 'per', 'cent', 'fiscal', '2007', '']
# Sentence after removing stopwords: ['This', 'bring', 'cost', 'savings', 'EUR', '3mn', 'year', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Nokian', 'Tyres', 'reported', 'fourth', 'quarter', 'pretax', 'profit', '615', 'mln', 'eur', '', '486', 'mln', 'back', 'strong', 'sales', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', 'EUR', '203', 'mn', 'EUR', '114', 'mn', '']
# Sentence after removing stopwords: ['', 'Beyond', 'improved', 'voice', 'capabilities', '', 'customers', 'streamlined', 'way', 'comply', 'recalls', 'traceability', 'requirements', '', 'providing', 'competitive', 'advantage', '']
# Sentence after removing stopwords: ['Actions', 'improve', 'operational', 'efficiency', 'adjust', 'operations', 'expected', 'deliver', 'annualised', 'permanent', 'cost', 'savings', 'around', 'EUR', '45', 'million', 'effected', 'mostly', 'first', 'half', '2010', '']
# Sentence after removing stopwords: ['EPS', 'grew', '004', 'eur', '002', 'eur', '']
# Sentence after removing stopwords: ['The', 'EBITDA', 'EUR116m', 'compared', 'EUR115m', '', 'corresponding', 'EBITDA', 'margin', '33', '', '']
# Sentence after removing stopwords: ['Incap', 'Lankapaja', 'aim', 'enter', 'actual', 'agreement', 'transfer', 'sheetmetal', 'production', 'buyer', 'February', 'order', 'complete', 'transfer', '1', 'March', '2011', '']
# Sentence after removing stopwords: ['Revenue', 'grew', '2', 'percent', '', 'x20ac', '580', 'million', '', '743', 'million', '', '', 'x20ac', '569', 'million', '']
# Sentence after removing stopwords: ['The', 'company', 'feels', 'leases', 'prime', 'locations', 'due', 'several', 'producing', 'formations', 'immediate', 'area', '']
# Sentence after removing stopwords: ['Finnish', 'investment', 'group', 'Panostaja', 'Oyj', 'said', 'net', 'profit', 'went', '86', 'mln', 'euro', '', '114', 'mln', 'fiscal', '200506', '', 'ended', 'October', '31', '', '2006', '', '28', 'mln', 'euro', '', '37', 'mln', 'period', 'fiscal', '200405', '']
# Sentence after removing stopwords: ['Exports', 'accounted', '654', '', 'net', 'sales', '', 'representing', 'time', 'record', 'company', '']
# Sentence after removing stopwords: ['', 'Our', 'customer', 'satisfied', 'Basware', 'Invoice', 'Automation', 'solution', 'extends', 'implementation', 'new', 'geographies', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['Demand', 'seems', 'hit', 'bottom', '', 'signs', 'improvement', 'seen', '']
# Sentence after removing stopwords: ['Finnish', 'Ahlstrom', 'Corporation', 'ordered', 'key', 'production', 'equipment', 'new', 'glass', 'nonwovens', 'production', 'line', 'Russian', 'Tver', 'Mill', 'Finnish', 'Vaahto', 'Pulp', '', 'Paper', 'Machinery', '', 'part', 'Vaahto', 'Group', '', '']
# Sentence after removing stopwords: ['The', 'company', 'expects', 'net', 'sales', '2008', 'increase', '510', '', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'Bank', 'land', 'reports', 'operating', 'profit', 'rose', 'EUR', '213', 'mn', 'second', 'quarter', '2009', 'EUR', '61', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['Sanoma', 'Magazines', 'Finland', 'net', 'sales', 'grew', 'EUR', '1401', 'mn', 'EUR', '1318', 'mn', '']
# Sentence after removing stopwords: ['Comparable', 'net', 'sales', 'expected', 'increase', '10', '', '2008', '', 'line', 'group', 'target', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'components', 'supplier', 'Componenta', 'Oyj', 'said', 'net', 'profit', 'went', '35', 'mln', 'euro', '', '45', 'mln', '2006', '22', 'mln', 'euro', '', '28', 'mln', '2005', '']
# Sentence after removing stopwords: ['It', 'also', 'said', 'third', 'quarter', 'diluted', 'EPS', 'came', '034', 'eur', 'compared', '016', 'eur', 'quarter', 'year', 'ago', '']
# Sentence after removing stopwords: ['Its', 'market', 'share', 'widened', '4851', 'percent', '4831', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Satama', 'net', 'sales', 'would', 'higher', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'financial', 'group', 'Aktia', 'reports', 'operating', 'profit', 'EUR', '444', 'mn', 'JanuarySeptember', '2009', '', 'EUR', '373', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['Cargo', 'volume', 'grew', '7', '', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'expected', 'improve', 'access', 'chrome', 'ore', 'resources', 'Turkey', '']
# Sentence after removing stopwords: ['Kaido', 'Kaare', '', 'general', 'director', 'Atria', 'Eesti', '', 'says', 'company', 'investments', 'upgrade', 'pig', 'farms', 'surpass', 'EEK', '150mn', 'EUR', '959', 'mn', 'USD', '1419', 'mn', 'past', 'years', '']
# Sentence after removing stopwords: ['Lithuanian', 'beer', 'makers', 'sold', '25688', 'million', 'liters', 'beer', '2005', '', 'rise', '45', 'per', 'cent', 'yearearlier', 'figure', '24592', 'million', 'liters', '']
# Sentence after removing stopwords: ['The', 'company', 'order', 'book', 'stood', '15', 'bln', 'euro', '', '22', 'bln', 'September', '30', '', '2007', '', '242', 'pct', 'year', '', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '', '5343', 'mln', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totaled', 'EUR', '55', 'mn', '', 'EUR', '07', 'mn', '']
# Sentence after removing stopwords: ['The', 'services', 'also', 'give', 'supplier', 'opportunity', 'keyin', 'invoices', '', 'receive', 'orders', 'electronically', '', 'send', 'order', 'confirmations', 'upload', 'create', 'electronic', 'catalogues', '']
# Sentence after removing stopwords: ['The', 'energyefficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'stateoftheart', 'technology', '']
# Sentence after removing stopwords: ['', 'Following', 'last', 'year', 'good', 'profit', 'development', '', 'entered', 'current', 'year', 'good', 'position', '']
# Sentence after removing stopwords: ['According', 'report', 'Neomarkka', '', 'Kuitu', 'Finland', 'customers', 'interested', 'buying', 'company', 'products', 'restarts', 'production', '']
# Sentence after removing stopwords: ['', 'The', 'margarine', 'business', 'put', 'good', 'shape', 'last', 'two', 'years', '', 'making', 'natural', 'addition', 'Bunge', '', 'looking', 'leverage', 'position', 'Central', 'Northern', 'European', 'markets', '', '', 'Raisio', 'CEO', 'Matti', 'Rihko', 'said', 'statement', '']
# Sentence after removing stopwords: ['The', 'Brazilian', 'unit', 'Finnish', 'security', 'solutions', 'provider', 'FSecure', 'signed', '1500', 'new', 'clients', 'last', 'year', '', 'online', 'news', 'source', 'Reseller', 'Web', 'quoted', 'division', 'commercial', 'director', '', 'Vladimir', 'Brando', '', 'saying', '']
# Sentence after removing stopwords: ['Unit', 'costs', 'flight', 'operations', 'fell', '64', 'percent', '']
# Sentence after removing stopwords: ['The', 'respondents', 'praised', 'Finnair', 'reliability', '', 'Finnishness', '', 'understanding', 'target', 'group', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['It', 'leading', 'private', 'road', 'ambulance', 'service', 'company', 'Finland', '']
# Sentence after removing stopwords: ['In', 'second', 'quarter', '2010', '', 'Raute', 'net', 'loss', 'narrowed', 'EUR', '123000', 'EUR', '15', 'million', 'period', '2009', '']
# Sentence after removing stopwords: ['3', 'January', '2011', '', 'Finnish', 'flag', 'carrier', 'Finnair', 'Oyj', '', 'HEL', '', 'FIA1S', '', 'said', 'today', 'sealed', 'nineyear', 'sale', 'leaseback', 'agreement', 'newest', 'Airbus', 'A330', 'aircraft', 'syndication', 'Japanese', 'operating', 'lease', 'market', '']
# Sentence after removing stopwords: ['The', 'production', 'capacity', 'tripled', 'without', 'major', 'additional', 'investments', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Israeli', 'cable', 'network', 'operator', 'HOT', 'Telecom', 'chosen', 'Teleste', '', 'international', 'technology', 'group', '', 'exclusive', 'provider', 'FTTx', 'equipment', 'Israel', '', 'according', 'Teleste', 'today', '']
# Sentence after removing stopwords: ['The', 'company', 'aims', 'maintain', 'trend', 'profitability', 'current', 'year', '']
# Sentence after removing stopwords: ['The', 'terms', 'financing', 'approved', 'Annual', 'General', 'Meeting', 'Company', 'held', 'June', '30', '', '2010', '']
# Sentence after removing stopwords: ['The', 'refining', 'margin', 'year', '', '1339', '', 'bbl', '', 'compared', '', '1046', '', 'bbl', 'prior', 'year', '']
# Sentence after removing stopwords: ['Altimo', 'TeliaSonera', 'said', 'yesterday', 'Usmanov', 'would', 'welcome', 'join', 'new', 'company', '']
# Sentence after removing stopwords: ['With', 'appointment', 'Kaupthing', 'Bank', 'aims', 'coordinate', 'Capital', 'Markets', 'activities', 'within', 'Group', 'improve', 'overall', 'service', 'clients', '']
# Sentence after removing stopwords: ['EBIT', 'excluding', 'nonrecurring', 'items', 'estimated', 'increase', '2009', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'supply', 'WCDMA', '3GHSPA', 'radio', 'network', '', 'including', 'modular', '', 'high', 'capacity', 'Nokia', 'Flexi', 'WCDMA', 'base', 'station', 'East', 'Java', '', 'Bali', '', 'Sumatra', 'Batam', '']
# Sentence after removing stopwords: ['Brazilian', 'mobile', 'player', 'Telemig', 'Celular', 'yesterday', 'announced', 'selected', 'Finnish', 'software', 'developer', 'Tecnomen', 'Oyj', 'expand', 'prepaid', 'billing', 'system', '']
# Sentence after removing stopwords: ['Finnish', 'forest', 'machinery', 'manufacturer', 'Ponsse', 'agreed', 'Volvo', 'start', 'cooperation', 'Latin', 'America', '']
# Sentence after removing stopwords: ['The', 'divestment', 'Raisio', 'margarine', 'business', 'May', '2009', 'gave', 'company', 'clearer', 'focus', 'grainbased', 'products', '']
# Sentence after removing stopwords: ['TeliaSonera', 'secured', 'deliveries', '4G', 'modems', 'support', '3G', '2G', 'second', 'quarter', '2010', '']
# Sentence after removing stopwords: ['Mobile', 'phone', 'shipments', 'jumped', '26', 'percent', 'almost', '112', 'million', 'units', '', 'Finnish', 'company', 'global', 'market', 'share', 'rose', '39', 'percent', '36', 'percent', '']
# Sentence after removing stopwords: ['Finnish', 'elevators', 'escalators', 'maker', 'KONE', 'Corporation', 'said', 'Tuesday', '', '18', 'March', '', 'received', 'major', 'order', 'Sir', 'Robert', 'McAlpine', 'supply', 'elevators', 'escalators', 'Watermark', 'Place', 'project', 'City', 'London', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '830', 'mn', '', 'EUR', '235', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['At', 'first', 'contract', 'envisaged', 'construction', 'three', 'ferryboats', 'option', 'two', 'units', '', 'confirmed', 'total', 'value', '500', 'mln', 'euro', '', '', '6458', 'mln', '', '']
# Sentence after removing stopwords: ['', 'The', 'Government', 'professional', 'approach', 'assessing', 'offer', '']
# Sentence after removing stopwords: ['Kone', 'net', 'sales', 'rose', '14', '', 'yearonyear', 'first', 'nine', 'months', '2008', '']
# Sentence after removing stopwords: ['Nyrstar', 'also', 'agreed', 'supply', 'Talvivaara', '150000', 'tonnes', 'sulphuric', 'acid', 'per', 'annum', 'use', 'Talvivaara', 'leaching', 'process', 'period', 'supply', 'zinc', 'concentrate', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'move', '', 'says', 'Morna', 'Cowie', '', 'coowner', '', '', '', 'double', 'size', 'current', 'shop', 'lovely', 'feel', '', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', 'net', 'profit', 'rose', '261', 'mln', 'euro', '', '', '359', 'mln', '', 'first', 'quarter', '2007', '53', 'mln', 'euro', '', '', '73', 'mln', '', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['Sales', 'rose', '10', 'pct', '566', 'mln', 'eur', 'back', 'strong', 'volume', 'favourable', 'currency', 'effects', '']
# Sentence after removing stopwords: ['', 'We', 'lowest', 'bidders', 'final', 'approval', 'awaited', '', '']
# Sentence after removing stopwords: ['The', 'transactions', 'would', 'increase', 'earnings', 'per', 'share', 'first', 'quarter', 'EUR0', '28', '']
# Sentence after removing stopwords: ['Xerox', 'Stora', 'Enso', 'teamed', 'tailor', 'iGen3', 'shortrun', '', 'ondemand', 'packaging', 'market', '']
# Sentence after removing stopwords: ['He', 'believes', 'soyoats', 'good', 'chance', 'entering', 'UK', 'market', '']
# Sentence after removing stopwords: ['The', 'parties', 'agreed', 'negotiate', 'definitive', 'distribution', 'license', 'agreements', 'end', 'June', '2010', '']
# Sentence after removing stopwords: ['We', 'pleased', 'fine', 'cooperation', 'two', 'countries', 'recent', 'times', '', 'said', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'saw', 'net', 'profit', 'jump', 'EUR2', '1', 'last', 'quarter', '2010', 'EUR995', '000', 'period', '2009', '']
# Sentence after removing stopwords: ['New', 'product', 'launches', 'Finland', 'double', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'Kalmar', 'received', 'significant', 'order', 'US', 'Department', 'Defense', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '278', 'mn', 'EUR', '175', 'mn', '2008', '']
# Sentence after removing stopwords: ['Airvana', 'UMTS', 'Home', 'Base', 'Station', 'femto', 'cell', 'uses', 'softwarebased', 'functionality', 'offtheshelf', 'silicon', 'accelerate', 'feature', 'development', 'reduce', 'product', 'cost', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '368', 'EUR', '050', '']
# Sentence after removing stopwords: ['Sales', 'security', 'system', 'packaging', 'increased', 'slightly', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'Asian', 'plants', 'grew', 'markedly', '']
# Sentence after removing stopwords: ['The', 'bank', 'sees', 'potential', 'Getinge', 'share', 'rise', '']
# Sentence after removing stopwords: ['Net', 'sales', 'went', '1', '', 'yearonyear', 'EUR', '29', 'million', '', 'affected', 'business', 'acquisitions', '', 'realized', 'previous', 'financial', 'period', '', 'effect', 'EUR', '51', 'million', 'review', 'period', '']
# Sentence after removing stopwords: ['21', 'October', '2010', '', 'Finnish', 'fishing', 'tackle', 'company', 'Rapala', 'VMC', 'Corp', '', 'HEL', '', 'RAP1V', '', 'said', 'today', 'net', 'profit', 'rose', 'EUR18', '9', 'first', 'nine', 'months', '2010', 'EUR15', '1', 'period', 'year', 'earlier', '']
# Sentence after removing stopwords: ['OUTOTEC', 'OYJ', 'PRESS', 'RELEASE', 'DECEMBER', '4', '', '2009', '1030', 'AM', 'Outotec', 'establishes', 'new', 'subsidiary', 'Kolkata', 'Outotec', 'established', 'subsidiary', 'India', 'order', 'better', 'serve', 'Indian', 'customers', 'increase', 'business', 'growing', 'Indian', 'market', '']
# Sentence after removing stopwords: ['In', 'AsiaPacific', 'region', '', 'Visa', 'Wave', 'available', 'Malaysia', '', 'Taiwan', 'South', 'Korea', 'expanded', 'Japan', 'Southeast', 'Asia', 'year', '', 'Jung', 'added', '']
# Sentence after removing stopwords: ['The', 'cooperation', 'double', 'The', 'Switch', 'converter', 'capacity', '']
# Sentence after removing stopwords: ['Luxembourgregistered', 'investment', 'fund', 'Amber', 'Trust', 'II', 'final', 'approval', 'Lithuania', 'Competition', 'Council', 'acquire', '296', 'percent', 'Sanitas', '', 'country', 'largest', 'pharmaceutical', 'producer', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'EUR', '114', 'mn', '', 'EUR', '75', 'mn', '']
# Sentence after removing stopwords: ['1', 'November', '2010', '', 'Finnish', 'textile', 'clothing', 'company', 'Marimekko', 'Oyj', '', 'HEL', '', 'MMO1V', '', 'announced', 'Friday', 'opening', 'first', 'concept', 'store', 'Seoul', 'cooperation', 'Japanese', 'sector', 'player', 'Look', 'Inc', '', 'TYO', '', '8029', '', '']
# Sentence after removing stopwords: ['All', 'Raisio', 'divisions', 'recorded', 'operating', 'profit', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'threemonth', 'period', 'increased', 'EUR1', '2', '', 'revenue', 'increased', 'EUR20', '2', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['The', 'solutions', 'used', 'upgrading', 'networks', 'Russian', 'MSO', '37', 'different', 'cities', 'Russia', '']
# Sentence after removing stopwords: ['In', 'JulySeptember', '2008', '', 'YIT', 'net', 'sales', 'increased', 'EUR', '9708', 'mn', '', 'compared', 'EUR', '9068', 'mn', 'corresponding', 'period', '2007', '']
# Sentence after removing stopwords: ['', 'The', 'acquisition', 'Sampo', 'Bank', 'makes', 'strategic', 'sense', 'DB', '', '', 'says', 'Lindsey', 'Liddell', '', 'director', 'Fitch', 'Ratings', 'Financial', 'Institutions', 'Group', '']
# Sentence after removing stopwords: ['In', '2007', '', 'Marimekko', 'also', 'opened', 'concept', 'stores', 'Yokohama', 'Nagoya', '', 'central', 'Japan', '', 'Silver', 'Spring', 'metropolitan', 'Washington', 'DC', '', 'USA', '', 'Graz', '', 'central', 'Austria', '', 'Aalborg', '', 'northern', 'Denmark', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'investment', 'properties', 'totalled', 'EUR', '22999', 'mn', '', 'compared', 'EUR', '22295', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['The', 'agreement', 'strengthens', 'longterm', 'partnership', 'Nokia', 'Siemens', 'Networks', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '5mn', 'EUR', '28', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'stock', 'new', 'machines', 'reasonably', 'small', 'new', 'orders', 'bring', 'work', '']
# Sentence after removing stopwords: ['The', 'third', 'order', 'awarded', 'Outokumpu', 'Technology', 'Shalkiya', 'Zinc', 'Kazakhstan', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['LONDON', 'MarketWatch', '', 'Nokia', 'nok', 'said', 'fiveyear', 'services', 'contract', 'run', 'Hutchison', 'Essar', 'network', 'operations', 'nine', 'locations', 'India', '']
# Sentence after removing stopwords: ['Outotec', 'net', 'profit', 'second', 'quarter', '2007', 'jumped', '168', 'mln', 'euro', '', '', '231', 'mln', '', '46', 'mln', 'euro', '', '', '63', 'mln', '', 'year', 'ago', '']
# Sentence after removing stopwords: ['Industry', 'Investment', 'interested', 'Glaston', 'solar', 'energy', 'projects', '']
# Sentence after removing stopwords: ['planning', 'expand', 'product', 'portfolio', 'harbor', 'segment', '', 'chief', 'executive', 'Pekka', 'Lundmark', 'told', 'Financial', 'Times', 'Deutschland', '']
# Sentence after removing stopwords: ['The', 'Lithuanian', 'beer', 'market', 'made', '1441', 'million', 'liters', 'January', '', 'rise', '08', 'percent', 'yearearlier', 'figure', '', 'Lithuanian', 'Brewers', '', 'Association', 'reporting', 'citing', 'results', 'members', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'company', 'operating', 'profit', 'grew', '432', '', 'EUR', '6', 'million', '']
# Sentence after removing stopwords: ['According', 'company', '', 'operating', 'profit', '', 'excluding', 'nonrecurring', 'items', '', 'fourth', 'quarter', '2009', 'significantly', 'better', 'expected', '', 'also', 'better', 'figures', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'company', 'established', '3G', 'base', 'station', '17000', 'feet', 'foot', 'Mount', 'Everest', 'enable', 'mountain', 'climbers', '29035foot', 'summit', 'surf', 'Internet', 'even', 'send', 'videos', 'exploits', '']
# Sentence after removing stopwords: ['For', 'Telenor', '', 'three', 'half', 'year', 'contract', 'worth', 'estimated', '126', 'YIT', 'chosen', 'Telenor', 'Elisa', 'principal', 'suppliers', 'ICT', 'solutions', 'Norway', '', 'Sweden', '', 'Denmark', 'Finland', '']
# Sentence after removing stopwords: ['Cooper', 'SH', '', 'UK', 'distributor', 'lift', 'equipment', 'manufacturer', 'Konecranes', '', 'fiveyear', 'deal', 'involves', 'low', 'maintenance', 'fuel', 'saving', 'technologies', '']
# Sentence after removing stopwords: ['Affecto', 'expects', 'net', 'sales', 'whole', '2010', 'increase', '2009', 'level', 'reached', 'EUR', '103', 'million', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'awarded', 'significant', 'order', 'total', '292', 'Hiab', 'loader', 'cranes', 'BAE', 'Systems', 'US', '']
# Sentence after removing stopwords: ['According', 'ARehu', 'Managing', 'Director', '', 'Jouko', 'Lahtinen', '', 'project', 'stabilise', 'costs', 'improve', 'supply', 'security', '']
# Sentence after removing stopwords: ['Acquisitions', 'made', 'businesses', 'well', 'integrated', '']
# Sentence after removing stopwords: ['', 'Our', 'design', 'team', 'long', 'admired', 'Marimekko', 'vivid', 'patterns', 'colors', '']
# Sentence after removing stopwords: ['In', 'Middle', 'East', '', 'North', 'Africa', '', 'Tecnotree', 'grown', 'considerably', 'recent', 'years', '']
# Sentence after removing stopwords: ['The', 'company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230000', 'tonnes', 'copper', '']
# Sentence after removing stopwords: ['SvyturysUtenos', 'Alus', '', 'controlled', 'Nordic', 'group', 'Baltic', 'Beverages', 'Holding', '', 'BBH', '', '', 'posted', '47percent', 'growth', 'beer', 'sales', 'JanuaryMay', '4622', 'million', 'litres', '']
# Sentence after removing stopwords: ['It', 'also', 'turned', 'earnings', 'per', 'share', '', 'EPS', '', 'EUR', '044', 'versus', 'loss', 'per', 'share', 'EUR', '226', '']
# Sentence after removing stopwords: ['Sony', 'Ericsson', 'Nokia', 'dominated', 'list', 'bestselling', 'handsets', 'five', 'models', '']
# Sentence after removing stopwords: ['However', '', 'net', 'sales', '2010', 'seen', 'grown', 'EUR598', '3', 'EUR582', '3', '2009', '']
# Sentence after removing stopwords: ['Again', '', 'significant', 'sales', 'increase', '186', '', 'Russia', '']
# Sentence after removing stopwords: ['Ixonos', 'estimates', 'hire', '20', 'specialists', 'mechanical', 'engineering', '', 'electronics', 'design', '', 'RD', 'new', 'unit', 'Jyvaeskylae', 'end', '2009', '']
# Sentence after removing stopwords: ['Both', 'operating', 'profit', 'net', 'sales', '12month', 'period', 'increased', '', 'respectively', 'EUR10', '5', 'EUR28', '8', '', 'compared', 'financial', 'year', '2004', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['Metso', 'supply', 'equipment', 'two', 'process', 'lines', 'Northland', 'Resources', '', 'new', 'Kaunisvaara', 'iron', 'ore', 'project', 'Sweden', 'exploits', 'Tapuli', 'Sahavaara', 'iron', 'ore', 'deposits', '']
# Sentence after removing stopwords: ['More', 'staff', 'recruited', 'Japan', 'complement', 'network', 'close', '50', 'service', 'locations', '20', 'countries', 'worldwide', '']
# Sentence after removing stopwords: ['Finnish', 'dental', 'care', 'group', 'Oral', 'Hammaslaakarit', 'Oyj', 'posted', 'total', 'net', 'profit', '849000', 'euro', '', '11', 'mln', 'first', 'nine', 'months', '2006', 'versus', 'net', 'loss', '331000', 'euro', '', '421000', 'period', '2005', '']
# Sentence after removing stopwords: ['In', 'addition', 'deal', 'includes', 'call', 'option', 'enable', 'Maritim', 'Food', 'AS', 'increase', 'holding', 'Sandanger', 'AS', '51', '', 'future', '']
# Sentence after removing stopwords: ['Finnish', 'steel', 'maker', 'Rautaruukki', 'Oyj', '', 'Ruukki', '', 'said', 'July', '7', '', '2008', '90', 'mln', 'euro', '', '', '141', 'mln', '', 'contract', 'supply', 'install', 'steel', 'superstructures', 'Partihallsforbindelsen', 'bridge', 'project', 'Gothenburg', '', 'western', 'Sweden', '']
# Sentence after removing stopwords: ['Sales', 'clothing', 'developed', 'best', '']
# Sentence after removing stopwords: ['Profit', 'period', 'totaled', 'EUR', '394', 'mn', '', 'EUR', '339', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['Other', 'carriers', 'handset', 'makers', 'spin', 'positive', 'event', 'raise', 'interest', 'higherend', 'phones', 'pricier', 'data', 'plans', '']
# Sentence after removing stopwords: ['Shareholders', 'Rakvere', 'Lihakombinaat', 'decided', 'favor', 'buyout', 'minority', 'shares', 'midJuly', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'immediate', 'positive', 'impact', 'Aspocomp', 'financial', 'result', '']
# Sentence after removing stopwords: ['Furthermore', '', 'efficiency', 'improvement', 'measures', 'initiated', 'earlier', 'bearing', 'fruit', '', '', 'CEO', 'Jan', 'Lang', 'said', '']
# Sentence after removing stopwords: ['Having', 'China', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', '', 'also', 'strengthen', 'capability', 'offer', 'industryleading', 'products', 'customers', 'China', '', '']
# Sentence after removing stopwords: ['', 'Demand', 'sports', 'equipment', 'good', '2005', '']
# Sentence after removing stopwords: ['SOUTHFIELD', '', 'Mich', '', 'Central', 'Corporate', 'Credit', 'Union', 'distribute', 'patronage', 'dividends', 'members', 'waiving', 'service', 'fees', 'incurred', 'months', 'July', 'November', '2008', '', 'tune', 'estimated', '', '1', 'million', '']
# Sentence after removing stopwords: ['Revenue', 'July', 'September', 'grew', '14', 'percent', '', 'EURO', '', '467', 'million', 'year', 'earlier', '', 'company', 'said', 'Thursday', '']
# Sentence after removing stopwords: ['Shares', 'Standard', 'Chartered', '', 'STAN', '', 'rose', '12', '', 'FTSE', '100', '', 'Royal', 'Bank', 'Scotland', '', 'RBS', '', 'shares', 'rose', '2', '', 'Barclays', 'shares', '', 'BARC', '', '', 'BCS', '', '17', '', '']
# Sentence after removing stopwords: ['The', 'German', 'company', 'also', 'signed', 'code', 'share', 'agreement', 'another', 'Oneworld', 'member', '', 'American', 'Airlines', 'Inc', '', 'part', 'USbased', 'AMR', 'Corp', '', 'NYSE', '', 'AMR', '', '']
# Sentence after removing stopwords: ['TietoEnator', 'uses', 'Nokia', 'Intellisync', 'Mobile', 'Suite', 'wireless', 'email', '', 'calendar', '', 'device', 'management', 'capabilities', '', 'company', 'extend', 'services', 'customers', '']
# Sentence after removing stopwords: ['Both', 'loans', 'used', 'finance', 'strategic', 'investments', 'shopping', 'center', 'redevelopment', 'projects', 'refinancing', 'maturing', 'debt', '']
# Sentence after removing stopwords: ['The', 'new', 'agreement', '', 'expands', 'longestablished', 'cooperation', 'companies', '', 'involves', 'transfer', 'certain', 'engineering', 'documentation', 'functions', 'Larox', 'Etteplan', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'said', 'Wednesday', 'net', 'profit', 'rocketed', 'EUR4', '8', '2010', 'EUR416', '000', '2009', 'lifted', 'dividend', 'proposal', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Jawad', 'Williams', 'scored', '23', 'points', 'impressive', 'debut', 'Jerusalem', '', 'Jason', 'Rich', 'adding', '18', 'Yuval', 'Naimi', 'chipping', '16', 'points', 'Hapoel', '', 'visits', 'yellowandblue', 'next', 'week', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Finnish', 'handling', 'systems', 'provider', 'Cargotec', 'Oyj', '', 'HEL', '', 'CGCBV', '', 'announced', 'Friday', 'orders', 'worth', 'EUR', '10', 'million', '', 'USD', '132', '', 'deliver', 'linkspans', 'Jordan', '', 'Morocco', 'Ireland', '']
# Sentence after removing stopwords: ['Nokian', 'Capacitors', '', 'equipment', 'used', 'raise', 'capacity', 'reliability', 'Indian', 'grid', '']
# Sentence after removing stopwords: ['Finnish', 'food', 'industry', 'companies', 'HK', 'Ruokatalo', 'Atria', 'form', 'joint', 'venture', 'company', 'called', 'LÆnsiKalkkuna', 'produce', 'turkey', 'meat', '']
# Sentence after removing stopwords: ['Sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season', '']
# Sentence after removing stopwords: ['Speaking', 'justdrinks', 'today', '', 'spokesperson', 'Olvi', 'said', '', '', 'We', 'performed', 'well', 'four', 'countries', 'operate', '', 'namely', '', 'Finland', '', 'Estonia', '', 'Latvia', 'Lithuania', '', '']
# Sentence after removing stopwords: ['TELE2', 'Affarsvarlden', 'gave', '', 'buy', '', 'recommendation', 'mobile', 'operator', 'Tele2', 'AB', 'share', 'price', 'target', '142', 'crowns', '', '', '2354', '', '1519', 'euro', '', '']
# Sentence after removing stopwords: ['Excluding', 'nonrecurring', 'items', '', 'pretax', 'profit', 'surged', '45', '', 'EUR80m', '']
# Sentence after removing stopwords: ['Finnish', 'P¦yry', 'awarded', 'engineering', 'contract', 'CFR', '', 'national', 'railway', 'company', 'Romania', '']
# Sentence after removing stopwords: ['The', 'airline', 'ordered', 'nine', 'Airbus', 'A350900', 'aircraft', 'deliveries', '2011', '', 'becomes', 'lead', 'airline', 'latest', 'variant', 'RollsRoyce', 'Trent', 'series', 'engines', '', 'called', '1700', '']
# ...
# Sentence after removing stopwords: ['', 'A', 'spokesperson', 'told', 'WWD', 'expect', '5050', 'mix', 'clothing', 'home', 'decor', '', '']
# Sentence after removing stopwords: ['Two', 'contracts', 'turntable', 'anode', 'vibrocompactors', 'delivered', 'Gansu', 'Hualu', 'Aluminum', 'Co', 'Ltd', 'another', 'unnamed', 'costumer', '']
# Sentence after removing stopwords: ['The', 'carrier', 'said', 'Area', 'travel', 'agency', 'sell', 'outlets', 'sister', 'chain', 'Suomen', 'Matkatoimisto', 'SMTand', 'use', 'remaining', 'bricksandmortar', 'presence', 'primarily', 'target', 'business', 'customers', 'going', 'forward', '']
# Sentence after removing stopwords: ['The', 'new', 'company', 'likely', 'hold', 'IPO', 'NYSE', 'another', 'international', 'stock', 'exchange', '', 'according', 'Altimo', 'manages', 'Alfa', 'Group', 'telecommunications', 'assets', 'TeliaSonera', 'agreement', '', 'published', 'website', 'US', 'Securities', 'Exchange', 'Commission', '']
# Sentence after removing stopwords: ['The', 'order', 'also', 'includes', 'startup', 'commissioning', 'services', '']
# Sentence after removing stopwords: ['The', 'challenge', 'company', '', 'however', '', 'finding', 'new', 'sources', 'raw', 'material', '', 'said', 'Risto', 'Rinne', '', 'CEO', 'Neste', 'Oil', '']
# Sentence after removing stopwords: ['Protalix', 'developing', 'genetically', 'engineered', 'proteins', 'plant', 'cells', '']
# Sentence after removing stopwords: ['It', 'grew', 'Finland', '', 'Norway', '', 'Denmark', 'Baltic', 'countries', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totaled', 'EUR', '186', 'mn', '83', '', 'net', 'sales', '']
# Sentence after removing stopwords: ['Citigroup', '', 'Inc', 'NYSE', '', 'C', '', 'Deutsche', 'Bank', 'NYSE', '', 'DB', 'Pohjola', 'Bank', 'lead', 'managers', 'sale', '']
# Sentence after removing stopwords: ['Medical', 'Devices', '', 'Russia', 'This', 'brandnew', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'medical', 'device', 'market', 'Russia', '']
# Sentence after removing stopwords: ['Also', '', 'sevenyear', 'historic', 'analysis', 'provided', 'markets', '']
# Sentence after removing stopwords: ['Fiskars', 'R', '', 'founded', '1649', '', 'one', 'oldest', 'companies', 'world', 'largest', 'manufacturer', 'lightweight', 'stainless', 'steel', 'scissors', 'US', '']
# Sentence after removing stopwords: ['In', '2007', '', 'Contempus', 'generated', 'revenue', 'NOK', '693', '', 'approx', '']
# Sentence after removing stopwords: ['According', 'FinnishRussian', 'Chamber', 'Commerce', '', 'major', 'construction', 'companies', 'Finland', 'operating', 'Russia', '']
# Sentence after removing stopwords: ['Tikkurila', 'Powder', 'Coatings', '50', 'employees', 'four', 'paint', 'plants', '', 'generated', 'revenues', 'EUR2', '4', 'USD3', '3', '2010', '']
# Sentence after removing stopwords: ['Neither', 'companies', 'use', 'genetically', 'engineered', 'soy', 'moment', '']
# Sentence after removing stopwords: ['The', 'Division', 'also', 'includes', 'joint', 'sales', '', 'marketing', 'controlling', 'functions', 'units', '']
# Sentence after removing stopwords: ['The', 'identity', 'buyer', 'yet', 'known', '']
# Sentence after removing stopwords: ['It', 'comes', 'complete', 'LCD', 'touch', 'screen', 'system', 'selection', 'chosen', 'function', 'prices', 'start', 'around', 'pounds', '4805', 'mark', '']
# Sentence after removing stopwords: ['CompaniesandMarketscom', 'provides', 'wide', 'range', 'research', 'reports', '', 'industry', 'statistics', 'competitive', 'intelligence', 'industrial', 'sector', '']
# Sentence after removing stopwords: ['However', '', 'production', 'almost', 'entirely', 'labor', 'intensive', 'based', 'small', 'investments', '']
# Sentence after removing stopwords: ['Mr', 'Koistinen', 'joins', 'Nokia', 'Siemens', 'Networks', 'held', 'various', 'senior', 'sales', 'management', 'business', 'development', 'positions', 'since', '1997', '']
# Sentence after removing stopwords: ['Finnish', 'consumers', 'prefer', 'buy', 'cheapest', 'beer', 'brand', '']
# Sentence after removing stopwords: ['SRV', 'also', 'build', 'aqua', 'park', 'wellness', 'area', '', 'restaurant', 'multifunctional', 'ice', 'arena', '']
# Sentence after removing stopwords: ['The', 'ecommerce', 'site', 'flagship', 'managed', 'Marimekko', 'North', 'America', 'Retail', 'LLC', '', 'subsidiary', 'established', 'US', 'last', 'year', '']
# Sentence after removing stopwords: ['The', 'product', 'range', 'includes', 'marinated', 'olives', '', 'cold', 'cuts', '', 'pates', '', 'example', '']
# Sentence after removing stopwords: ['After', 'buying', 'Eukor', 'Car', 'Carriers', '50', 'percent', 'stake', '', 'Grimaldi', 'Group', 'sole', 'owner', 'Swedish', 'rollon', '', 'rolloff', 'port', 'Wallhamn', '']
# Sentence after removing stopwords: ['BasWare', 'Invoice', 'Processing', '', 'BasWare', 'Contract', 'Matching', '', 'BasWare', 'Order', 'Matching', 'BasWare', 'KPI', 'Reporting', 'Tool', 'part', 'BasWare', 'Enterprise', 'Purchase', 'Pay', 'product', 'suite', '']
# Sentence after removing stopwords: ['The', 'net', 'sales', 'Healthcare', 'Trade', 'business', '2009', 'EUR', '1451', 'million', 'EUR', '1552', 'million', 'operating', 'profit', 'EUR', '89', 'million', 'EUR', '79', 'million', '']
# Sentence after removing stopwords: ['After', 'transaction', '', 'Tikkurila', 'powder', 'coatings', 'related', 'operations', '']
# Sentence after removing stopwords: ['In', '2008', '', 'AVC', 'Systemhaus', 'net', 'sales', 'EUR', '10', 'million', 'USD', '71', '']
# Sentence after removing stopwords: ['The', 'process', '', 'technology', '', 'project', 'management', '', 'basic', 'engineering', 'quality', 'assurance', 'within', 'Forest', 'Industry', 'consolidated', 'Vantaa', '', 'southern', 'Finland', '']
# Sentence after removing stopwords: ['The', 'Bank', 'land', 'acquired', 'private', 'banking', 'business', '', 'asset', 'management', '', 'share', 'brokerage', 'business', 'Kaupthing', 'Sweden', 'early', '2009', '']
# Sentence after removing stopwords: ['Swedish', 'Wallenberg', 'family', 'controlled', 'Investor', 'bought', 'large', 'stake', 'C', 'shares', 'Swedish', 'retail', 'bank', 'SEB', '']
# Sentence after removing stopwords: ['The', 'Segu', 'companies', 'PKC', 'Polish', 'unit', 'form', 'business', 'servicing', 'western', 'European', 'markets', '', 'annual', 'sales', 'hundred', 'million', '', '2500', 'employees', '', 'Finnish', 'company', 'CEO', '', 'Harri', 'Suutari', '', 'said', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'privacy', 'security', 'software', 'developer', 'Tectia', 'Oyj', '', 'HEL', '', 'TEC1V', '', 'said', 'Wednesday', 'set', 'two', 'strategic', 'business', 'units', '', 'managed', 'security', 'mobile', 'authentication', '']
# Sentence after removing stopwords: ['Mursula', 'said', 'tried', 'gather', 'macroeconomic', 'perspective', 'see', 'Malaysia', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafers', 'maker', 'Okmetic', 'Oyj', 'said', 'September', '17', '', '2008', 'invest', 'total', '15', 'mln', 'euro', '', '213', 'mln', 'sensor', 'wafer', 'business', '']
# Sentence after removing stopwords: ['Sunrise', 'Resources', 'operates', 'Russian', 'nearshore', 'development', 'markets', 'whollyowned', 'Russian', 'subsidiary', '80', '', 'personnel', 'Russia', '']
# Sentence after removing stopwords: ['Performance', 'based', 'values', 'sustainability', '']
# Sentence after removing stopwords: ['Under', 'agreement', 'Benefon', 'forthcoming', 'range', 'TWIG', 'integrated', 'GPS', 'navigation', 'mobile', 'phone', 'devices', 'use', 'jointly', 'developed', 'webbased', 'tracking', 'location', 'technology', '', 'consumer', 'commercial', 'applications', '']
# Sentence after removing stopwords: ['GeoSentric', 'acquiring', 'extra', 'financing', 'issuing', 'maximum', '220000', 'new', 'shares', 'convertible', 'bond', 'subscription', 'rights', '880000', 'shares', '', 'fully', 'subscribed', '']
# Sentence after removing stopwords: ['The', 'divested', 'activities', 'net', 'sales', 'EUR', '1451', 'million', '2009', 'operating', 'profit', 'EUR', '89', 'million', '']
# Sentence after removing stopwords: ['The', 'final', 'price', 'specified', '14', 'May', '2010', '', 'acquiring', 'company', 'said', '']
# Sentence after removing stopwords: ['Honkarakenne', 'customer', 'project', 'one', 'biggest', 'real', 'estate', 'companies', 'Kazakhstan', '', 'according', 'company', '']
# Sentence after removing stopwords: ['', 'These', 'patronage', 'refunds', 'reward', 'members', 'use', 'feebased', 'services', 'make', 'positive', 'contribution', 'CenCorp', 'operating', 'results', '', '', 'said', 'Bill', 'Walby', '', 'CenCorp', 'CEO', '']
# Sentence after removing stopwords: ['Shareholders', 'right', 'put', 'agenda', 'AGM', 'items', 'within', 'competence', 'general', 'meeting', '']
# Sentence after removing stopwords: ['The', 'front', 'surfaces', 'valve', 'plates', 'directed', 'towards', '']
# Sentence after removing stopwords: ['Subjectmatter', 'invention', 'furthermore', 'use', 'cyclone', 'separating', 'partly', 'molten', 'particles', '', '']
# Sentence after removing stopwords: ['The', 'dualfuel', 'engines', 'vessel', 'operate', 'liquefied', 'natural', 'gas', 'LNG', 'low', 'emissions', '']
# Sentence after removing stopwords: ['The', 'expansion', 'finalized', 'autumn', '2009', '']
# Sentence after removing stopwords: ['MetsaBotnia', 'sell', '821', '', 'stake', 'Uruguayan', 'companies', 'Metsaliitto', '', '55', '', '']
# Sentence after removing stopwords: ['Unit', 'prices', 'straddle', 'carriers', 'vary', 'EUR700', '000', 'EUR900', '000', '', 'company', 'added', '']
# Sentence after removing stopwords: ['The', 'company', 'board', 'directors', 'would', 'propose', 'dividend', 'EUR1', '00', 'per', 'share', '2005', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'Oct', '3', '', 'Markka', 'A', 'Oksanen', 'Harald', 'Kaaja', '', 'Helsinki', '', 'Finland', '', 'Juha', 'Salokannel', 'Kangasala', '', 'Finland', '', 'Arto', 'Palin', 'Viiala', '', 'Finland', '', 'developed', 'system', 'providing', 'communications', 'security', '']
# Sentence after removing stopwords: ['BG', 'Crane', 'strong', 'customer', 'base', 'onroad', 'load', 'handling', 'related', 'installation', 'service', 'businesses', '']
# Sentence after removing stopwords: ['Connectivity', 'Services', 'include', 'outsourced', 'Scan', 'Capture', 'transfers', 'paper', 'invoices', 'electronic', 'format', 'Basware', 'Business', 'Transactions', 'Service', 'enables', 'customer', 'receive', 'send', 'invoices', 'electronic', 'format', '']
# Sentence after removing stopwords: ['The', 'Extraordinary', 'General', 'Meeting', 'expected', 'take', 'place', 'later', '18', 'February', '2011', '']
# Sentence after removing stopwords: ['The', 'shares', 'subscribed', 'stock', 'options', 'registered', 'Trade', 'Register', '20', 'January', '2011', '', 'date', 'new', 'shares', 'establish', 'shareholder', 'rights', '']
# Sentence after removing stopwords: ['In', 'addition', 'verification', 'identity', 'digital', 'signatures', '', 'new', 'stateapproved', 'Mobile', 'ID', 'enables', 'cast', 'votes', 'elections', 'well', '']
# Sentence after removing stopwords: ['The', 'contract', 'includes', 'design', '', 'construction', '', 'delivery', 'equipment', '', 'installation', 'commissioning', '']
# Sentence after removing stopwords: ['The', 'total', 'restructuring', 'costs', 'expected', 'EUR', '30mn', '', 'EUR', '135', 'mn', 'booked', 'December', '2008', '']
# Sentence after removing stopwords: ['IonPhasE', 'second', 'major', 'owner', 'venture', 'capital', 'firm', 'Aura', 'Capital', '']
# Sentence after removing stopwords: ['Any', 'investment', 'investment', 'activity', 'communication', 'relates', 'available', 'relevant', 'persons', 'engaged', 'relevant', 'persons', '']
# Sentence after removing stopwords: ['Pharmaceuticals', '', 'Belgium', 'This', 'brandnew', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'pharmaceutical', 'market', 'Belgium', '']
# Sentence after removing stopwords: ['Risto', 'Jalo', '', 'chief', 'executive', 'Dormus', 'Print', 'also', 'owner', 'remainder', 'company', '', 'keep', 'position', 'acquisition', '']
# Sentence after removing stopwords: ['It', 'first', 'oil', 'company', 'join', 'RSPO', 'commits', 'fully', 'sustainable', 'sourcing', 'feedstocks', 'production', 'NExBTL', 'biodiesel', '', 'said', '']
# Sentence after removing stopwords: ['Sarantel', '', 'based', 'Wellingborough', '', 'UK', '', 'designs', 'highperformance', 'antennas', 'portable', 'wireless', 'devices', '']
# Sentence after removing stopwords: ['The', 'energy', 'shot', 'packed', '100millilitre', 'bag', 'screw', 'cap', '']
# Sentence after removing stopwords: ['Its', 'product', 'portfolio', 'comprises', 'harvesters', '', 'forwarders', '', 'harvester', 'heads', '', 'well', 'cranes', 'loaders', '']
# Sentence after removing stopwords: ['Remote', 'Phone', 'Management', 'demonstrates', 'SysOpen', 'Digia', 'unique', 'endtoend', 'offering', 'operators', '', 'handset', 'manufacturers', 'enterprise', 'customers', '']
# Sentence after removing stopwords: ['Mobile', 'data', 'transfer', 'expected', 'increase', 'explosively', 'LTE', 'era', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'expected', '2008', 'financial', 'performance', 'remain', 'level', '2008', '']
# Sentence after removing stopwords: ['These', 'module', 'products', 'available', 'trials', '3Q07', 'volume', 'deliveries', '4Q07', '']
# Sentence after removing stopwords: ['Glaston', 'share', 'GLA1V', 'listed', 'NASDAQ', 'OMX', 'Helsinki', '', 'Mid', 'Cap', 'List', '']
# Sentence after removing stopwords: ['A', 'Le', 'Coq', 'market', 'share', '413', 'percent', 'rival', 'beverage', 'group', 'Saku', '321', 'percent', '']
# Sentence after removing stopwords: ['The', 'business', 'idea', 'Budget', 'Sport', 'offer', 'customers', 'wide', 'range', 'highquality', 'sports', 'equipment', 'clothing', 'low', 'prices', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'talks', 'involved', 'Food', 'Ingredients', 'Divisions', '', 'well', 'group', 'service', 'functions', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'agreement', 'must', 'approved', 'Russian', 'competition', 'authorities', 'enters', 'force', '']
# Sentence after removing stopwords: ['Water', 'Treatment', 'Products', 'In', 'Australia', 'Today', '', 'Global', 'Research', '', 'Data', 'Services', 'going', 'publish', 'market', 'analysis', 'market', 'chemical', 'water', 'treatment', 'products', 'Australia', '']
# Sentence after removing stopwords: ['The', 'company', 'issue', 'inaugural', 'Eurobond', 'deal', 'near', 'future', 'subject', 'market', 'conditions', '']
# Sentence after removing stopwords: ['', 'That', 'high', 'figure', 'European', 'scale', '', '', 'Noop', 'said', '', 'recalling', 'however', 'also', 'includes', 'beer', 'bought', 'Finnish', 'tourists', '']
# Sentence after removing stopwords: ['The', 'aim', 'CEO', 'QA', 'sessions', 'give', 'clarity', 'information', '', 'made', 'public', 'already', 'earlier', '']
# Sentence after removing stopwords: ['These', 'sections', 'put', 'place', 'form', 'loadbearing', 'steel', 'structure', 'bridge', '', '', 'says', 'Sami', 'Eronen', '', 'Senior', 'Vice', 'President', '', 'Infrastructure', 'Northern', 'Europe', '', 'Ruukki', 'Construction', '']
# Sentence after removing stopwords: ['The', 'use', 'validation', 'rule', 'base', 'enables', 'verifying', 'processing', 'rule', 'bases', 'managed', 'different', 'administrators', 'fulfil', 'set', 'requirements', '']
# Sentence after removing stopwords: ['The', 'plant', 'collect', 'raw', 'material', 'Baltic', 'Sea', 'region', '']
# Sentence after removing stopwords: ['Yvonne', 'Jones', 'owner', 'Chameleon', 'Interiors', '']
# Sentence after removing stopwords: ['M2', 'Communications', 'disclaims', 'liability', 'information', 'provided', 'within', 'information', 'world', 'wide', 'web', '']

# %%
positiveValues
#output is a dictionary-list of words in news column and the count of each of these words in train dataset where sentiment=positive
# Out:
# defaultdict(int,
#             {'Finnish': 121,
#              'consumer': 1,
#              'packaging': 4,
#              'manufacturer': 9,
#              'Huhtamaki': 1,
#              'Oyj': 50,
#              'said': 137,
#              'swung': 5,
#              'net': 98,
#              'profit': 110,
#              '841': 1,
#              'mln': 84,
#              'euro': 37,
#              '': 2295,
#              '1056': 1,
#              'first': 41,
#              'nine': 17,
#              'months': 20,
#              '2006': 40,
#              'loss': 42,
#              '26': 4,
#              '33': 4,
#              'period': 80,
#              '2005': 28,
#              'We': 26,
#              'delighted': 2,
#              'welcome': 5,
#              'Elisa': 8,
#              'Board': 2,
#              'Directors': 2,
#              'Garry': 1,
#              'McGuire': 1,
#              'CEO': 19,
#              'RMG': 1,
#              'Networks': 5,
#              'com': 1,
#              'constantly': 1,
#              'planning': 4,
#              'new': 45,
#              'ways': 1,
#              'serve': 2,
#              'customers': 23,
#              'online': 3,
#              'comprehensive': 2,
#              'basis': 4,
#              'says': 17,
#              'Matti': 4,
#              'Leminen': 1,
#              'President': 5,
#              'Anttila': 1,
#              'Oy': 11,
#              'The': 167,
#              'stable': 1,
#              'outlook': 1,
#              'reflects': 1,
#              'Nokia': 24,
#              'strong': 13,
#              'market': 41,
#              'position': 10,
#              'global': 11,
#              'mobile': 25,
#              'handset': 4,
#              'cash': 5,
#              'flow': 6,
#              'generation': 3,
#              'conservative': 1,
#              'balance': 3,
#              'sheet': 3,
#              'Raab': 1,
#              'In': 43,
#              'quarter': 75,
#              '2010': 71,
#              'marktomarket': 1,
#              'result': 17,
#              'pretax': 12,
#              'EUR': 227,
#              '133': 1,
#              'million': 100,
#              'versus': 12,
#              '32': 4,
#              'last': 18,
#              'year': 84,
#              'Previously': 1,
#              'company': 147,
#              'estimated': 14,
#              'operating': 43,
#              'reach': 3,
#              'level': 4,
#              'autumn': 3,
#              'plans': 10,
#              'expand': 14,
#              'service': 30,
#              'St': 6,
#              'Petersburg': 6,
#              'Moscow': 4,
#              'launch': 3,
#              'Yekaterinburg': 1,
#              'Russia': 15,
#              'flying': 1,
#              'three': 7,
#              'times': 3,
#              'week': 4,
#              'Upgrades': 1,
#              'include': 3,
#              'five': 3,
#              'megapixel': 1,
#              'camera': 1,
#              'voice': 5,
#              'control': 2,
#              'looks': 1,
#              'optical': 2,
#              'mouse': 1,
#              'instead': 1,
#              'Dpad': 1,
#              'upgrade': 4,
#              'clickhappy': 1,
#              'S60': 1,
#              'needed': 1,
#              'forever': 1,
#              'fourth': 8,
#              '2009': 65,
#              'Orion': 4,
#              'went': 7,
#              '338': 1,
#              'yearonyear': 16,
#              'EUR33m': 1,
#              'As': 3,
#              'distribution': 7,
#              'companies': 21,
#              'start': 3,
#              'distribute': 3,
#              'addition': 8,
#              'current': 10,
#              'product': 6,
#              'offering': 10,
#              'Shimano': 2,
#              'reels': 1,
#              'rods': 1,
#              'fishing': 2,
#              'tackle': 2,
#              'products': 17,
#              'exclusive': 2,
#              'Rory': 1,
#              'Fitzgerald': 1,
#              'general': 4,
#              'manager': 4,
#              'operations': 31,
#              'Bristol': 1,
#              'Port': 2,
#              'With': 5,
#              'use': 13,
#              'low': 4,
#              'maintenance': 5,
#              'technology': 29,
#              'save': 2,
#              '30': 12,
#              'per': 29,
#              'cent': 6,
#              'servicing': 1,
#              'plus': 2,
#              'load': 1,
#              'sensing': 1,
#              'hydraulics': 2,
#              'us': 8,
#              'extra': 1,
#              '15': 15,
#              'fuel': 4,
#              'consumption': 4,
#              'announced': 12,
#              'investment': 12,
#              'carmaker': 1,
#              'Hyundai': 1,
#              'example': 1,
#              'sounds': 1,
#              'optimistically': 1,
#              'course': 1,
#              'cars': 1,
#              'mean': 1,
#              'tires': 2,
#              'According': 19,
#              'Aktia': 6,
#              'Bank': 15,
#              'Managing': 3,
#              'Director': 4,
#              'Jussi': 2,
#              'Laitinen': 1,
#              'bank': 3,
#              'aim': 11,
#              'triple': 1,
#              'number': 7,
#              'Finland': 38,
#              'next': 7,
#              'years': 13,
#              'Profit': 6,
#              'taxes': 6,
#              'EUR0': 17,
#              '9': 11,
#              '01': 5,
#              'Commission': 1,
#              'applauded': 1,
#              'applying': 1,
#              'factbased': 1,
#              'datadriven': 1,
#              'approach': 3,
#              'providing': 4,
#              'clarity': 1,
#              'future': 6,
#              'petitions': 1,
#              'Shares': 2,
#              'Corp': 6,
#              'rose': 64,
#              'Thursday': 5,
#              'cell': 3,
#              'phone': 10,
#              'maker': 21,
#              'thirdquarter': 2,
#              'earnings': 10,
#              'almost': 3,
#              'doubled': 4,
#              'share': 41,
#              'increased': 47,
#              'Pretax': 4,
#              '06': 2,
#              'mn': 139,
#              '04': 4,
#              'corresponding': 35,
#              'Advertising': 1,
#              'circulation': 1,
#              'revenues': 5,
#              'grew': 19,
#              '34': 2,
#              'respectively': 14,
#              'Karppinen': 1,
#              'Frozen': 2,
#              'Foods': 2,
#              'posted': 7,
#              'good': 11,
#              'BasWare': 2,
#              'Ilkka': 1,
#              'Sihvo': 1,
#              'comments': 4,
#              'conjunction': 1,
#              'Interim': 1,
#              'Report': 2,
#              'whole': 4,
#              'succeeded': 2,
#              'well': 16,
#              'second': 21,
#              '2007': 38,
#              'hope': 1,
#              'increase': 44,
#              'traffic': 2,
#              'volumes': 4,
#              'opening': 3,
#              'Freight': 1,
#              'One': 2,
#              'Scandinavia': 2,
#              'Neste': 4,
#              'Oil': 5,
#              'signed': 31,
#              'longterm': 10,
#              'procurement': 1,
#              'contracts': 2,
#              'Honkajoki': 1,
#              'Findest': 1,
#              'Protein': 1,
#              'owned': 2,
#              'food': 6,
#              'manufacturers': 2,
#              'supply': 23,
#              'animal': 2,
#              'fat': 2,
#              'biodiesel': 3,
#              'production': 15,
#              '200000': 1,
#              'bcd': 1,
#              'Porvoo': 1,
#              'refinery': 1,
#              '16': 4,
#              'July': 10,
#              'steel': 14,
#              'Rautaruukki': 6,
#              'HEL': 29,
#              'RTRKS': 2,
#              'Ruukki': 11,
#              'today': 35,
#              'turned': 6,
#              'EUR20m': 1,
#              'EUR94m': 1,
#              'Operating': 33,
#              'totalled': 10,
#              '08': 5,
#              'improved': 14,
#              '27': 8,
#              '5798': 1,
#              '4572': 1,
#              'This': 16,
#              'contract': 34,
#              'demonstrates': 1,
#              'ability': 1,
#              'apply': 1,
#              'minerals': 2,
#              'metals': 5,
#              'technologies': 4,
#              'adjacent': 1,
#              'industries': 2,
#              'oil': 4,
#              'shale': 1,
#              'processing': 4,
#              'Nevertheless': 2,
#              'Fitch': 2,
#              'notes': 1,
#              'business': 30,
#              'fundamentals': 1,
#              'banks': 3,
#              'currently': 2,
#              'remain': 2,
#              'sound': 2,
#              'Metso': 9,
#              'Paper': 3,
#              'awarded': 18,
#              'rebuild': 2,
#              'Sabah': 2,
#              'Forest': 1,
#              'Industries': 1,
#              'SFI': 1,
#              'pulp': 3,
#              'mill': 3,
#              'Malaysia': 2,
#              'Aldata': 2,
#              'Solution': 2,
#              'GOLD': 1,
#              'system': 11,
#              'two': 16,
#              'French': 2,
#              'retail': 6,
#              'chains': 1,
#              'HELSINKI': 6,
#              'Thomson': 2,
#              'Financial': 5,
#              'Kemira': 6,
#              'GrowHow': 1,
#              'sales': 101,
#              'especially': 4,
#              'fertilizer': 2,
#              'Europe': 5,
#              'normally': 1,
#              'stronger': 2,
#              'KCI': 2,
#              'Konecranes': 6,
#              'order': 27,
#              'four': 8,
#              'hot': 1,
#              'metal': 9,
#              'ladle': 1,
#              'cranes': 2,
#              'Indian': 7,
#              'producer': 4,
#              'Bhushan': 1,
#              'Steel': 1,
#              'Strips': 1,
#              'delivered': 3,
#              'talks': 1,
#              'aimed': 5,
#              'restructuring': 6,
#              'cutting': 1,
#              'costs': 9,
#              'terms': 6,
#              'profitability': 3,
#              'best': 8,
#              'history': 2,
#              'Chief': 4,
#              'Executive': 3,
#              'VeliMatti': 1,
#              'Mattila': 1,
#              'Uponor': 4,
#              'performance': 8,
#              'spite': 1,
#              'decrease': 2,
#              'residential': 3,
#              'construction': 15,
#              'US': 13,
#              'Both': 11,
#              'sixmonth': 3,
#              'EUR7': 2,
#              '5': 13,
#              'EUR655': 1,
#              'compared': 35,
#              'wood': 3,
#              'handling': 8,
#              'bleaching': 1,
#              'lines': 3,
#              'kraft': 1,
#              'liner': 1,
#              'washing': 1,
#              'line': 13,
#              'Klabin': 1,
#              'Tel\x97maco': 1,
#              'Borba': 1,
#              'Brazilian': 4,
#              'state': 2,
#              'Paranè': 1,
#              'previously': 4,
#              'concluded': 4,
#              'adaptation': 2,
#              'measures': 5,
#              'concerning': 2,
#              'staff': 2,
#              'adequate': 2,
#              'time': 5,
#              'continue': 7,
#              'plant': 17,
#              'world': 14,
#              'biggest': 3,
#              'magazine': 1,
#              'paper': 3,
#              'program': 6,
#              'improve': 10,
#              'efficiency': 7,
#              'closing': 2,
#              'several': 3,
#              'least': 2,
#              'competitive': 5,
#              'mills': 3,
#              'would': 15,
#              'cover': 4,
#              'resulting': 1,
#              'annual': 11,
#              'savings': 12,
#              'euro200': 1,
#              '240': 1,
#              'Suominen': 4,
#              'Corporation': 24,
#              'estimates': 11,
#              'costcutting': 1,
#              'started': 4,
#              'higher': 10,
#              'prices': 4,
#              'expected': 15,
#              'growth': 24,
#              'volume': 5,
#              'Wet': 1,
#              'Wipes': 1,
#              'make': 5,
#              'profitable': 4,
#              'Net': 12,
#              '255': 1,
#              'EUR59': 1,
#              '6': 17,
#              'chargers': 1,
#              '41': 5,
#              '659': 1,
#              'pieces': 1,
#              'Kesko': 6,
#              'Agro': 2,
#              'Eesti': 2,
#              'retailer': 3,
#              'wholesaler': 1,
#              'grain': 2,
#              'agricultural': 2,
#              'warehousing': 1,
#              'machinery': 8,
#              'accessories': 2,
#              '81': 2,
#              'euros': 17,
#              'onetenth': 1,
#              'preceding': 1,
#              'systems': 9,
#              'Cargotec': 6,
#              'CGCBV': 3,
#              '13': 12,
#              'USD': 14,
#              '166': 2,
#              'deliver': 8,
#              'MacGregor': 1,
#              'hatch': 1,
#              'covers': 2,
#              'ships': 1,
#              'ordered': 4,
#              'Norwegian': 7,
#              'shipowner': 1,
#              'Grieg': 1,
#              'Shipping': 3,
#              'Our': 7,
#              'extensive': 2,
#              'cooperation': 19,
#              'also': 39,
#              'bolster': 1,
#              'SysOpen': 2,
#              'Digia': 2,
#              'domestic': 3,
#              'operator': 7,
#              'Kallioranta': 1,
#              'adds': 3,
#              'strategic': 8,
#              'Rentakran': 1,
#              'brings': 3,
#              'alreadyworking': 1,
#              'relationships': 1,
#              'authorities': 1,
#              'territories': 1,
#              'Jarmo': 1,
#              'Laasanen': 1,
#              'senior': 1,
#              'Cramo': 3,
#              'A': 9,
#              'portion': 1,
#              '125': 1,
#              'recorded': 3,
#              'part': 9,
#              'winnings': 1,
#              'prior': 2,
#              'patent': 1,
#              'dispute': 1,
#              'Q1': 3,
#              '10': 15,
#              '19': 8,
#              'April': 6,
#              'forest': 6,
#              'equipment': 22,
#              'Ponsse': 3,
#              'PON1V': 1,
#              'expects': 13,
#              'swing': 2,
#              'EUR6': 3,
#              '3': 20,
#              'EUR9': 1,
#              'earlier': 28,
#              'Finlandbased': 1,
#              'Elcoteq': 10,
#              'SE': 3,
#              'privately': 1,
#              'held': 4,
#              'provider': 19,
#              'electronics': 6,
#              'manufacturing': 13,
#              'services': 38,
#              'communications': 3,
#              'deal': 13,
#              'Andrew': 1,
#              'Lidskoe': 1,
#              'Pivo': 1,
#              'foresees': 1,
#              'integrated': 4,
#              'modernization': 1,
#              'updating': 1,
#              'transport': 4,
#              'logistics': 4,
#              'infrastructure': 5,
#              'developing': 6,
#              'marketing': 2,
#              'instruments': 2,
#              'Mikshis': 1,
#              'Done': 2,
#              'Logistics': 2,
#              'largest': 10,
#              'Norway': 2,
#              'diversified': 1,
#              'group': 36,
#              'Nokian': 7,
#              'Tyres': 4,
#              'Kazakhstan': 5,
#              'Ordabasy': 2,
#              'agreement': 35,
#              'build': 3,
#              'Astana': 1,
#              'produce': 3,
#              'car': 2,
#              'chairman': 1,
#              'Dinmukhamet': 1,
#              'Idrisov': 1,
#              'press': 3,
#              'conference': 1,
#              'At': 3,
#              'seminar': 2,
#              'memorandum': 3,
#              'understanding': 3,
#              'Company': 5,
#              'Vietnam': 3,
#              'National': 2,
#              'Chemical': 3,
#              'priority': 1,
#              'strengthen': 7,
#              'Hannu': 1,
#              'Krook': 1,
#              'economic': 1,
#              'occupancy': 1,
#              'rate': 2,
#              'Sponda': 2,
#              'property': 4,
#              'portfolio': 5,
#              '912': 1,
#              '888': 1,
#              'Ministry': 1,
#              'Water': 2,
#              'Tanzania': 2,
#              'Poyry': 5,
#              'water': 5,
#              'sanitation': 2,
#              'engineering': 10,
#              'assignment': 2,
#              'rehabilitation': 1,
#              'extension': 2,
#              'Bukoba': 1,
#              'Musoma': 1,
#              'situated': 1,
#              'Lake': 1,
#              'Victoria': 1,
#              'northern': 3,
#              'bought': 3,
#              'Chicagobased': 1,
#              'Navteq': 2,
#              '2008': 46,
#              'acquiring': 2,
#              'maps': 3,
#              'database': 1,
#              'compete': 2,
#              'Google': 1,
#              'navigation': 4,
#              'device': 4,
#              'TomTom': 2,
#              'NV': 2,
#              'Garmin': 1,
#              'Ltd': 5,
#              'made': 4,
#              '1510': 1,
#              '1437': 1,
#              'record': 9,
#              'It': 13,
#              'offshore': 1,
#              'There': 2,
#              'recovery': 1,
#              'base': 8,
#              'demand': 7,
#              'China': 10,
#              'however': 3,
#              'GeoSentric': 1,
#              'developer': 8,
#              'solutions': 20,
#              'location': 3,
#              'based': 4,
#              'preliminary': 2,
#              'agreed': 7,
#              '6mn': 1,
#              'shortterm': 1,
#              'funding': 1,
#              'leading': 13,
#              'investor': 3,
#              'UPM': 1,
#              'deliveries': 3,
#              'third': 24,
#              '4': 15,
#              'percent': 44,
#              'Pesonen': 1,
#              'end': 10,
#              'outlets': 2,
#              'rise': 10,
#              '6070': 1,
#              'import': 1,
#              'retailing': 1,
#              'VVAuto': 1,
#              'saw': 3,
#              'grow': 3,
#              '171': 2,
#              'pct': 18,
#              'I': 7,
#              'looking': 2,
#              'forward': 5,
#              'contribute': 2,
#              'SRV': 2,
#              'success': 1,
#              'competence': 2,
#              'Taneli': 1,
#              'Hassinen': 1,
#              'combines': 1,
#              'perfect': 1,
#              'price': 12,
#              'sophisticated': 1,
#              'management': 13,
#              'facilities': 2,
#              '114': 5,
#              '822': 1,
#              '6865': 1,
#              '138': 1,
#              'existing': 4,
#              'partnership': 3,
#              'Cybercom': 1,
#              'Teleste': 8,
#              'CTO': 1,
#              'Esko': 1,
#              'Myllyla': 1,
#              'Nordea': 7,
#              'sees': 4,
#              'return': 3,
#              'positive': 14,
#              'Baltic': 11,
#              'countries': 12,
#              '2011': 12,
#              'These': 3,
#              'moderate': 1,
#              'significant': 12,
#              'changes': 2,
#              'resulted': 1,
#              '2432': 1,
#              'reduction': 2,
#              'CVD': 1,
#              'risk': 1,
#              'Sweden': 6,
#              'review': 3,
#              'totaled': 8,
#              '308': 2,
#              'First': 1,
#              'underlying': 1,
#              'eur': 36,
#              'MANAVIGATORSeptember': 1,
#              '7': 14,
#              '2010Kemira': 1,
#              'unveils': 1,
#              'JV': 1,
#              'IVRCL': 3,
#              'chemicals': 3,
#              'KRA1V': 1,
#              'Tuesday': 6,
#              'inked': 1,
#              'form': 4,
#              'joint': 3,
#              'venture': 4,
#              'India': 8,
#              'local': 6,
#              'firm': 5,
#              'Infrastructure': 1,
#              'Projects': 1,
#              'BOM': 1,
#              '530773': 1,
#              'Alma': 1,
#              'Media': 1,
#              'forecast': 2,
#              'Adanac': 1,
#              'Molybdenum': 1,
#              'Canada': 2,
#              'grinding': 3,
#              'molybdenum': 1,
#              'project': 15,
#              'British': 1,
#              'Columbia': 1,
#              'Shalkiya': 4,
#              'Zinc': 2,
#              'zinclead': 2,
#              '19mn': 1,
#              'fair': 3,
#              'value': 9,
#              'Kapiteeli': 1,
#              'acquisition': 14,
#              '26862': 1,
#              '12597': 1,
#              '135': 1,
#              '97': 3,
#              'soapstone': 1,
#              'deposits': 2,
#              'Medvezhyegorsk': 1,
#              'area': 7,
#              'Tulikivi': 1,
#              'reserves': 1,
#              'considerably': 5,
#              'Clothing': 2,
#              'chain': 7,
#              'SeppÆlÆ': 2,
#              '8': 12,
#              '1552': 1,
#              '311': 1,
#              '2004': 10,
#              'clearly': 4,
#              'pleased': 8,
#              'proud': 5,
#              'Juha': 5,
#              'Rantanen': 2,
#              'statement': 4,
#              'supports': 2,
#              'strategy': 10,
#              'close': 3,
#              'around': 7,
#              'related': 2,
#              'ADP': 8,
#              'News': 8,
#              'Oct': 2,
#              '31': 7,
#              'Raisio': 4,
#              'OMX': 17,
#              'RAIVV': 1,
#              'jumped': 5,
#              '164': 1,
#              '209': 1,
#              '11': 6,
#              '2': 14,
#              'successful': 1,
#              'effort': 1,
#              'financial': 14,
#              'feeling': 1,
#              'quite': 3,
#              'region': 9,
#              'Its': 3,
#              'main': 7,
#              'Glass': 1,
#              'Machinery': 2,
#              'Group': 27,
#              'Glaston': 3,
#              'Technologies': 2,
#              'leader': 2,
#              'glass': 6,
#              'machines': 4,
#              'TeliaSonera': 4,
#              '100': 9,
#              'invested': 1,
#              'bring': 5,
#              'coverage': 1,
#              '90': 2,
#              'Nepal': 1,
#              'population': 1,
#              'trade': 2,
#              'stands': 2,
#              'billion': 19,
#              'dollars': 2,
#              'growing': 3,
#              '96': 2,
#              'fiscal': 4,
#              'cost': 12,
#              '3mn': 1,
#              'AFX': 4,
#              'reported': 8,
#              '615': 1,
#              '486': 1,
#              'back': 5,
#              '203': 2,
#              'Beyond': 1,
#              'capabilities': 2,
#              'streamlined': 1,
#              'way': 5,
#              'comply': 1,
#              'recalls': 1,
#              'traceability': 1,
#              'requirements': 4,
#              'advantage': 2,
#              'Actions': 1,
#              'operational': 4,
#              'adjust': 2,
#              'annualised': 1,
#              'permanent': 1,
#              '45': 8,
#              'effected': 1,
#              'mostly': 2,
#              'half': 4,
#              'EPS': 17,
#              '004': 2,
#              '002': 1,
#              'EBITDA': 4,
#              'EUR116m': 1,
#              'EUR115m': 1,
#              'margin': 7,
#              'Incap': 3,
#              'Lankapaja': 1,
#              'enter': 2,
#              'actual': 1,
#              'transfer': 5,
#              'sheetmetal': 1,
#              'buyer': 2,
#              'February': 6,
#              'complete': 2,
#              '1': 18,
#              'March': 5,
#              'Revenue': 4,
#              'x20ac': 8,
#              '580': 1,
#              '743': 2,
#              '569': 1,
#              'feels': 1,
#              'leases': 1,
#              'prime': 2,
#              'locations': 5,
#              'due': 4,
#              'producing': 1,
#              'formations': 1,
#              'immediate': 2,
#              'Panostaja': 2,
#              '86': 1,
#              '200506': 1,
#              'ended': 1,
#              'October': 10,
#              '28': 9,
#              '37': 3,
#              '200405': 1,
#              'Exports': 2,
#              'accounted': 2,
#              '654': 1,
#              'representing': 5,
#              'customer': 7,
#              'satisfied': 2,
#              'Basware': 7,
#              'Invoice': 3,
#              'Automation': 3,
#              'solution': 10,
#              'extends': 2,
#              'implementation': 1,
#              'geographies': 1,
#              'Thanks': 1,
#              'multiplying': 1,
#              'effect': 3,
#              'wagon': 1,
#              'much': 1,
#              'efficient': 5,
#              'development': 5,
#              'Malkia': 1,
#              'VR': 1,
#              'Cargo': 3,
#              'Demand': 3,
#              'seems': 2,
#              'hit': 2,
#              'bottom': 1,
#              'signs': 1,
#              'improvement': 6,
#              'seen': 6,
#              'Ahlstrom': 1,
#              'key': 1,
#              'nonwovens': 1,
#              'Russian': 6,
#              'Tver': 1,
#              'Mill': 1,
#              'Vaahto': 3,
#              'Pulp': 1,
#              '510': 1,
#              'land': 3,
#              'reports': 6,
#              '213': 1,
#              '61': 3,
#              'Sanoma': 1,
#              'Magazines': 1,
#              '1401': 1,
#              '1318': 1,
#              'Comparable': 1,
#              'target': 5,
#              'components': 3,
#              'supplier': 7,
#              'Componenta': 6,
#              '35': 6,
#              '22': 6,
#              'diluted': 2,
#              'came': 4,
#              '034': 1,
#              '016': 1,
#              'ago': 9,
#              'widened': 2,
#              '4851': 2,
#              '4831': 1,
#              'Satama': 2,
#              '444': 1,
#              'JanuarySeptember': 6,
#              '373': 1,
#              'access': 3,
#              'chrome': 1,
#              'ore': 3,
#              'resources': 2,
#              'Turkey': 1,
#              'Kaido': 1,
#              'Kaare': 1,
#              'director': 7,
#              'Atria': 7,
#              'investments': 7,
#              'pig': 1,
#              'farms': 1,
#              'surpass': 2,
#              'EEK': 1,
#              '150mn': 1,
#              '959': 1,
#              '1419': 1,
#              'past': 4,
#              'Lithuanian': 8,
#              'beer': 8,
#              'makers': 3,
#              'sold': 6,
#              '25688': 1,
#              'liters': 9,
#              'yearearlier': 2,
#              'figure': 3,
#              '24592': 1,
#              'book': 4,
#              'stood': 4,
#              'bln': 3,
#              'September': 14,
#              '242': 1,
#              'international': 6,
#              'orders': 15,
#              'amounting': 1,
#              '365': 1,
#              '5343': 1,
#              '55': 3,
#              '07': 1,
#              'give': 1,
#              'opportunity': 1,
#              'keyin': 1,
#              'invoices': 1,
#              'receive': 1,
#              ...})

# %%
positiveValues.items()
#o/p is a dictionary with the word in news column as key and its count within the train dataset as its corresponding value
# Out:
# dict_items([('Finnish', 121), ('consumer', 1), ('packaging', 4), ('manufacturer', 9), ('Huhtamaki', 1), ('Oyj', 50), ('said', 137), ('swung', 5), ('net', 98), ('profit', 110), ('841', 1), ('mln', 84), ('euro', 37), ('', 2295), ('1056', 1), ('first', 41), ('nine', 17), ('months', 20), ('2006', 40), ('loss', 42), ('26', 4), ('33', 4), ('period', 80), ('2005', 28), ('We', 26), ('delighted', 2), ('welcome', 5), ('Elisa', 8), ('Board', 2), ('Directors', 2), ('Garry', 1), ('McGuire', 1), ('CEO', 19), ('RMG', 1), ('Networks', 5), ('com', 1), ('constantly', 1), ('planning', 4), ('new', 45), ('ways', 1), ('serve', 2), ('customers', 23), ('online', 3), ('comprehensive', 2), ('basis', 4), ('says', 17), ('Matti', 4), ('Leminen', 1), ('President', 5), ('Anttila', 1), ('Oy', 11), ('The', 167), ('stable', 1), ('outlook', 1), ('reflects', 1), ('Nokia', 24), ('strong', 13), ('market', 41), ('position', 10), ('global', 11), ('mobile', 25), ('handset', 4), ('cash', 5), ('flow', 6), ('generation', 3), ('conservative', 1), ('balance', 3), ('sheet', 3), ('Raab', 1), ('In', 43), ('quarter', 75), ('2010', 71), ('marktomarket', 1), ('result', 17), ('pretax', 12), ('EUR', 227), ('133', 1), ('million', 100), ('versus', 12), ('32', 4), ('last', 18), ('year', 84), ('Previously', 1), ('company', 147), ('estimated', 14), ('operating', 43), ('reach', 3), ('level', 4), ('autumn', 3), ('plans', 10), ('expand', 14), ('service', 30), ('St', 6), ('Petersburg', 6), ('Moscow', 4), ('launch', 3), ('Yekaterinburg', 1), ('Russia', 15), ('flying', 1), ('three', 7), ('times', 3), ('week', 4), ('Upgrades', 1), ('include', 3), ('five', 3), ('megapixel', 1), ('camera', 1), ('voice', 5), ('control', 2), ('looks', 1), ('optical', 2), ('mouse', 1), ('instead', 1), ('Dpad', 1), ('upgrade', 4), ('clickhappy', 1), ('S60', 1), ('needed', 1), ('forever', 1), ('fourth', 8), ('2009', 65), ('Orion', 4), ('went', 7), ('338', 1), ('yearonyear', 16), ('EUR33m', 1), ('As', 3), ('distribution', 7), ('companies', 21), ('start', 3), ('distribute', 3), ('addition', 8), ('current', 10), ('product', 6), ('offering', 10), ('Shimano', 2), ('reels', 1), ('rods', 1), ('fishing', 2), ('tackle', 2), ('products', 17), ('exclusive', 2), ('Rory', 1), ('Fitzgerald', 1), ('general', 4), ('manager', 4), ('operations', 31), ('Bristol', 1), ('Port', 2), ('With', 5), ('use', 13), ('low', 4), ('maintenance', 5), ('technology', 29), ('save', 2), ('30', 12), ('per', 29), ('cent', 6), ('servicing', 1), ('plus', 2), ('load', 1), ('sensing', 1), ('hydraulics', 2), ('us', 8), ('extra', 1), ('15', 15), ('fuel', 4), ('consumption', 4), ('announced', 12), ('investment', 12), ('carmaker', 1), ('Hyundai', 1), ('example', 1), ('sounds', 1), ('optimistically', 1), ('course', 1), ('cars', 1), ('mean', 1), ('tires', 2), ('According', 19), ('Aktia', 6), ('Bank', 15), ('Managing', 3), ('Director', 4), ('Jussi', 2), ('Laitinen', 1), ('bank', 3), ('aim', 11), ('triple', 1), ('number', 7), ('Finland', 38), ('next', 7), ('years', 13), ('Profit', 6), ('taxes', 6), ('EUR0', 17), ('9', 11), ('01', 5), ('Commission', 1), ('applauded', 1), ('applying', 1), ('factbased', 1), ('datadriven', 1), ('approach', 3), ('providing', 4), ('clarity', 1), ('future', 6), ('petitions', 1), ('Shares', 2), ('Corp', 6), ('rose', 64), ('Thursday', 5), ('cell', 3), ('phone', 10), ('maker', 21), ('thirdquarter', 2), ('earnings', 10), ('almost', 3), ('doubled', 4), ('share', 41), ('increased', 47), ('Pretax', 4), ('06', 2), ('mn', 139), ('04', 4), ('corresponding', 35), ('Advertising', 1), ('circulation', 1), ('revenues', 5), ('grew', 19), ('34', 2), ('respectively', 14), ('Karppinen', 1), ('Frozen', 2), ('Foods', 2), ('posted', 7), ('good', 11), ('BasWare', 2), ('Ilkka', 1), ('Sihvo', 1), ('comments', 4), ('conjunction', 1), ('Interim', 1), ('Report', 2), ('whole', 4), ('succeeded', 2), ('well', 16), ('second', 21), ('2007', 38), ('hope', 1), ('increase', 44), ('traffic', 2), ('volumes', 4), ('opening', 3), ('Freight', 1), ('One', 2), ('Scandinavia', 2),  ...

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive=pd.DataFrame(sorted(positiveValues.items(),key=lambda x:x[1],reverse=True))
df_negative=pd.DataFrame(sorted(negativeValues.items(),key=lambda x:x[1],reverse=True))
df_neutral=pd.DataFrame(sorted(neutralValues.items(),key=lambda x:x[1],reverse=True))

# %%
pd1=df_positive[0][:10]
pd2=df_positive[1][:10]

ned1=df_negative[0][:10]
ned2=df_negative[1][:10]

nud1=df_neutral[0][:10]
nud2=df_neutral[1][:10]


plt.figure(1,figsize=(16,4))

plt.bar(pd1,pd2, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-UNIGRAM ANALYSIS")

plt.savefig("positive-unigram.png")
plt.show()

# %%
df_positive.head(10)
# Out:
#          0     1
# 0           2295
# 1      EUR   227
# 2      The   167
# 3  company   147
# 4       mn   139
# 5     said   137
# 6  Finnish   121
# 7   profit   110
# 8    sales   101
# 9  million   100

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1,ned2, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-UNIGRAM ANALYSIS")

plt.savefig("negative-unigram.png")
plt.show()

# %%
df_negative.head(10)
# Out:
#          0    1
# 0           994
# 1      EUR  195
# 2       mn  154
# 3   profit   86
# 4   period   58
# 5    sales   56
# 6      The   54
# 7  Finnish   54
# 8  company   52
# 9     2008   52

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1,nud2, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-UNIGRAM ANALYSIS")

plt.savefig("neutral-unigram.png")
plt.show()

# %%
df_neutral.head(10)
# Out:
#          0     1
# 0           4286
# 1      The   613
# 2  company   288
# 3  Finland   146
# 4     said   135
# 5  Finnish   129
# 6      EUR   121
# 7   shares   106
# 8  million   106
# 9    sales    99

# %% [markdown]
# **Creating bigrams**

# %%
positiveValues2=defaultdict(int)
negativeValues2=defaultdict(int)
neutralValues2=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text,2):
    positiveValues2[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text,2):
    negativeValues2[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text,2):
    neutralValues2[word]+=1
# Out:
# Sentence after removing stopwords: ['Finnish', 'consumer', 'packaging', 'manufacturer', 'Huhtamaki', 'Oyj', 'said', 'swung', 'net', 'profit', '841', 'mln', 'euro', '', '1056', 'mln', 'first', 'nine', 'months', '2006', 'net', 'loss', '26', 'mln', 'euro', '', '33', 'mln', 'period', '2005', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'welcome', 'Elisa', 'Board', 'Directors', '', '', 'said', 'Garry', 'McGuire', '', 'CEO', 'RMG', 'Networks', '']
# Sentence after removing stopwords: ['com', '', 'constantly', 'planning', 'new', 'ways', 'serve', 'customers', 'online', 'comprehensive', 'basis', '', '', 'says', 'Matti', 'Leminen', '', 'President', 'Anttila', 'Oy', '']
# Sentence after removing stopwords: ['', 'The', 'stable', 'outlook', 'reflects', 'Nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', '', 'strong', 'cash', 'flow', 'generation', '', 'conservative', 'balance', 'sheet', '', '', 'said', 'Raab', '']
# Sentence after removing stopwords: ['In', 'first', 'quarter', '2010', '', 'marktomarket', 'result', 'pretax', 'profit', 'EUR', '133', 'million', 'versus', 'loss', 'EUR', '32', 'million', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Previously', 'company', 'estimated', 'operating', 'profit', 'reach', 'level', '2005', '']
# Sentence after removing stopwords: ['In', 'autumn', '', 'plans', 'expand', 'service', 'St', 'Petersburg', 'Moscow', 'launch', 'service', 'Yekaterinburg', '', 'Russia', '', 'flying', 'three', 'times', 'week', '']
# Sentence after removing stopwords: ['Upgrades', 'include', 'five', 'megapixel', 'camera', '', 'voice', 'control', '', 'looks', 'optical', 'mouse', 'instead', 'Dpad', '', 'upgrade', 'clickhappy', 'S60', 'needed', 'forever', '']
# Sentence after removing stopwords: ['In', 'fourth', 'quarter', '2009', '', 'Orion', 'net', 'profit', 'went', '338', '', 'yearonyear', 'EUR33m', '']
# Sentence after removing stopwords: ['As', 'result', '', 'distribution', 'companies', 'start', 'distribute', '', 'addition', 'current', 'product', 'offering', '', 'Shimano', 'reels', '', 'rods', 'Shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis', '']
# Sentence after removing stopwords: ['Rory', 'Fitzgerald', '', 'general', 'manager', '', 'operations', '', 'Bristol', 'Port', '', 'said', '', '', 'With', 'use', 'low', 'maintenance', 'technology', 'save', '30', 'per', 'cent', 'servicing', '', 'plus', 'load', 'sensing', 'hydraulics', 'save', 'us', 'extra', '15', '30', 'per', 'cent', 'fuel', 'consumption', '', '']
# Sentence after removing stopwords: ['', 'The', 'announced', 'investment', 'carmaker', 'Hyundai', 'example', 'sounds', 'optimistically', 'us', 'course', 'new', 'cars', 'mean', 'new', 'tires', '', '']
# Sentence after removing stopwords: ['According', 'Finnish', 'Aktia', 'Bank', 'Managing', 'Director', 'Jussi', 'Laitinen', '', 'bank', 'aim', 'triple', 'number', 'customers', 'Finland', 'next', 'five', 'years', '']
# Sentence after removing stopwords: ['Profit', 'taxes', 'period', 'EUR0', '9', '', 'EUR0', '01', 'last', 'year', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['Shares', 'Nokia', 'Corp', 'rose', 'Thursday', 'cell', 'phone', 'maker', 'said', 'thirdquarter', 'earnings', 'almost', 'doubled', 'share', 'global', 'handset', 'market', 'increased', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '06', 'mn', 'EUR', '04', 'mn', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Advertising', 'circulation', 'revenues', 'grew', '34', '', '04', '', '', 'respectively', '']
# Sentence after removing stopwords: ['According', 'CEO', 'Matti', 'Karppinen', '', 'Frozen', 'Foods', 'posted', 'good', 'result', '2010', '', '2009', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['We', 'hope', 'increase', 'traffic', 'volumes', 'opening', 'Freight', 'One', 'Scandinavia', '', '']
# Sentence after removing stopwords: ['Neste', 'Oil', 'Corp', 'signed', 'longterm', 'procurement', 'contracts', 'Honkajoki', 'Oy', 'Findest', 'Protein', 'Oy', '', 'owned', 'Finnish', 'food', 'manufacturers', '', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'Neste', '200000', 'bcd', 'Porvoo', '', 'Finland', '', 'refinery', '']
# Sentence after removing stopwords: ['2010', '16', 'July', '2010', '', 'Finnish', 'steel', 'maker', 'Rautaruukki', 'Oyj', 'HEL', '', 'RTRKS', '', 'Ruukki', '', 'said', 'today', 'turned', 'net', 'profit', 'EUR20m', 'second', 'quarter', '2010', 'net', 'loss', 'EUR94m', 'corresponding', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '04', 'mn', '', 'operating', 'loss', 'EUR', '08', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', '27', '', 'EUR', '5798', 'mn', 'EUR', '4572', 'mn', '2006', '']
# Sentence after removing stopwords: ['', 'This', 'contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', '', 'oil', 'shale', 'processing', '']
# Sentence after removing stopwords: ['Nevertheless', '', 'Fitch', 'notes', 'business', 'fundamentals', 'three', 'banks', 'currently', 'remain', 'sound', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'Paper', 'awarded', 'contract', 'rebuild', 'Sabah', 'Forest', 'Industries', '', '', 'SFI', '', 'pulp', 'mill', 'Sabah', '', 'Malaysia', '']
# Sentence after removing stopwords: ['Finnish', 'Aldata', 'Solution', 'signed', 'contract', 'supply', 'GOLD', 'system', 'two', 'French', 'retail', 'chains', '']
# Sentence after removing stopwords: ['HELSINKI', 'Thomson', 'Financial', 'Kemira', 'GrowHow', 'swung', 'profit', 'first', 'quarter', 'earnings', 'improved', 'sales', '', 'especially', 'fertilizer', 'business', 'Europe', '', 'normally', 'stronger', 'first', 'quarter', '']
# Sentence after removing stopwords: ['Finnish', 'KCI', 'Konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'Indian', 'steel', 'producer', 'Bhushan', 'Steel', '', 'Strips', 'delivered', '2007', '']
# Sentence after removing stopwords: ['The', 'talks', 'aimed', 'restructuring', 'operations', 'cutting', 'costs', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['Uponor', 'improved', 'performance', 'spite', 'decrease', 'residential', 'construction', 'US', '']
# Sentence after removing stopwords: ['Both', 'operating', 'profit', 'net', 'sales', 'sixmonth', 'period', 'increased', '', 'respectively', 'EUR7', '5', 'EUR655', '5', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', '', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'Klabin', 'Tel\x97maco', 'Borba', 'mill', 'Brazilian', 'state', 'Paranè', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'world', 'biggest', 'magazine', 'paper', 'maker', 'said', 'program', 'improve', 'efficiency', 'include', 'closing', 'several', 'least', 'competitive', 'mills', 'would', 'cover', 'company', 'operations', 'resulting', 'annual', 'savings', 'euro200', 'million', 'US', '240', 'million', '']
# Sentence after removing stopwords: ['Suominen', 'Corporation', 'estimates', 'costcutting', 'program', 'started', 'autumn', '2005', '', 'higher', 'sales', 'prices', '', 'expected', 'growth', 'volume', 'Wet', 'Wipes', '', 'make', 'company', 'operations', 'profitable', '']
# Sentence after removing stopwords: ['Net', 'sales', 'rose', '255', '', 'yearonyear', 'EUR59', '6', '', 'number', 'chargers', 'delivered', 'went', '41', '', '659', 'million', 'pieces', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Eesti', '', 'retailer', 'wholesaler', 'grain', '', 'agricultural', 'warehousing', 'machinery', 'accessories', '', 'net', 'sales', '81', 'million', 'euros', '2007', '', 'increase', 'onetenth', 'preceding', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'handling', 'systems', 'company', 'Cargotec', 'Oyj', '', 'HEL', '', 'CGCBV', '', 'said', 'today', 'EUR', '13', 'million', '', 'USD', '166', '', 'contract', 'deliver', 'MacGregor', 'hatch', 'covers', 'ships', 'ordered', 'Norwegian', 'shipowner', 'Grieg', 'Shipping', '']
# Sentence after removing stopwords: ['', 'Our', 'extensive', 'cooperation', 'also', 'bolster', 'SysOpen', 'Digia', 'position', 'domestic', 'operator', 'market', '', '', 'Kallioranta', 'adds', '']
# Sentence after removing stopwords: ['', 'Our', 'strategic', 'cooperation', 'Rentakran', 'brings', 'us', 'new', 'customers', 'alreadyworking', 'relationships', 'authorities', 'new', 'territories', '', '', 'said', 'Jarmo', 'Laasanen', '', 'senior', 'manager', 'Cramo', '']
# Sentence after removing stopwords: ['A', 'portion', '', '', '125', 'million', '', 'recorded', 'part', 'winnings', 'prior', 'patent', 'dispute', 'Finnish', 'phone', 'maker', 'Nokia', 'Oyj', '']
# Sentence after removing stopwords: ['Q1', '10', '19', 'April', '2010', '', 'Finnish', 'forest', 'machinery', 'equipment', 'maker', 'Ponsse', 'Oyj', 'HEL', '', 'PON1V', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'EUR6', '3', 'first', 'quarter', '2010', '', 'EUR9', '6', 'loss', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Finlandbased', 'Elcoteq', 'SE', '', 'privately', 'held', 'provider', 'electronics', 'manufacturing', 'services', 'communications', 'companies', '', 'said', 'Thursday', 'signed', 'longterm', 'manufacturing', 'supply', 'deal', 'communications', 'equipment', 'company', 'Andrew', 'Corp', '']
# Sentence after removing stopwords: ['', 'Lidskoe', 'Pivo', 'investment', 'program', 'foresees', 'integrated', 'modernization', 'production', '', 'updating', 'transport', 'logistics', 'infrastructure', 'developing', 'new', 'marketing', 'instruments', '', '', 'Mikshis', 'said', '']
# Sentence after removing stopwords: ['This', 'Done', 'Logistics', '', 'largest', 'order', 'Norway', '', 'diversified', 'group', 'said', '']
# Sentence after removing stopwords: ['Finland', 'Nokian', 'Tyres', 'Kazakhstan', 'Ordabasy', 'Corporation', 'signed', 'agreement', 'build', 'plant', 'Astana', 'produce', 'car', 'tires', '', 'Ordabasy', 'chairman', 'Dinmukhamet', 'Idrisov', 'said', 'press', 'conference', '']
# Sentence after removing stopwords: ['At', 'seminar', '', 'memorandum', 'understanding', 'cooperation', 'signed', 'Finnish', 'Kemira', 'Company', 'Vietnam', 'National', 'Chemical', 'Corporation', '']
# Sentence after removing stopwords: ['', 'The', 'priority', '2009', 'strengthen', 'company', 'balance', 'sheet', 'increase', 'cash', 'flow', '', '', 'CEO', 'Hannu', 'Krook', 'said', '']
# Sentence after removing stopwords: ['The', 'economic', 'occupancy', 'rate', 'Sponda', 'property', 'portfolio', 'rose', '912', '', '888', '', '2006', '']
# Sentence after removing stopwords: ['The', 'Ministry', 'Water', 'Tanzania', 'awarded', 'Poyry', 'water', 'sanitation', 'engineering', 'assignment', 'rehabilitation', 'extension', 'water', 'supply', 'sanitation', 'infrastructure', 'Bukoba', 'Musoma', '', 'situated', 'Lake', 'Victoria', 'northern', 'Tanzania', '']
# Sentence after removing stopwords: ['Nokia', 'bought', 'Chicagobased', 'Navteq', '2008', '', 'acquiring', 'maps', 'database', 'compete', 'Google', 'maps', 'well', 'navigation', 'device', 'companies', 'TomTom', 'NV', 'Garmin', 'Ltd', '']
# Sentence after removing stopwords: ['Uponor', 'made', 'operating', 'profit', 'EUR', '1510', 'mn', '', 'EUR', '1437', 'mn', '', 'made', '2007', 'record', 'year', '']
# Sentence after removing stopwords: ['It', 'also', 'strengthen', 'Ruukki', 'offshore', 'business', '']
# Sentence after removing stopwords: ['There', 'recovery', 'base', 'metals', 'prices', 'increased', 'demand', 'metals', 'China', '', 'however', '']
# Sentence after removing stopwords: ['Finnish', 'GeoSentric', '', 'developer', 'provider', 'solutions', '', 'products', '', 'technologies', 'location', 'based', 'services', '', 'preliminary', 'agreed', 'EUR', '6mn', 'shortterm', 'funding', 'leading', 'investor', '']
# Sentence after removing stopwords: ['', 'UPM', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', '', 'efficiency', 'operations', 'improved', '', '', 'Chief', 'Executive', 'Jussi', 'Pesonen', 'said', '']
# Sentence after removing stopwords: ['In', 'end', '2006', '', 'number', 'outlets', 'rise', '6070', '']
# Sentence after removing stopwords: ['Kesko', 'car', 'import', 'retailing', 'business', '', 'VVAuto', '', 'saw', 'sales', 'grow', '171', 'pct', '']
# Sentence after removing stopwords: ['I', 'looking', 'forward', 'contribute', 'SRV', 'success', 'competence', '', '', 'says', 'Taneli', 'Hassinen', '']
# Sentence after removing stopwords: ['It', 'combines', 'perfect', 'price', 'performance', 'sophisticated', 'management', 'facilities', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'company', 'net', 'profit', 'rose', '114', '', 'year', '822', 'million', 'euros', '2005', 'sales', '6865', 'million', 'euros', '', '138', '', 'year', '', 'company', 'said', 'earlier', '']
# Sentence after removing stopwords: ['We', 'also', 'strengthen', 'existing', 'partnership', 'Cybercom', '', '', 'says', 'Teleste', 'CTO', 'Esko', 'Myllyla', '']
# Sentence after removing stopwords: ['Nordea', 'sees', 'return', 'positive', 'growth', 'Baltic', 'countries', '2011', '']
# Sentence after removing stopwords: ['These', 'moderate', 'significant', 'changes', 'resulted', 'significant', '2432', '', 'reduction', 'estimated', 'CVD', 'risk', '']
# Sentence after removing stopwords: ['In', 'Sweden', '', 'operating', 'profit', 'period', 'review', 'totaled', 'EUR', '34', 'mn', '', '308', '', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['First', 'quarter', 'underlying', 'operating', 'profit', 'rose', '41', 'mln', 'eur', '33', 'mln', 'year', 'earlier', '']
# Sentence after removing stopwords: ['MANAVIGATORSeptember', '7', '', '2010Kemira', 'unveils', 'Indian', 'JV', 'IVRCL', 'Finnish', 'chemicals', 'group', 'Kemira', '', 'HEL', '', 'KRA1V', '', 'Tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'India', 'local', 'construction', 'firm', 'IVRCL', 'Infrastructure', 'Projects', 'Ltd', '', 'BOM', '530773', '', '']
# Sentence after removing stopwords: ['Alma', 'Media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously', '']
# Sentence after removing stopwords: ['Adanac', 'Molybdenum', 'Canada', 'ordered', 'grinding', 'technology', 'molybdenum', 'project', 'British', 'Columbia', '', 'Canada', '', 'Shalkiya', 'Zinc', 'Kazakhstan', 'awarded', 'contract', 'grinding', 'technology', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'EUR', '06', 'mn', '', 'loss', 'EUR', '19mn', 'year', 'earlier', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'property', 'portfolio', 'doubled', 'result', 'Kapiteeli', 'acquisition', 'totalled', 'EUR', '26862', '12597', 'million', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '135', 'mn', 'EUR', '97', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['The', 'soapstone', 'deposits', 'Medvezhyegorsk', 'area', 'expected', 'increase', 'Tulikivi', 'current', 'reserves', 'considerably', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['The', 'company', 'estimates', 'net', 'sales', '2010', 'increase', 'considerably', '2009', 'operating', 'result', 'clearly', 'positive', '']
# Sentence after removing stopwords: ['', 'I', 'pleased', 'proud', 'performance', 'last', 'year', '', '', 'Chief', 'Executive', 'Juha', 'Rantanen', 'said', 'statement', '']
# Sentence after removing stopwords: ['This', 'acquisition', 'supports', 'strategy', 'close', 'customers', 'around', 'world', 'offering', 'equipment', 'related', 'services', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Oct', '31', '', '2008', '', 'Finnish', 'food', 'company', 'Raisio', 'Oyj', '', 'OMX', '', 'RAIVV', '', 'said', 'today', 'net', 'profit', 'jumped', 'EUR', '164', 'million', '', 'USD', '209', '', 'first', 'nine', 'months', '2008', 'EUR', '11', 'million', 'period', '2']
# Sentence after removing stopwords: ['This', 'second', 'successful', 'effort', 'financial', 'investor', 'year', '']
# Sentence after removing stopwords: ['', 'We', 'feeling', 'quite', 'positive', 'region', 'whole', '']
# Sentence after removing stopwords: ['Its', 'main', 'business', 'area', '', 'Glass', 'Machinery', 'Group', 'Glaston', 'Technologies', '', 'global', 'market', 'leader', 'glass', 'processing', 'machines', '']
# Sentence after removing stopwords: ['TeliaSonera', 'said', '', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', '', 'Nepal', 'population', '']
# Sentence after removing stopwords: ['India', 'trade', 'Russia', 'currently', 'stands', 'four', 'billion', 'dollars', '', 'growing', '96', 'per', 'cent', 'fiscal', '2007', '']
# Sentence after removing stopwords: ['This', 'bring', 'cost', 'savings', 'EUR', '3mn', 'year', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Nokian', 'Tyres', 'reported', 'fourth', 'quarter', 'pretax', 'profit', '615', 'mln', 'eur', '', '486', 'mln', 'back', 'strong', 'sales', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', 'EUR', '203', 'mn', 'EUR', '114', 'mn', '']
# Sentence after removing stopwords: ['', 'Beyond', 'improved', 'voice', 'capabilities', '', 'customers', 'streamlined', 'way', 'comply', 'recalls', 'traceability', 'requirements', '', 'providing', 'competitive', 'advantage', '']
# Sentence after removing stopwords: ['Actions', 'improve', 'operational', 'efficiency', 'adjust', 'operations', 'expected', 'deliver', 'annualised', 'permanent', 'cost', 'savings', 'around', 'EUR', '45', 'million', 'effected', 'mostly', 'first', 'half', '2010', '']
# Sentence after removing stopwords: ['EPS', 'grew', '004', 'eur', '002', 'eur', '']
# Sentence after removing stopwords: ['The', 'EBITDA', 'EUR116m', 'compared', 'EUR115m', '', 'corresponding', 'EBITDA', 'margin', '33', '', '']
# Sentence after removing stopwords: ['Incap', 'Lankapaja', 'aim', 'enter', 'actual', 'agreement', 'transfer', 'sheetmetal', 'production', 'buyer', 'February', 'order', 'complete', 'transfer', '1', 'March', '2011', '']
# Sentence after removing stopwords: ['Revenue', 'grew', '2', 'percent', '', 'x20ac', '580', 'million', '', '743', 'million', '', '', 'x20ac', '569', 'million', '']
# Sentence after removing stopwords: ['The', 'company', 'feels', 'leases', 'prime', 'locations', 'due', 'several', 'producing', 'formations', 'immediate', 'area', '']
# Sentence after removing stopwords: ['Finnish', 'investment', 'group', 'Panostaja', 'Oyj', 'said', 'net', 'profit', 'went', '86', 'mln', 'euro', '', '114', 'mln', 'fiscal', '200506', '', 'ended', 'October', '31', '', '2006', '', '28', 'mln', 'euro', '', '37', 'mln', 'period', 'fiscal', '200405', '']
# Sentence after removing stopwords: ['Exports', 'accounted', '654', '', 'net', 'sales', '', 'representing', 'time', 'record', 'company', '']
# Sentence after removing stopwords: ['', 'Our', 'customer', 'satisfied', 'Basware', 'Invoice', 'Automation', 'solution', 'extends', 'implementation', 'new', 'geographies', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['Demand', 'seems', 'hit', 'bottom', '', 'signs', 'improvement', 'seen', '']
# Sentence after removing stopwords: ['Finnish', 'Ahlstrom', 'Corporation', 'ordered', 'key', 'production', 'equipment', 'new', 'glass', 'nonwovens', 'production', 'line', 'Russian', 'Tver', 'Mill', 'Finnish', 'Vaahto', 'Pulp', '', 'Paper', 'Machinery', '', 'part', 'Vaahto', 'Group', '', '']
# Sentence after removing stopwords: ['The', 'company', 'expects', 'net', 'sales', '2008', 'increase', '510', '', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'Bank', 'land', 'reports', 'operating', 'profit', 'rose', 'EUR', '213', 'mn', 'second', 'quarter', '2009', 'EUR', '61', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['Sanoma', 'Magazines', 'Finland', 'net', 'sales', 'grew', 'EUR', '1401', 'mn', 'EUR', '1318', 'mn', '']
# Sentence after removing stopwords: ['Comparable', 'net', 'sales', 'expected', 'increase', '10', '', '2008', '', 'line', 'group', 'target', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'components', 'supplier', 'Componenta', 'Oyj', 'said', 'net', 'profit', 'went', '35', 'mln', 'euro', '', '45', 'mln', '2006', '22', 'mln', 'euro', '', '28', 'mln', '2005', '']
# Sentence after removing stopwords: ['It', 'also', 'said', 'third', 'quarter', 'diluted', 'EPS', 'came', '034', 'eur', 'compared', '016', 'eur', 'quarter', 'year', 'ago', '']
# Sentence after removing stopwords: ['Its', 'market', 'share', 'widened', '4851', 'percent', '4831', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Satama', 'net', 'sales', 'would', 'higher', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'financial', 'group', 'Aktia', 'reports', 'operating', 'profit', 'EUR', '444', 'mn', 'JanuarySeptember', '2009', '', 'EUR', '373', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['Cargo', 'volume', 'grew', '7', '', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'expected', 'improve', 'access', 'chrome', 'ore', 'resources', 'Turkey', '']
# Sentence after removing stopwords: ['Kaido', 'Kaare', '', 'general', 'director', 'Atria', 'Eesti', '', 'says', 'company', 'investments', 'upgrade', 'pig', 'farms', 'surpass', 'EEK', '150mn', 'EUR', '959', 'mn', 'USD', '1419', 'mn', 'past', 'years', '']
# Sentence after removing stopwords: ['Lithuanian', 'beer', 'makers', 'sold', '25688', 'million', 'liters', 'beer', '2005', '', 'rise', '45', 'per', 'cent', 'yearearlier', 'figure', '24592', 'million', 'liters', '']
# Sentence after removing stopwords: ['The', 'company', 'order', 'book', 'stood', '15', 'bln', 'euro', '', '22', 'bln', 'September', '30', '', '2007', '', '242', 'pct', 'year', '', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '', '5343', 'mln', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totaled', 'EUR', '55', 'mn', '', 'EUR', '07', 'mn', '']
# Sentence after removing stopwords: ['The', 'services', 'also', 'give', 'supplier', 'opportunity', 'keyin', 'invoices', '', 'receive', 'orders', 'electronically', '', 'send', 'order', 'confirmations', 'upload', 'create', 'electronic', 'catalogues', '']
# Sentence after removing stopwords: ['The', 'energyefficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'stateoftheart', 'technology', '']
# Sentence after removing stopwords: ['', 'Following', 'last', 'year', 'good', 'profit', 'development', '', 'entered', 'current', 'year', 'good', 'position', '']
# Sentence after removing stopwords: ['According', 'report', 'Neomarkka', '', 'Kuitu', 'Finland', 'customers', 'interested', 'buying', 'company', 'products', 'restarts', 'production', '']
# Sentence after removing stopwords: ['', 'The', 'margarine', 'business', 'put', 'good', 'shape', 'last', 'two', 'years', '', 'making', 'natural', 'addition', 'Bunge', '', 'looking', 'leverage', 'position', 'Central', 'Northern', 'European', 'markets', '', '', 'Raisio', 'CEO', 'Matti', 'Rihko', 'said', 'statement', '']
# Sentence after removing stopwords: ['The', 'Brazilian', 'unit', 'Finnish', 'security', 'solutions', 'provider', 'FSecure', 'signed', '1500', 'new', 'clients', 'last', 'year', '', 'online', 'news', 'source', 'Reseller', 'Web', 'quoted', 'division', 'commercial', 'director', '', 'Vladimir', 'Brando', '', 'saying', '']
# Sentence after removing stopwords: ['Unit', 'costs', 'flight', 'operations', 'fell', '64', 'percent', '']
# Sentence after removing stopwords: ['The', 'respondents', 'praised', 'Finnair', 'reliability', '', 'Finnishness', '', 'understanding', 'target', 'group', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['It', 'leading', 'private', 'road', 'ambulance', 'service', 'company', 'Finland', '']
# Sentence after removing stopwords: ['In', 'second', 'quarter', '2010', '', 'Raute', 'net', 'loss', 'narrowed', 'EUR', '123000', 'EUR', '15', 'million', 'period', '2009', '']
# Sentence after removing stopwords: ['3', 'January', '2011', '', 'Finnish', 'flag', 'carrier', 'Finnair', 'Oyj', '', 'HEL', '', 'FIA1S', '', 'said', 'today', 'sealed', 'nineyear', 'sale', 'leaseback', 'agreement', 'newest', 'Airbus', 'A330', 'aircraft', 'syndication', 'Japanese', 'operating', 'lease', 'market', '']
# Sentence after removing stopwords: ['The', 'production', 'capacity', 'tripled', 'without', 'major', 'additional', 'investments', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Israeli', 'cable', 'network', 'operator', 'HOT', 'Telecom', 'chosen', 'Teleste', '', 'international', 'technology', 'group', '', 'exclusive', 'provider', 'FTTx', 'equipment', 'Israel', '', 'according', 'Teleste', 'today', '']
# Sentence after removing stopwords: ['The', 'company', 'aims', 'maintain', 'trend', 'profitability', 'current', 'year', '']
# Sentence after removing stopwords: ['The', 'terms', 'financing', 'approved', 'Annual', 'General', 'Meeting', 'Company', 'held', 'June', '30', '', '2010', '']
# Sentence after removing stopwords: ['The', 'refining', 'margin', 'year', '', '1339', '', 'bbl', '', 'compared', '', '1046', '', 'bbl', 'prior', 'year', '']
# Sentence after removing stopwords: ['Altimo', 'TeliaSonera', 'said', 'yesterday', 'Usmanov', 'would', 'welcome', 'join', 'new', 'company', '']
# Sentence after removing stopwords: ['With', 'appointment', 'Kaupthing', 'Bank', 'aims', 'coordinate', 'Capital', 'Markets', 'activities', 'within', 'Group', 'improve', 'overall', 'service', 'clients', '']
# Sentence after removing stopwords: ['EBIT', 'excluding', 'nonrecurring', 'items', 'estimated', 'increase', '2009', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'supply', 'WCDMA', '3GHSPA', 'radio', 'network', '', 'including', 'modular', '', 'high', 'capacity', 'Nokia', 'Flexi', 'WCDMA', 'base', 'station', 'East', 'Java', '', 'Bali', '', 'Sumatra', 'Batam', '']
# Sentence after removing stopwords: ['Brazilian', 'mobile', 'player', 'Telemig', 'Celular', 'yesterday', 'announced', 'selected', 'Finnish', 'software', 'developer', 'Tecnomen', 'Oyj', 'expand', 'prepaid', 'billing', 'system', '']
# Sentence after removing stopwords: ['Finnish', 'forest', 'machinery', 'manufacturer', 'Ponsse', 'agreed', 'Volvo', 'start', 'cooperation', 'Latin', 'America', '']
# Sentence after removing stopwords: ['The', 'divestment', 'Raisio', 'margarine', 'business', 'May', '2009', 'gave', 'company', 'clearer', 'focus', 'grainbased', 'products', '']
# Sentence after removing stopwords: ['TeliaSonera', 'secured', 'deliveries', '4G', 'modems', 'support', '3G', '2G', 'second', 'quarter', '2010', '']
# Sentence after removing stopwords: ['Mobile', 'phone', 'shipments', 'jumped', '26', 'percent', 'almost', '112', 'million', 'units', '', 'Finnish', 'company', 'global', 'market', 'share', 'rose', '39', 'percent', '36', 'percent', '']
# Sentence after removing stopwords: ['Finnish', 'elevators', 'escalators', 'maker', 'KONE', 'Corporation', 'said', 'Tuesday', '', '18', 'March', '', 'received', 'major', 'order', 'Sir', 'Robert', 'McAlpine', 'supply', 'elevators', 'escalators', 'Watermark', 'Place', 'project', 'City', 'London', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '830', 'mn', '', 'EUR', '235', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['At', 'first', 'contract', 'envisaged', 'construction', 'three', 'ferryboats', 'option', 'two', 'units', '', 'confirmed', 'total', 'value', '500', 'mln', 'euro', '', '', '6458', 'mln', '', '']
# Sentence after removing stopwords: ['', 'The', 'Government', 'professional', 'approach', 'assessing', 'offer', '']
# Sentence after removing stopwords: ['Kone', 'net', 'sales', 'rose', '14', '', 'yearonyear', 'first', 'nine', 'months', '2008', '']
# Sentence after removing stopwords: ['Nyrstar', 'also', 'agreed', 'supply', 'Talvivaara', '150000', 'tonnes', 'sulphuric', 'acid', 'per', 'annum', 'use', 'Talvivaara', 'leaching', 'process', 'period', 'supply', 'zinc', 'concentrate', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'move', '', 'says', 'Morna', 'Cowie', '', 'coowner', '', '', '', 'double', 'size', 'current', 'shop', 'lovely', 'feel', '', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', 'net', 'profit', 'rose', '261', 'mln', 'euro', '', '', '359', 'mln', '', 'first', 'quarter', '2007', '53', 'mln', 'euro', '', '', '73', 'mln', '', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['Sales', 'rose', '10', 'pct', '566', 'mln', 'eur', 'back', 'strong', 'volume', 'favourable', 'currency', 'effects', '']
# Sentence after removing stopwords: ['', 'We', 'lowest', 'bidders', 'final', 'approval', 'awaited', '', '']
# Sentence after removing stopwords: ['The', 'transactions', 'would', 'increase', 'earnings', 'per', 'share', 'first', 'quarter', 'EUR0', '28', '']
# Sentence after removing stopwords: ['Xerox', 'Stora', 'Enso', 'teamed', 'tailor', 'iGen3', 'shortrun', '', 'ondemand', 'packaging', 'market', '']
# Sentence after removing stopwords: ['He', 'believes', 'soyoats', 'good', 'chance', 'entering', 'UK', 'market', '']
# Sentence after removing stopwords: ['The', 'parties', 'agreed', 'negotiate', 'definitive', 'distribution', 'license', 'agreements', 'end', 'June', '2010', '']
# Sentence after removing stopwords: ['We', 'pleased', 'fine', 'cooperation', 'two', 'countries', 'recent', 'times', '', 'said', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'saw', 'net', 'profit', 'jump', 'EUR2', '1', 'last', 'quarter', '2010', 'EUR995', '000', 'period', '2009', '']
# Sentence after removing stopwords: ['New', 'product', 'launches', 'Finland', 'double', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'Kalmar', 'received', 'significant', 'order', 'US', 'Department', 'Defense', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '278', 'mn', 'EUR', '175', 'mn', '2008', '']
# Sentence after removing stopwords: ['Airvana', 'UMTS', 'Home', 'Base', 'Station', 'femto', 'cell', 'uses', 'softwarebased', 'functionality', 'offtheshelf', 'silicon', 'accelerate', 'feature', 'development', 'reduce', 'product', 'cost', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '368', 'EUR', '050', '']
# Sentence after removing stopwords: ['Sales', 'security', 'system', 'packaging', 'increased', 'slightly', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'Asian', 'plants', 'grew', 'markedly', '']
# Sentence after removing stopwords: ['The', 'bank', 'sees', 'potential', 'Getinge', 'share', 'rise', '']
# Sentence after removing stopwords: ['Net', 'sales', 'went', '1', '', 'yearonyear', 'EUR', '29', 'million', '', 'affected', 'business', 'acquisitions', '', 'realized', 'previous', 'financial', 'period', '', 'effect', 'EUR', '51', 'million', 'review', 'period', '']
# Sentence after removing stopwords: ['21', 'October', '2010', '', 'Finnish', 'fishing', 'tackle', 'company', 'Rapala', 'VMC', 'Corp', '', 'HEL', '', 'RAP1V', '', 'said', 'today', 'net', 'profit', 'rose', 'EUR18', '9', 'first', 'nine', 'months', '2010', 'EUR15', '1', 'period', 'year', 'earlier', '']
# Sentence after removing stopwords: ['OUTOTEC', 'OYJ', 'PRESS', 'RELEASE', 'DECEMBER', '4', '', '2009', '1030', 'AM', 'Outotec', 'establishes', 'new', 'subsidiary', 'Kolkata', 'Outotec', 'established', 'subsidiary', 'India', 'order', 'better', 'serve', 'Indian', 'customers', 'increase', 'business', 'growing', 'Indian', 'market', '']
# Sentence after removing stopwords: ['In', 'AsiaPacific', 'region', '', 'Visa', 'Wave', 'available', 'Malaysia', '', 'Taiwan', 'South', 'Korea', 'expanded', 'Japan', 'Southeast', 'Asia', 'year', '', 'Jung', 'added', '']
# Sentence after removing stopwords: ['The', 'cooperation', 'double', 'The', 'Switch', 'converter', 'capacity', '']
# Sentence after removing stopwords: ['Luxembourgregistered', 'investment', 'fund', 'Amber', 'Trust', 'II', 'final', 'approval', 'Lithuania', 'Competition', 'Council', 'acquire', '296', 'percent', 'Sanitas', '', 'country', 'largest', 'pharmaceutical', 'producer', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'EUR', '114', 'mn', '', 'EUR', '75', 'mn', '']
# Sentence after removing stopwords: ['1', 'November', '2010', '', 'Finnish', 'textile', 'clothing', 'company', 'Marimekko', 'Oyj', '', 'HEL', '', 'MMO1V', '', 'announced', 'Friday', 'opening', 'first', 'concept', 'store', 'Seoul', 'cooperation', 'Japanese', 'sector', 'player', 'Look', 'Inc', '', 'TYO', '', '8029', '', '']
# Sentence after removing stopwords: ['All', 'Raisio', 'divisions', 'recorded', 'operating', 'profit', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'threemonth', 'period', 'increased', 'EUR1', '2', '', 'revenue', 'increased', 'EUR20', '2', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['The', 'solutions', 'used', 'upgrading', 'networks', 'Russian', 'MSO', '37', 'different', 'cities', 'Russia', '']
# Sentence after removing stopwords: ['In', 'JulySeptember', '2008', '', 'YIT', 'net', 'sales', 'increased', 'EUR', '9708', 'mn', '', 'compared', 'EUR', '9068', 'mn', 'corresponding', 'period', '2007', '']
# Sentence after removing stopwords: ['', 'The', 'acquisition', 'Sampo', 'Bank', 'makes', 'strategic', 'sense', 'DB', '', '', 'says', 'Lindsey', 'Liddell', '', 'director', 'Fitch', 'Ratings', 'Financial', 'Institutions', 'Group', '']
# Sentence after removing stopwords: ['In', '2007', '', 'Marimekko', 'also', 'opened', 'concept', 'stores', 'Yokohama', 'Nagoya', '', 'central', 'Japan', '', 'Silver', 'Spring', 'metropolitan', 'Washington', 'DC', '', 'USA', '', 'Graz', '', 'central', 'Austria', '', 'Aalborg', '', 'northern', 'Denmark', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'investment', 'properties', 'totalled', 'EUR', '22999', 'mn', '', 'compared', 'EUR', '22295', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['The', 'agreement', 'strengthens', 'longterm', 'partnership', 'Nokia', 'Siemens', 'Networks', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '5mn', 'EUR', '28', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'stock', 'new', 'machines', 'reasonably', 'small', 'new', 'orders', 'bring', 'work', '']
# Sentence after removing stopwords: ['The', 'third', 'order', 'awarded', 'Outokumpu', 'Technology', 'Shalkiya', 'Zinc', 'Kazakhstan', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['LONDON', 'MarketWatch', '', 'Nokia', 'nok', 'said', 'fiveyear', 'services', 'contract', 'run', 'Hutchison', 'Essar', 'network', 'operations', 'nine', 'locations', 'India', '']
# Sentence after removing stopwords: ['Outotec', 'net', 'profit', 'second', 'quarter', '2007', 'jumped', '168', 'mln', 'euro', '', '', '231', 'mln', '', '46', 'mln', 'euro', '', '', '63', 'mln', '', 'year', 'ago', '']
# Sentence after removing stopwords: ['Industry', 'Investment', 'interested', 'Glaston', 'solar', 'energy', 'projects', '']
# Sentence after removing stopwords: ['planning', 'expand', 'product', 'portfolio', 'harbor', 'segment', '', 'chief', 'executive', 'Pekka', 'Lundmark', 'told', 'Financial', 'Times', 'Deutschland', '']
# Sentence after removing stopwords: ['The', 'Lithuanian', 'beer', 'market', 'made', '1441', 'million', 'liters', 'January', '', 'rise', '08', 'percent', 'yearearlier', 'figure', '', 'Lithuanian', 'Brewers', '', 'Association', 'reporting', 'citing', 'results', 'members', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'company', 'operating', 'profit', 'grew', '432', '', 'EUR', '6', 'million', '']
# Sentence after removing stopwords: ['According', 'company', '', 'operating', 'profit', '', 'excluding', 'nonrecurring', 'items', '', 'fourth', 'quarter', '2009', 'significantly', 'better', 'expected', '', 'also', 'better', 'figures', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'company', 'established', '3G', 'base', 'station', '17000', 'feet', 'foot', 'Mount', 'Everest', 'enable', 'mountain', 'climbers', '29035foot', 'summit', 'surf', 'Internet', 'even', 'send', 'videos', 'exploits', '']
# Sentence after removing stopwords: ['For', 'Telenor', '', 'three', 'half', 'year', 'contract', 'worth', 'estimated', '126', 'YIT', 'chosen', 'Telenor', 'Elisa', 'principal', 'suppliers', 'ICT', 'solutions', 'Norway', '', 'Sweden', '', 'Denmark', 'Finland', '']
# Sentence after removing stopwords: ['Cooper', 'SH', '', 'UK', 'distributor', 'lift', 'equipment', 'manufacturer', 'Konecranes', '', 'fiveyear', 'deal', 'involves', 'low', 'maintenance', 'fuel', 'saving', 'technologies', '']
# Sentence after removing stopwords: ['Affecto', 'expects', 'net', 'sales', 'whole', '2010', 'increase', '2009', 'level', 'reached', 'EUR', '103', 'million', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'awarded', 'significant', 'order', 'total', '292', 'Hiab', 'loader', 'cranes', 'BAE', 'Systems', 'US', '']
# Sentence after removing stopwords: ['According', 'ARehu', 'Managing', 'Director', '', 'Jouko', 'Lahtinen', '', 'project', 'stabilise', 'costs', 'improve', 'supply', 'security', '']
# Sentence after removing stopwords: ['Acquisitions', 'made', 'businesses', 'well', 'integrated', '']
# Sentence after removing stopwords: ['', 'Our', 'design', 'team', 'long', 'admired', 'Marimekko', 'vivid', 'patterns', 'colors', '']
# Sentence after removing stopwords: ['In', 'Middle', 'East', '', 'North', 'Africa', '', 'Tecnotree', 'grown', 'considerably', 'recent', 'years', '']
# Sentence after removing stopwords: ['The', 'company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230000', 'tonnes', 'copper', '']
# Sentence after removing stopwords: ['SvyturysUtenos', 'Alus', '', 'controlled', 'Nordic', 'group', 'Baltic', 'Beverages', 'Holding', '', 'BBH', '', '', 'posted', '47percent', 'growth', 'beer', 'sales', 'JanuaryMay', '4622', 'million', 'litres', '']
# Sentence after removing stopwords: ['It', 'also', 'turned', 'earnings', 'per', 'share', '', 'EPS', '', 'EUR', '044', 'versus', 'loss', 'per', 'share', 'EUR', '226', '']
# Sentence after removing stopwords: ['Sony', 'Ericsson', 'Nokia', 'dominated', 'list', 'bestselling', 'handsets', 'five', 'models', '']
# Sentence after removing stopwords: ['However', '', 'net', 'sales', '2010', 'seen', 'grown', 'EUR598', '3', 'EUR582', '3', '2009', '']
# Sentence after removing stopwords: ['Again', '', 'significant', 'sales', 'increase', '186', '', 'Russia', '']
# Sentence after removing stopwords: ['Ixonos', 'estimates', 'hire', '20', 'specialists', 'mechanical', 'engineering', '', 'electronics', 'design', '', 'RD', 'new', 'unit', 'Jyvaeskylae', 'end', '2009', '']
# Sentence after removing stopwords: ['Both', 'operating', 'profit', 'net', 'sales', '12month', 'period', 'increased', '', 'respectively', 'EUR10', '5', 'EUR28', '8', '', 'compared', 'financial', 'year', '2004', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['Metso', 'supply', 'equipment', 'two', 'process', 'lines', 'Northland', 'Resources', '', 'new', 'Kaunisvaara', 'iron', 'ore', 'project', 'Sweden', 'exploits', 'Tapuli', 'Sahavaara', 'iron', 'ore', 'deposits', '']
# Sentence after removing stopwords: ['More', 'staff', 'recruited', 'Japan', 'complement', 'network', 'close', '50', 'service', 'locations', '20', 'countries', 'worldwide', '']
# Sentence after removing stopwords: ['Finnish', 'dental', 'care', 'group', 'Oral', 'Hammaslaakarit', 'Oyj', 'posted', 'total', 'net', 'profit', '849000', 'euro', '', '11', 'mln', 'first', 'nine', 'months', '2006', 'versus', 'net', 'loss', '331000', 'euro', '', '421000', 'period', '2005', '']
# Sentence after removing stopwords: ['In', 'addition', 'deal', 'includes', 'call', 'option', 'enable', 'Maritim', 'Food', 'AS', 'increase', 'holding', 'Sandanger', 'AS', '51', '', 'future', '']
# Sentence after removing stopwords: ['Finnish', 'steel', 'maker', 'Rautaruukki', 'Oyj', '', 'Ruukki', '', 'said', 'July', '7', '', '2008', '90', 'mln', 'euro', '', '', '141', 'mln', '', 'contract', 'supply', 'install', 'steel', 'superstructures', 'Partihallsforbindelsen', 'bridge', 'project', 'Gothenburg', '', 'western', 'Sweden', '']
# Sentence after removing stopwords: ['Sales', 'clothing', 'developed', 'best', '']
# Sentence after removing stopwords: ['Profit', 'period', 'totaled', 'EUR', '394', 'mn', '', 'EUR', '339', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['Other', 'carriers', 'handset', 'makers', 'spin', 'positive', 'event', 'raise', 'interest', 'higherend', 'phones', 'pricier', 'data', 'plans', '']
# Sentence after removing stopwords: ['Shareholders', 'Rakvere', 'Lihakombinaat', 'decided', 'favor', 'buyout', 'minority', 'shares', 'midJuly', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'immediate', 'positive', 'impact', 'Aspocomp', 'financial', 'result', '']
# Sentence after removing stopwords: ['Furthermore', '', 'efficiency', 'improvement', 'measures', 'initiated', 'earlier', 'bearing', 'fruit', '', '', 'CEO', 'Jan', 'Lang', 'said', '']
# Sentence after removing stopwords: ['Having', 'China', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', '', 'also', 'strengthen', 'capability', 'offer', 'industryleading', 'products', 'customers', 'China', '', '']
# Sentence after removing stopwords: ['', 'Demand', 'sports', 'equipment', 'good', '2005', '']
# Sentence after removing stopwords: ['SOUTHFIELD', '', 'Mich', '', 'Central', 'Corporate', 'Credit', 'Union', 'distribute', 'patronage', 'dividends', 'members', 'waiving', 'service', 'fees', 'incurred', 'months', 'July', 'November', '2008', '', 'tune', 'estimated', '', '1', 'million', '']
# Sentence after removing stopwords: ['Revenue', 'July', 'September', 'grew', '14', 'percent', '', 'EURO', '', '467', 'million', 'year', 'earlier', '', 'company', 'said', 'Thursday', '']
# Sentence after removing stopwords: ['Shares', 'Standard', 'Chartered', '', 'STAN', '', 'rose', '12', '', 'FTSE', '100', '', 'Royal', 'Bank', 'Scotland', '', 'RBS', '', 'shares', 'rose', '2', '', 'Barclays', 'shares', '', 'BARC', '', '', 'BCS', '', '17', '', '']
# Sentence after removing stopwords: ['The', 'German', 'company', 'also', 'signed', 'code', 'share', 'agreement', 'another', 'Oneworld', 'member', '', 'American', 'Airlines', 'Inc', '', 'part', 'USbased', 'AMR', 'Corp', '', 'NYSE', '', 'AMR', '', '']
# Sentence after removing stopwords: ['TietoEnator', 'uses', 'Nokia', 'Intellisync', 'Mobile', 'Suite', 'wireless', 'email', '', 'calendar', '', 'device', 'management', 'capabilities', '', 'company', 'extend', 'services', 'customers', '']
# Sentence after removing stopwords: ['Both', 'loans', 'used', 'finance', 'strategic', 'investments', 'shopping', 'center', 'redevelopment', 'projects', 'refinancing', 'maturing', 'debt', '']
# Sentence after removing stopwords: ['The', 'new', 'agreement', '', 'expands', 'longestablished', 'cooperation', 'companies', '', 'involves', 'transfer', 'certain', 'engineering', 'documentation', 'functions', 'Larox', 'Etteplan', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'said', 'Wednesday', 'net', 'profit', 'rocketed', 'EUR4', '8', '2010', 'EUR416', '000', '2009', 'lifted', 'dividend', 'proposal', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Jawad', 'Williams', 'scored', '23', 'points', 'impressive', 'debut', 'Jerusalem', '', 'Jason', 'Rich', 'adding', '18', 'Yuval', 'Naimi', 'chipping', '16', 'points', 'Hapoel', '', 'visits', 'yellowandblue', 'next', 'week', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Finnish', 'handling', 'systems', 'provider', 'Cargotec', 'Oyj', '', 'HEL', '', 'CGCBV', '', 'announced', 'Friday', 'orders', 'worth', 'EUR', '10', 'million', '', 'USD', '132', '', 'deliver', 'linkspans', 'Jordan', '', 'Morocco', 'Ireland', '']
# Sentence after removing stopwords: ['Nokian', 'Capacitors', '', 'equipment', 'used', 'raise', 'capacity', 'reliability', 'Indian', 'grid', '']
# Sentence after removing stopwords: ['Finnish', 'food', 'industry', 'companies', 'HK', 'Ruokatalo', 'Atria', 'form', 'joint', 'venture', 'company', 'called', 'LÆnsiKalkkuna', 'produce', 'turkey', 'meat', '']
# Sentence after removing stopwords: ['Sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season', '']
# Sentence after removing stopwords: ['Speaking', 'justdrinks', 'today', '', 'spokesperson', 'Olvi', 'said', '', '', 'We', 'performed', 'well', 'four', 'countries', 'operate', '', 'namely', '', 'Finland', '', 'Estonia', '', 'Latvia', 'Lithuania', '', '']
# Sentence after removing stopwords: ['TELE2', 'Affarsvarlden', 'gave', '', 'buy', '', 'recommendation', 'mobile', 'operator', 'Tele2', 'AB', 'share', 'price', 'target', '142', 'crowns', '', '', '2354', '', '1519', 'euro', '', '']
# Sentence after removing stopwords: ['Excluding', 'nonrecurring', 'items', '', 'pretax', 'profit', 'surged', '45', '', 'EUR80m', '']
# Sentence after removing stopwords: ['Finnish', 'P¦yry', 'awarded', 'engineering', 'contract', 'CFR', '', 'national', 'railway', 'company', 'Romania', '']
# Sentence after removing stopwords: ['The', 'airline', 'ordered', 'nine', 'Airbus', 'A350900', 'aircraft', 'deliveries', '2011', '', 'becomes', 'lead', 'airline', 'latest', 'variant', 'RollsRoyce', 'Trent', 'series', 'engines', '', 'called', '1700', '']
# ...
# Sentence after removing stopwords: ['', 'A', 'spokesperson', 'told', 'WWD', 'expect', '5050', 'mix', 'clothing', 'home', 'decor', '', '']
# Sentence after removing stopwords: ['Two', 'contracts', 'turntable', 'anode', 'vibrocompactors', 'delivered', 'Gansu', 'Hualu', 'Aluminum', 'Co', 'Ltd', 'another', 'unnamed', 'costumer', '']
# Sentence after removing stopwords: ['The', 'carrier', 'said', 'Area', 'travel', 'agency', 'sell', 'outlets', 'sister', 'chain', 'Suomen', 'Matkatoimisto', 'SMTand', 'use', 'remaining', 'bricksandmortar', 'presence', 'primarily', 'target', 'business', 'customers', 'going', 'forward', '']
# Sentence after removing stopwords: ['The', 'new', 'company', 'likely', 'hold', 'IPO', 'NYSE', 'another', 'international', 'stock', 'exchange', '', 'according', 'Altimo', 'manages', 'Alfa', 'Group', 'telecommunications', 'assets', 'TeliaSonera', 'agreement', '', 'published', 'website', 'US', 'Securities', 'Exchange', 'Commission', '']
# Sentence after removing stopwords: ['The', 'order', 'also', 'includes', 'startup', 'commissioning', 'services', '']
# Sentence after removing stopwords: ['The', 'challenge', 'company', '', 'however', '', 'finding', 'new', 'sources', 'raw', 'material', '', 'said', 'Risto', 'Rinne', '', 'CEO', 'Neste', 'Oil', '']
# Sentence after removing stopwords: ['Protalix', 'developing', 'genetically', 'engineered', 'proteins', 'plant', 'cells', '']
# Sentence after removing stopwords: ['It', 'grew', 'Finland', '', 'Norway', '', 'Denmark', 'Baltic', 'countries', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totaled', 'EUR', '186', 'mn', '83', '', 'net', 'sales', '']
# Sentence after removing stopwords: ['Citigroup', '', 'Inc', 'NYSE', '', 'C', '', 'Deutsche', 'Bank', 'NYSE', '', 'DB', 'Pohjola', 'Bank', 'lead', 'managers', 'sale', '']
# Sentence after removing stopwords: ['Medical', 'Devices', '', 'Russia', 'This', 'brandnew', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'medical', 'device', 'market', 'Russia', '']
# Sentence after removing stopwords: ['Also', '', 'sevenyear', 'historic', 'analysis', 'provided', 'markets', '']
# Sentence after removing stopwords: ['Fiskars', 'R', '', 'founded', '1649', '', 'one', 'oldest', 'companies', 'world', 'largest', 'manufacturer', 'lightweight', 'stainless', 'steel', 'scissors', 'US', '']
# Sentence after removing stopwords: ['In', '2007', '', 'Contempus', 'generated', 'revenue', 'NOK', '693', '', 'approx', '']
# Sentence after removing stopwords: ['According', 'FinnishRussian', 'Chamber', 'Commerce', '', 'major', 'construction', 'companies', 'Finland', 'operating', 'Russia', '']
# Sentence after removing stopwords: ['Tikkurila', 'Powder', 'Coatings', '50', 'employees', 'four', 'paint', 'plants', '', 'generated', 'revenues', 'EUR2', '4', 'USD3', '3', '2010', '']
# Sentence after removing stopwords: ['Neither', 'companies', 'use', 'genetically', 'engineered', 'soy', 'moment', '']
# Sentence after removing stopwords: ['The', 'Division', 'also', 'includes', 'joint', 'sales', '', 'marketing', 'controlling', 'functions', 'units', '']
# Sentence after removing stopwords: ['The', 'identity', 'buyer', 'yet', 'known', '']
# Sentence after removing stopwords: ['It', 'comes', 'complete', 'LCD', 'touch', 'screen', 'system', 'selection', 'chosen', 'function', 'prices', 'start', 'around', 'pounds', '4805', 'mark', '']
# Sentence after removing stopwords: ['CompaniesandMarketscom', 'provides', 'wide', 'range', 'research', 'reports', '', 'industry', 'statistics', 'competitive', 'intelligence', 'industrial', 'sector', '']
# Sentence after removing stopwords: ['However', '', 'production', 'almost', 'entirely', 'labor', 'intensive', 'based', 'small', 'investments', '']
# Sentence after removing stopwords: ['Mr', 'Koistinen', 'joins', 'Nokia', 'Siemens', 'Networks', 'held', 'various', 'senior', 'sales', 'management', 'business', 'development', 'positions', 'since', '1997', '']
# Sentence after removing stopwords: ['Finnish', 'consumers', 'prefer', 'buy', 'cheapest', 'beer', 'brand', '']
# Sentence after removing stopwords: ['SRV', 'also', 'build', 'aqua', 'park', 'wellness', 'area', '', 'restaurant', 'multifunctional', 'ice', 'arena', '']
# Sentence after removing stopwords: ['The', 'ecommerce', 'site', 'flagship', 'managed', 'Marimekko', 'North', 'America', 'Retail', 'LLC', '', 'subsidiary', 'established', 'US', 'last', 'year', '']
# Sentence after removing stopwords: ['The', 'product', 'range', 'includes', 'marinated', 'olives', '', 'cold', 'cuts', '', 'pates', '', 'example', '']
# Sentence after removing stopwords: ['After', 'buying', 'Eukor', 'Car', 'Carriers', '50', 'percent', 'stake', '', 'Grimaldi', 'Group', 'sole', 'owner', 'Swedish', 'rollon', '', 'rolloff', 'port', 'Wallhamn', '']
# Sentence after removing stopwords: ['BasWare', 'Invoice', 'Processing', '', 'BasWare', 'Contract', 'Matching', '', 'BasWare', 'Order', 'Matching', 'BasWare', 'KPI', 'Reporting', 'Tool', 'part', 'BasWare', 'Enterprise', 'Purchase', 'Pay', 'product', 'suite', '']
# Sentence after removing stopwords: ['The', 'net', 'sales', 'Healthcare', 'Trade', 'business', '2009', 'EUR', '1451', 'million', 'EUR', '1552', 'million', 'operating', 'profit', 'EUR', '89', 'million', 'EUR', '79', 'million', '']
# Sentence after removing stopwords: ['After', 'transaction', '', 'Tikkurila', 'powder', 'coatings', 'related', 'operations', '']
# Sentence after removing stopwords: ['In', '2008', '', 'AVC', 'Systemhaus', 'net', 'sales', 'EUR', '10', 'million', 'USD', '71', '']
# Sentence after removing stopwords: ['The', 'process', '', 'technology', '', 'project', 'management', '', 'basic', 'engineering', 'quality', 'assurance', 'within', 'Forest', 'Industry', 'consolidated', 'Vantaa', '', 'southern', 'Finland', '']
# Sentence after removing stopwords: ['The', 'Bank', 'land', 'acquired', 'private', 'banking', 'business', '', 'asset', 'management', '', 'share', 'brokerage', 'business', 'Kaupthing', 'Sweden', 'early', '2009', '']
# Sentence after removing stopwords: ['Swedish', 'Wallenberg', 'family', 'controlled', 'Investor', 'bought', 'large', 'stake', 'C', 'shares', 'Swedish', 'retail', 'bank', 'SEB', '']
# Sentence after removing stopwords: ['The', 'Segu', 'companies', 'PKC', 'Polish', 'unit', 'form', 'business', 'servicing', 'western', 'European', 'markets', '', 'annual', 'sales', 'hundred', 'million', '', '2500', 'employees', '', 'Finnish', 'company', 'CEO', '', 'Harri', 'Suutari', '', 'said', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'privacy', 'security', 'software', 'developer', 'Tectia', 'Oyj', '', 'HEL', '', 'TEC1V', '', 'said', 'Wednesday', 'set', 'two', 'strategic', 'business', 'units', '', 'managed', 'security', 'mobile', 'authentication', '']
# Sentence after removing stopwords: ['Mursula', 'said', 'tried', 'gather', 'macroeconomic', 'perspective', 'see', 'Malaysia', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafers', 'maker', 'Okmetic', 'Oyj', 'said', 'September', '17', '', '2008', 'invest', 'total', '15', 'mln', 'euro', '', '213', 'mln', 'sensor', 'wafer', 'business', '']
# Sentence after removing stopwords: ['Sunrise', 'Resources', 'operates', 'Russian', 'nearshore', 'development', 'markets', 'whollyowned', 'Russian', 'subsidiary', '80', '', 'personnel', 'Russia', '']
# Sentence after removing stopwords: ['Performance', 'based', 'values', 'sustainability', '']
# Sentence after removing stopwords: ['Under', 'agreement', 'Benefon', 'forthcoming', 'range', 'TWIG', 'integrated', 'GPS', 'navigation', 'mobile', 'phone', 'devices', 'use', 'jointly', 'developed', 'webbased', 'tracking', 'location', 'technology', '', 'consumer', 'commercial', 'applications', '']
# Sentence after removing stopwords: ['GeoSentric', 'acquiring', 'extra', 'financing', 'issuing', 'maximum', '220000', 'new', 'shares', 'convertible', 'bond', 'subscription', 'rights', '880000', 'shares', '', 'fully', 'subscribed', '']
# Sentence after removing stopwords: ['The', 'divested', 'activities', 'net', 'sales', 'EUR', '1451', 'million', '2009', 'operating', 'profit', 'EUR', '89', 'million', '']
# Sentence after removing stopwords: ['The', 'final', 'price', 'specified', '14', 'May', '2010', '', 'acquiring', 'company', 'said', '']
# Sentence after removing stopwords: ['Honkarakenne', 'customer', 'project', 'one', 'biggest', 'real', 'estate', 'companies', 'Kazakhstan', '', 'according', 'company', '']
# Sentence after removing stopwords: ['', 'These', 'patronage', 'refunds', 'reward', 'members', 'use', 'feebased', 'services', 'make', 'positive', 'contribution', 'CenCorp', 'operating', 'results', '', '', 'said', 'Bill', 'Walby', '', 'CenCorp', 'CEO', '']
# Sentence after removing stopwords: ['Shareholders', 'right', 'put', 'agenda', 'AGM', 'items', 'within', 'competence', 'general', 'meeting', '']
# Sentence after removing stopwords: ['The', 'front', 'surfaces', 'valve', 'plates', 'directed', 'towards', '']
# Sentence after removing stopwords: ['Subjectmatter', 'invention', 'furthermore', 'use', 'cyclone', 'separating', 'partly', 'molten', 'particles', '', '']
# Sentence after removing stopwords: ['The', 'dualfuel', 'engines', 'vessel', 'operate', 'liquefied', 'natural', 'gas', 'LNG', 'low', 'emissions', '']
# Sentence after removing stopwords: ['The', 'expansion', 'finalized', 'autumn', '2009', '']
# Sentence after removing stopwords: ['MetsaBotnia', 'sell', '821', '', 'stake', 'Uruguayan', 'companies', 'Metsaliitto', '', '55', '', '']
# Sentence after removing stopwords: ['Unit', 'prices', 'straddle', 'carriers', 'vary', 'EUR700', '000', 'EUR900', '000', '', 'company', 'added', '']
# Sentence after removing stopwords: ['The', 'company', 'board', 'directors', 'would', 'propose', 'dividend', 'EUR1', '00', 'per', 'share', '2005', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'Oct', '3', '', 'Markka', 'A', 'Oksanen', 'Harald', 'Kaaja', '', 'Helsinki', '', 'Finland', '', 'Juha', 'Salokannel', 'Kangasala', '', 'Finland', '', 'Arto', 'Palin', 'Viiala', '', 'Finland', '', 'developed', 'system', 'providing', 'communications', 'security', '']
# Sentence after removing stopwords: ['BG', 'Crane', 'strong', 'customer', 'base', 'onroad', 'load', 'handling', 'related', 'installation', 'service', 'businesses', '']
# Sentence after removing stopwords: ['Connectivity', 'Services', 'include', 'outsourced', 'Scan', 'Capture', 'transfers', 'paper', 'invoices', 'electronic', 'format', 'Basware', 'Business', 'Transactions', 'Service', 'enables', 'customer', 'receive', 'send', 'invoices', 'electronic', 'format', '']
# Sentence after removing stopwords: ['The', 'Extraordinary', 'General', 'Meeting', 'expected', 'take', 'place', 'later', '18', 'February', '2011', '']
# Sentence after removing stopwords: ['The', 'shares', 'subscribed', 'stock', 'options', 'registered', 'Trade', 'Register', '20', 'January', '2011', '', 'date', 'new', 'shares', 'establish', 'shareholder', 'rights', '']
# Sentence after removing stopwords: ['In', 'addition', 'verification', 'identity', 'digital', 'signatures', '', 'new', 'stateapproved', 'Mobile', 'ID', 'enables', 'cast', 'votes', 'elections', 'well', '']
# Sentence after removing stopwords: ['The', 'contract', 'includes', 'design', '', 'construction', '', 'delivery', 'equipment', '', 'installation', 'commissioning', '']
# Sentence after removing stopwords: ['The', 'total', 'restructuring', 'costs', 'expected', 'EUR', '30mn', '', 'EUR', '135', 'mn', 'booked', 'December', '2008', '']
# Sentence after removing stopwords: ['IonPhasE', 'second', 'major', 'owner', 'venture', 'capital', 'firm', 'Aura', 'Capital', '']
# Sentence after removing stopwords: ['Any', 'investment', 'investment', 'activity', 'communication', 'relates', 'available', 'relevant', 'persons', 'engaged', 'relevant', 'persons', '']
# Sentence after removing stopwords: ['Pharmaceuticals', '', 'Belgium', 'This', 'brandnew', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'pharmaceutical', 'market', 'Belgium', '']
# Sentence after removing stopwords: ['Risto', 'Jalo', '', 'chief', 'executive', 'Dormus', 'Print', 'also', 'owner', 'remainder', 'company', '', 'keep', 'position', 'acquisition', '']
# Sentence after removing stopwords: ['It', 'first', 'oil', 'company', 'join', 'RSPO', 'commits', 'fully', 'sustainable', 'sourcing', 'feedstocks', 'production', 'NExBTL', 'biodiesel', '', 'said', '']
# Sentence after removing stopwords: ['Sarantel', '', 'based', 'Wellingborough', '', 'UK', '', 'designs', 'highperformance', 'antennas', 'portable', 'wireless', 'devices', '']
# Sentence after removing stopwords: ['The', 'energy', 'shot', 'packed', '100millilitre', 'bag', 'screw', 'cap', '']
# Sentence after removing stopwords: ['Its', 'product', 'portfolio', 'comprises', 'harvesters', '', 'forwarders', '', 'harvester', 'heads', '', 'well', 'cranes', 'loaders', '']
# Sentence after removing stopwords: ['Remote', 'Phone', 'Management', 'demonstrates', 'SysOpen', 'Digia', 'unique', 'endtoend', 'offering', 'operators', '', 'handset', 'manufacturers', 'enterprise', 'customers', '']
# Sentence after removing stopwords: ['Mobile', 'data', 'transfer', 'expected', 'increase', 'explosively', 'LTE', 'era', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'expected', '2008', 'financial', 'performance', 'remain', 'level', '2008', '']
# Sentence after removing stopwords: ['These', 'module', 'products', 'available', 'trials', '3Q07', 'volume', 'deliveries', '4Q07', '']
# Sentence after removing stopwords: ['Glaston', 'share', 'GLA1V', 'listed', 'NASDAQ', 'OMX', 'Helsinki', '', 'Mid', 'Cap', 'List', '']
# Sentence after removing stopwords: ['A', 'Le', 'Coq', 'market', 'share', '413', 'percent', 'rival', 'beverage', 'group', 'Saku', '321', 'percent', '']
# Sentence after removing stopwords: ['The', 'business', 'idea', 'Budget', 'Sport', 'offer', 'customers', 'wide', 'range', 'highquality', 'sports', 'equipment', 'clothing', 'low', 'prices', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'talks', 'involved', 'Food', 'Ingredients', 'Divisions', '', 'well', 'group', 'service', 'functions', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'agreement', 'must', 'approved', 'Russian', 'competition', 'authorities', 'enters', 'force', '']
# Sentence after removing stopwords: ['Water', 'Treatment', 'Products', 'In', 'Australia', 'Today', '', 'Global', 'Research', '', 'Data', 'Services', 'going', 'publish', 'market', 'analysis', 'market', 'chemical', 'water', 'treatment', 'products', 'Australia', '']
# Sentence after removing stopwords: ['The', 'company', 'issue', 'inaugural', 'Eurobond', 'deal', 'near', 'future', 'subject', 'market', 'conditions', '']
# Sentence after removing stopwords: ['', 'That', 'high', 'figure', 'European', 'scale', '', '', 'Noop', 'said', '', 'recalling', 'however', 'also', 'includes', 'beer', 'bought', 'Finnish', 'tourists', '']
# Sentence after removing stopwords: ['The', 'aim', 'CEO', 'QA', 'sessions', 'give', 'clarity', 'information', '', 'made', 'public', 'already', 'earlier', '']
# Sentence after removing stopwords: ['These', 'sections', 'put', 'place', 'form', 'loadbearing', 'steel', 'structure', 'bridge', '', '', 'says', 'Sami', 'Eronen', '', 'Senior', 'Vice', 'President', '', 'Infrastructure', 'Northern', 'Europe', '', 'Ruukki', 'Construction', '']
# Sentence after removing stopwords: ['The', 'use', 'validation', 'rule', 'base', 'enables', 'verifying', 'processing', 'rule', 'bases', 'managed', 'different', 'administrators', 'fulfil', 'set', 'requirements', '']
# Sentence after removing stopwords: ['The', 'plant', 'collect', 'raw', 'material', 'Baltic', 'Sea', 'region', '']
# Sentence after removing stopwords: ['Yvonne', 'Jones', 'owner', 'Chameleon', 'Interiors', '']
# Sentence after removing stopwords: ['M2', 'Communications', 'disclaims', 'liability', 'information', 'provided', 'within', 'information', 'world', 'wide', 'web', '']

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive2=pd.DataFrame(sorted(positiveValues2.items(),key=lambda x:x[1],reverse=True))
df_negative2=pd.DataFrame(sorted(negativeValues2.items(),key=lambda x:x[1],reverse=True))
df_neutral2=pd.DataFrame(sorted(neutralValues2.items(),key=lambda x:x[1],reverse=True))

# %%
pd1bi=df_positive2[0][:10]
pd2bi=df_positive2[1][:10]

ned1bi=df_negative2[0][:10]
ned2bi=df_negative2[1][:10]

nud1bi=df_neutral2[0][:10]
nud2bi=df_neutral2[1][:10]

plt.figure(1,figsize=(16,4))

plt.bar(pd1bi,pd2bi, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-BIGRAM ANALYSIS")

plt.savefig("positive-bigram.png")
plt.show()

# %%
df_positive2.head(10)
# Out:
#            0    1
# 0             151
# 1  net sales   53
# 2        mn    50
# 3      2009    46
# 4      2010    41
# 5       said   40
# 6      euro    37
# 7      said    37
# 8      year    35
# 9    Finnish   35

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1bi,ned2bi, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-BIGRAM ANALYSIS")

plt.savefig("negative-bigram.png")
plt.show()

# %%
df_negative2.head(10)
# Out:
#                       0   1
# 0                        64
# 1                   mn   53
# 2                 2009   36
# 3                 2008   35
# 4              compared  32
# 5  corresponding period  30
# 6                   EUR  29
# 7                 2007   27
# 8            profit EUR  23
# 9          totalled EUR  20

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1bi,nud2bi, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-BIGRAM ANALYSIS")

plt.savefig("neutral-bigram.png")
plt.show()

# %%
df_neutral2.head(10)
# Out:
#              0    1
# 0               166
# 1     Finland    89
# 2  The company   83
# 3    net sales   57
# 4      Finland   46
# 5        said    45
# 6        2007    44
# 7        2009    44
# 8        2008    39
# 9      company   38

# %% [markdown]
# **Creating trigrams**

# %%
positiveValues3=defaultdict(int)
negativeValues3=defaultdict(int)
neutralValues3=defaultdict(int)
#get the count of every word in both the columns of df_train and df_test dataframes

# %%
#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="positive"
for text in df_train[df_train.sentiment=="positive"].news:
  for word in generate_N_grams(text,3):
    positiveValues3[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="negative"
for text in df_train[df_train.sentiment=="negative"].news:
  for word in generate_N_grams(text,3):
    negativeValues3[word]+=1

#get the count of every word in both the columns of df_train and df_test dataframes where sentiment="neutral"
for text in df_train[df_train.sentiment=="neutral"].news:
  for word in generate_N_grams(text,3):
    neutralValues3[word]+=1
# Out:
# Sentence after removing stopwords: ['Finnish', 'consumer', 'packaging', 'manufacturer', 'Huhtamaki', 'Oyj', 'said', 'swung', 'net', 'profit', '841', 'mln', 'euro', '', '1056', 'mln', 'first', 'nine', 'months', '2006', 'net', 'loss', '26', 'mln', 'euro', '', '33', 'mln', 'period', '2005', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'welcome', 'Elisa', 'Board', 'Directors', '', '', 'said', 'Garry', 'McGuire', '', 'CEO', 'RMG', 'Networks', '']
# Sentence after removing stopwords: ['com', '', 'constantly', 'planning', 'new', 'ways', 'serve', 'customers', 'online', 'comprehensive', 'basis', '', '', 'says', 'Matti', 'Leminen', '', 'President', 'Anttila', 'Oy', '']
# Sentence after removing stopwords: ['', 'The', 'stable', 'outlook', 'reflects', 'Nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', '', 'strong', 'cash', 'flow', 'generation', '', 'conservative', 'balance', 'sheet', '', '', 'said', 'Raab', '']
# Sentence after removing stopwords: ['In', 'first', 'quarter', '2010', '', 'marktomarket', 'result', 'pretax', 'profit', 'EUR', '133', 'million', 'versus', 'loss', 'EUR', '32', 'million', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Previously', 'company', 'estimated', 'operating', 'profit', 'reach', 'level', '2005', '']
# Sentence after removing stopwords: ['In', 'autumn', '', 'plans', 'expand', 'service', 'St', 'Petersburg', 'Moscow', 'launch', 'service', 'Yekaterinburg', '', 'Russia', '', 'flying', 'three', 'times', 'week', '']
# Sentence after removing stopwords: ['Upgrades', 'include', 'five', 'megapixel', 'camera', '', 'voice', 'control', '', 'looks', 'optical', 'mouse', 'instead', 'Dpad', '', 'upgrade', 'clickhappy', 'S60', 'needed', 'forever', '']
# Sentence after removing stopwords: ['In', 'fourth', 'quarter', '2009', '', 'Orion', 'net', 'profit', 'went', '338', '', 'yearonyear', 'EUR33m', '']
# Sentence after removing stopwords: ['As', 'result', '', 'distribution', 'companies', 'start', 'distribute', '', 'addition', 'current', 'product', 'offering', '', 'Shimano', 'reels', '', 'rods', 'Shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis', '']
# Sentence after removing stopwords: ['Rory', 'Fitzgerald', '', 'general', 'manager', '', 'operations', '', 'Bristol', 'Port', '', 'said', '', '', 'With', 'use', 'low', 'maintenance', 'technology', 'save', '30', 'per', 'cent', 'servicing', '', 'plus', 'load', 'sensing', 'hydraulics', 'save', 'us', 'extra', '15', '30', 'per', 'cent', 'fuel', 'consumption', '', '']
# Sentence after removing stopwords: ['', 'The', 'announced', 'investment', 'carmaker', 'Hyundai', 'example', 'sounds', 'optimistically', 'us', 'course', 'new', 'cars', 'mean', 'new', 'tires', '', '']
# Sentence after removing stopwords: ['According', 'Finnish', 'Aktia', 'Bank', 'Managing', 'Director', 'Jussi', 'Laitinen', '', 'bank', 'aim', 'triple', 'number', 'customers', 'Finland', 'next', 'five', 'years', '']
# Sentence after removing stopwords: ['Profit', 'taxes', 'period', 'EUR0', '9', '', 'EUR0', '01', 'last', 'year', '']
# Sentence after removing stopwords: ['The', 'Commission', 'applauded', 'applying', 'factbased', 'datadriven', 'approach', 'providing', 'clarity', 'future', 'petitions', '']
# Sentence after removing stopwords: ['Shares', 'Nokia', 'Corp', 'rose', 'Thursday', 'cell', 'phone', 'maker', 'said', 'thirdquarter', 'earnings', 'almost', 'doubled', 'share', 'global', 'handset', 'market', 'increased', '']
# Sentence after removing stopwords: ['Pretax', 'profit', 'rose', 'EUR', '06', 'mn', 'EUR', '04', 'mn', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Advertising', 'circulation', 'revenues', 'grew', '34', '', '04', '', '', 'respectively', '']
# Sentence after removing stopwords: ['According', 'CEO', 'Matti', 'Karppinen', '', 'Frozen', 'Foods', 'posted', 'good', 'result', '2010', '', '2009', '']
# Sentence after removing stopwords: ['BasWare', 'CEO', 'Ilkka', 'Sihvo', 'comments', 'conjunction', 'Interim', 'Report', '', '', 'As', 'whole', '', 'BasWare', 'succeeded', 'well', 'second', 'quarter', '2007', '']
# Sentence after removing stopwords: ['We', 'hope', 'increase', 'traffic', 'volumes', 'opening', 'Freight', 'One', 'Scandinavia', '', '']
# Sentence after removing stopwords: ['Neste', 'Oil', 'Corp', 'signed', 'longterm', 'procurement', 'contracts', 'Honkajoki', 'Oy', 'Findest', 'Protein', 'Oy', '', 'owned', 'Finnish', 'food', 'manufacturers', '', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'Neste', '200000', 'bcd', 'Porvoo', '', 'Finland', '', 'refinery', '']
# Sentence after removing stopwords: ['2010', '16', 'July', '2010', '', 'Finnish', 'steel', 'maker', 'Rautaruukki', 'Oyj', 'HEL', '', 'RTRKS', '', 'Ruukki', '', 'said', 'today', 'turned', 'net', 'profit', 'EUR20m', 'second', 'quarter', '2010', 'net', 'loss', 'EUR94m', 'corresponding', 'period', 'last', 'year', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '04', 'mn', '', 'operating', 'loss', 'EUR', '08', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', '27', '', 'EUR', '5798', 'mn', 'EUR', '4572', 'mn', '2006', '']
# Sentence after removing stopwords: ['', 'This', 'contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', '', 'oil', 'shale', 'processing', '']
# Sentence after removing stopwords: ['Nevertheless', '', 'Fitch', 'notes', 'business', 'fundamentals', 'three', 'banks', 'currently', 'remain', 'sound', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'Paper', 'awarded', 'contract', 'rebuild', 'Sabah', 'Forest', 'Industries', '', '', 'SFI', '', 'pulp', 'mill', 'Sabah', '', 'Malaysia', '']
# Sentence after removing stopwords: ['Finnish', 'Aldata', 'Solution', 'signed', 'contract', 'supply', 'GOLD', 'system', 'two', 'French', 'retail', 'chains', '']
# Sentence after removing stopwords: ['HELSINKI', 'Thomson', 'Financial', 'Kemira', 'GrowHow', 'swung', 'profit', 'first', 'quarter', 'earnings', 'improved', 'sales', '', 'especially', 'fertilizer', 'business', 'Europe', '', 'normally', 'stronger', 'first', 'quarter', '']
# Sentence after removing stopwords: ['Finnish', 'KCI', 'Konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'Indian', 'steel', 'producer', 'Bhushan', 'Steel', '', 'Strips', 'delivered', '2007', '']
# Sentence after removing stopwords: ['The', 'talks', 'aimed', 'restructuring', 'operations', 'cutting', 'costs', '']
# Sentence after removing stopwords: ['', 'In', 'terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', '', '', 'Chief', 'Executive', 'VeliMatti', 'Mattila', 'said', '']
# Sentence after removing stopwords: ['Uponor', 'improved', 'performance', 'spite', 'decrease', 'residential', 'construction', 'US', '']
# Sentence after removing stopwords: ['Both', 'operating', 'profit', 'net', 'sales', 'sixmonth', 'period', 'increased', '', 'respectively', 'EUR7', '5', 'EUR655', '5', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'Metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', '', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'Klabin', 'Tel\x97maco', 'Borba', 'mill', 'Brazilian', 'state', 'Paranè', '']
# Sentence after removing stopwords: ['The', 'previously', 'concluded', 'adaptation', 'measures', '', 'concerning', 'staff', '', 'adequate', 'time', '', 'planning', 'operations', 'continue', 'plant', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'world', 'biggest', 'magazine', 'paper', 'maker', 'said', 'program', 'improve', 'efficiency', 'include', 'closing', 'several', 'least', 'competitive', 'mills', 'would', 'cover', 'company', 'operations', 'resulting', 'annual', 'savings', 'euro200', 'million', 'US', '240', 'million', '']
# Sentence after removing stopwords: ['Suominen', 'Corporation', 'estimates', 'costcutting', 'program', 'started', 'autumn', '2005', '', 'higher', 'sales', 'prices', '', 'expected', 'growth', 'volume', 'Wet', 'Wipes', '', 'make', 'company', 'operations', 'profitable', '']
# Sentence after removing stopwords: ['Net', 'sales', 'rose', '255', '', 'yearonyear', 'EUR59', '6', '', 'number', 'chargers', 'delivered', 'went', '41', '', '659', 'million', 'pieces', '']
# Sentence after removing stopwords: ['Kesko', 'Agro', 'Eesti', '', 'retailer', 'wholesaler', 'grain', '', 'agricultural', 'warehousing', 'machinery', 'accessories', '', 'net', 'sales', '81', 'million', 'euros', '2007', '', 'increase', 'onetenth', 'preceding', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'handling', 'systems', 'company', 'Cargotec', 'Oyj', '', 'HEL', '', 'CGCBV', '', 'said', 'today', 'EUR', '13', 'million', '', 'USD', '166', '', 'contract', 'deliver', 'MacGregor', 'hatch', 'covers', 'ships', 'ordered', 'Norwegian', 'shipowner', 'Grieg', 'Shipping', '']
# Sentence after removing stopwords: ['', 'Our', 'extensive', 'cooperation', 'also', 'bolster', 'SysOpen', 'Digia', 'position', 'domestic', 'operator', 'market', '', '', 'Kallioranta', 'adds', '']
# Sentence after removing stopwords: ['', 'Our', 'strategic', 'cooperation', 'Rentakran', 'brings', 'us', 'new', 'customers', 'alreadyworking', 'relationships', 'authorities', 'new', 'territories', '', '', 'said', 'Jarmo', 'Laasanen', '', 'senior', 'manager', 'Cramo', '']
# Sentence after removing stopwords: ['A', 'portion', '', '', '125', 'million', '', 'recorded', 'part', 'winnings', 'prior', 'patent', 'dispute', 'Finnish', 'phone', 'maker', 'Nokia', 'Oyj', '']
# Sentence after removing stopwords: ['Q1', '10', '19', 'April', '2010', '', 'Finnish', 'forest', 'machinery', 'equipment', 'maker', 'Ponsse', 'Oyj', 'HEL', '', 'PON1V', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'EUR6', '3', 'first', 'quarter', '2010', '', 'EUR9', '6', 'loss', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Finlandbased', 'Elcoteq', 'SE', '', 'privately', 'held', 'provider', 'electronics', 'manufacturing', 'services', 'communications', 'companies', '', 'said', 'Thursday', 'signed', 'longterm', 'manufacturing', 'supply', 'deal', 'communications', 'equipment', 'company', 'Andrew', 'Corp', '']
# Sentence after removing stopwords: ['', 'Lidskoe', 'Pivo', 'investment', 'program', 'foresees', 'integrated', 'modernization', 'production', '', 'updating', 'transport', 'logistics', 'infrastructure', 'developing', 'new', 'marketing', 'instruments', '', '', 'Mikshis', 'said', '']
# Sentence after removing stopwords: ['This', 'Done', 'Logistics', '', 'largest', 'order', 'Norway', '', 'diversified', 'group', 'said', '']
# Sentence after removing stopwords: ['Finland', 'Nokian', 'Tyres', 'Kazakhstan', 'Ordabasy', 'Corporation', 'signed', 'agreement', 'build', 'plant', 'Astana', 'produce', 'car', 'tires', '', 'Ordabasy', 'chairman', 'Dinmukhamet', 'Idrisov', 'said', 'press', 'conference', '']
# Sentence after removing stopwords: ['At', 'seminar', '', 'memorandum', 'understanding', 'cooperation', 'signed', 'Finnish', 'Kemira', 'Company', 'Vietnam', 'National', 'Chemical', 'Corporation', '']
# Sentence after removing stopwords: ['', 'The', 'priority', '2009', 'strengthen', 'company', 'balance', 'sheet', 'increase', 'cash', 'flow', '', '', 'CEO', 'Hannu', 'Krook', 'said', '']
# Sentence after removing stopwords: ['The', 'economic', 'occupancy', 'rate', 'Sponda', 'property', 'portfolio', 'rose', '912', '', '888', '', '2006', '']
# Sentence after removing stopwords: ['The', 'Ministry', 'Water', 'Tanzania', 'awarded', 'Poyry', 'water', 'sanitation', 'engineering', 'assignment', 'rehabilitation', 'extension', 'water', 'supply', 'sanitation', 'infrastructure', 'Bukoba', 'Musoma', '', 'situated', 'Lake', 'Victoria', 'northern', 'Tanzania', '']
# Sentence after removing stopwords: ['Nokia', 'bought', 'Chicagobased', 'Navteq', '2008', '', 'acquiring', 'maps', 'database', 'compete', 'Google', 'maps', 'well', 'navigation', 'device', 'companies', 'TomTom', 'NV', 'Garmin', 'Ltd', '']
# Sentence after removing stopwords: ['Uponor', 'made', 'operating', 'profit', 'EUR', '1510', 'mn', '', 'EUR', '1437', 'mn', '', 'made', '2007', 'record', 'year', '']
# Sentence after removing stopwords: ['It', 'also', 'strengthen', 'Ruukki', 'offshore', 'business', '']
# Sentence after removing stopwords: ['There', 'recovery', 'base', 'metals', 'prices', 'increased', 'demand', 'metals', 'China', '', 'however', '']
# Sentence after removing stopwords: ['Finnish', 'GeoSentric', '', 'developer', 'provider', 'solutions', '', 'products', '', 'technologies', 'location', 'based', 'services', '', 'preliminary', 'agreed', 'EUR', '6mn', 'shortterm', 'funding', 'leading', 'investor', '']
# Sentence after removing stopwords: ['', 'UPM', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', '', 'efficiency', 'operations', 'improved', '', '', 'Chief', 'Executive', 'Jussi', 'Pesonen', 'said', '']
# Sentence after removing stopwords: ['In', 'end', '2006', '', 'number', 'outlets', 'rise', '6070', '']
# Sentence after removing stopwords: ['Kesko', 'car', 'import', 'retailing', 'business', '', 'VVAuto', '', 'saw', 'sales', 'grow', '171', 'pct', '']
# Sentence after removing stopwords: ['I', 'looking', 'forward', 'contribute', 'SRV', 'success', 'competence', '', '', 'says', 'Taneli', 'Hassinen', '']
# Sentence after removing stopwords: ['It', 'combines', 'perfect', 'price', 'performance', 'sophisticated', 'management', 'facilities', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'company', 'net', 'profit', 'rose', '114', '', 'year', '822', 'million', 'euros', '2005', 'sales', '6865', 'million', 'euros', '', '138', '', 'year', '', 'company', 'said', 'earlier', '']
# Sentence after removing stopwords: ['We', 'also', 'strengthen', 'existing', 'partnership', 'Cybercom', '', '', 'says', 'Teleste', 'CTO', 'Esko', 'Myllyla', '']
# Sentence after removing stopwords: ['Nordea', 'sees', 'return', 'positive', 'growth', 'Baltic', 'countries', '2011', '']
# Sentence after removing stopwords: ['These', 'moderate', 'significant', 'changes', 'resulted', 'significant', '2432', '', 'reduction', 'estimated', 'CVD', 'risk', '']
# Sentence after removing stopwords: ['In', 'Sweden', '', 'operating', 'profit', 'period', 'review', 'totaled', 'EUR', '34', 'mn', '', '308', '', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['First', 'quarter', 'underlying', 'operating', 'profit', 'rose', '41', 'mln', 'eur', '33', 'mln', 'year', 'earlier', '']
# Sentence after removing stopwords: ['MANAVIGATORSeptember', '7', '', '2010Kemira', 'unveils', 'Indian', 'JV', 'IVRCL', 'Finnish', 'chemicals', 'group', 'Kemira', '', 'HEL', '', 'KRA1V', '', 'Tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'India', 'local', 'construction', 'firm', 'IVRCL', 'Infrastructure', 'Projects', 'Ltd', '', 'BOM', '530773', '', '']
# Sentence after removing stopwords: ['Alma', 'Media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously', '']
# Sentence after removing stopwords: ['Adanac', 'Molybdenum', 'Canada', 'ordered', 'grinding', 'technology', 'molybdenum', 'project', 'British', 'Columbia', '', 'Canada', '', 'Shalkiya', 'Zinc', 'Kazakhstan', 'awarded', 'contract', 'grinding', 'technology', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'EUR', '06', 'mn', '', 'loss', 'EUR', '19mn', 'year', 'earlier', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'property', 'portfolio', 'doubled', 'result', 'Kapiteeli', 'acquisition', 'totalled', 'EUR', '26862', '12597', 'million', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '135', 'mn', 'EUR', '97', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['The', 'soapstone', 'deposits', 'Medvezhyegorsk', 'area', 'expected', 'increase', 'Tulikivi', 'current', 'reserves', 'considerably', '']
# Sentence after removing stopwords: ['Clothing', 'retail', 'chain', 'SeppÆlÆ', 'sales', 'increased', '8', '', 'EUR', '1552', 'mn', '', 'operating', 'profit', 'rose', 'EUR', '311', 'mn', 'EUR', '171', 'mn', '2004', '']
# Sentence after removing stopwords: ['The', 'company', 'estimates', 'net', 'sales', '2010', 'increase', 'considerably', '2009', 'operating', 'result', 'clearly', 'positive', '']
# Sentence after removing stopwords: ['', 'I', 'pleased', 'proud', 'performance', 'last', 'year', '', '', 'Chief', 'Executive', 'Juha', 'Rantanen', 'said', 'statement', '']
# Sentence after removing stopwords: ['This', 'acquisition', 'supports', 'strategy', 'close', 'customers', 'around', 'world', 'offering', 'equipment', 'related', 'services', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Oct', '31', '', '2008', '', 'Finnish', 'food', 'company', 'Raisio', 'Oyj', '', 'OMX', '', 'RAIVV', '', 'said', 'today', 'net', 'profit', 'jumped', 'EUR', '164', 'million', '', 'USD', '209', '', 'first', 'nine', 'months', '2008', 'EUR', '11', 'million', 'period', '2']
# Sentence after removing stopwords: ['This', 'second', 'successful', 'effort', 'financial', 'investor', 'year', '']
# Sentence after removing stopwords: ['', 'We', 'feeling', 'quite', 'positive', 'region', 'whole', '']
# Sentence after removing stopwords: ['Its', 'main', 'business', 'area', '', 'Glass', 'Machinery', 'Group', 'Glaston', 'Technologies', '', 'global', 'market', 'leader', 'glass', 'processing', 'machines', '']
# Sentence after removing stopwords: ['TeliaSonera', 'said', '', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', '', 'Nepal', 'population', '']
# Sentence after removing stopwords: ['India', 'trade', 'Russia', 'currently', 'stands', 'four', 'billion', 'dollars', '', 'growing', '96', 'per', 'cent', 'fiscal', '2007', '']
# Sentence after removing stopwords: ['This', 'bring', 'cost', 'savings', 'EUR', '3mn', 'year', '']
# Sentence after removing stopwords: ['HELSINKI', '', 'AFX', '', '', 'Nokian', 'Tyres', 'reported', 'fourth', 'quarter', 'pretax', 'profit', '615', 'mln', 'eur', '', '486', 'mln', 'back', 'strong', 'sales', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'improved', 'EUR', '203', 'mn', 'EUR', '114', 'mn', '']
# Sentence after removing stopwords: ['', 'Beyond', 'improved', 'voice', 'capabilities', '', 'customers', 'streamlined', 'way', 'comply', 'recalls', 'traceability', 'requirements', '', 'providing', 'competitive', 'advantage', '']
# Sentence after removing stopwords: ['Actions', 'improve', 'operational', 'efficiency', 'adjust', 'operations', 'expected', 'deliver', 'annualised', 'permanent', 'cost', 'savings', 'around', 'EUR', '45', 'million', 'effected', 'mostly', 'first', 'half', '2010', '']
# Sentence after removing stopwords: ['EPS', 'grew', '004', 'eur', '002', 'eur', '']
# Sentence after removing stopwords: ['The', 'EBITDA', 'EUR116m', 'compared', 'EUR115m', '', 'corresponding', 'EBITDA', 'margin', '33', '', '']
# Sentence after removing stopwords: ['Incap', 'Lankapaja', 'aim', 'enter', 'actual', 'agreement', 'transfer', 'sheetmetal', 'production', 'buyer', 'February', 'order', 'complete', 'transfer', '1', 'March', '2011', '']
# Sentence after removing stopwords: ['Revenue', 'grew', '2', 'percent', '', 'x20ac', '580', 'million', '', '743', 'million', '', '', 'x20ac', '569', 'million', '']
# Sentence after removing stopwords: ['The', 'company', 'feels', 'leases', 'prime', 'locations', 'due', 'several', 'producing', 'formations', 'immediate', 'area', '']
# Sentence after removing stopwords: ['Finnish', 'investment', 'group', 'Panostaja', 'Oyj', 'said', 'net', 'profit', 'went', '86', 'mln', 'euro', '', '114', 'mln', 'fiscal', '200506', '', 'ended', 'October', '31', '', '2006', '', '28', 'mln', 'euro', '', '37', 'mln', 'period', 'fiscal', '200405', '']
# Sentence after removing stopwords: ['Exports', 'accounted', '654', '', 'net', 'sales', '', 'representing', 'time', 'record', 'company', '']
# Sentence after removing stopwords: ['', 'Our', 'customer', 'satisfied', 'Basware', 'Invoice', 'Automation', 'solution', 'extends', 'implementation', 'new', 'geographies', '']
# Sentence after removing stopwords: ['Thanks', 'multiplying', 'effect', 'wagon', 'performance', '', 'transport', 'much', 'efficient', '', '', 'says', 'development', 'manager', 'Juha', 'Malkia', 'VR', 'Cargo', '']
# Sentence after removing stopwords: ['Demand', 'seems', 'hit', 'bottom', '', 'signs', 'improvement', 'seen', '']
# Sentence after removing stopwords: ['Finnish', 'Ahlstrom', 'Corporation', 'ordered', 'key', 'production', 'equipment', 'new', 'glass', 'nonwovens', 'production', 'line', 'Russian', 'Tver', 'Mill', 'Finnish', 'Vaahto', 'Pulp', '', 'Paper', 'Machinery', '', 'part', 'Vaahto', 'Group', '', '']
# Sentence after removing stopwords: ['The', 'company', 'expects', 'net', 'sales', '2008', 'increase', '510', '', '2007', '']
# Sentence after removing stopwords: ['Finnish', 'Bank', 'land', 'reports', 'operating', 'profit', 'rose', 'EUR', '213', 'mn', 'second', 'quarter', '2009', 'EUR', '61', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['Sanoma', 'Magazines', 'Finland', 'net', 'sales', 'grew', 'EUR', '1401', 'mn', 'EUR', '1318', 'mn', '']
# Sentence after removing stopwords: ['Comparable', 'net', 'sales', 'expected', 'increase', '10', '', '2008', '', 'line', 'group', 'target', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'components', 'supplier', 'Componenta', 'Oyj', 'said', 'net', 'profit', 'went', '35', 'mln', 'euro', '', '45', 'mln', '2006', '22', 'mln', 'euro', '', '28', 'mln', '2005', '']
# Sentence after removing stopwords: ['It', 'also', 'said', 'third', 'quarter', 'diluted', 'EPS', 'came', '034', 'eur', 'compared', '016', 'eur', 'quarter', 'year', 'ago', '']
# Sentence after removing stopwords: ['Its', 'market', 'share', 'widened', '4851', 'percent', '4831', 'percent', 'year', 'earlier', '']
# Sentence after removing stopwords: ['Satama', 'net', 'sales', 'would', 'higher', 'year', '']
# Sentence after removing stopwords: ['Finnish', 'financial', 'group', 'Aktia', 'reports', 'operating', 'profit', 'EUR', '444', 'mn', 'JanuarySeptember', '2009', '', 'EUR', '373', 'mn', 'corresponding', 'period', '2008', '']
# Sentence after removing stopwords: ['Cargo', 'volume', 'grew', '7', '', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'expected', 'improve', 'access', 'chrome', 'ore', 'resources', 'Turkey', '']
# Sentence after removing stopwords: ['Kaido', 'Kaare', '', 'general', 'director', 'Atria', 'Eesti', '', 'says', 'company', 'investments', 'upgrade', 'pig', 'farms', 'surpass', 'EEK', '150mn', 'EUR', '959', 'mn', 'USD', '1419', 'mn', 'past', 'years', '']
# Sentence after removing stopwords: ['Lithuanian', 'beer', 'makers', 'sold', '25688', 'million', 'liters', 'beer', '2005', '', 'rise', '45', 'per', 'cent', 'yearearlier', 'figure', '24592', 'million', 'liters', '']
# Sentence after removing stopwords: ['The', 'company', 'order', 'book', 'stood', '15', 'bln', 'euro', '', '22', 'bln', 'September', '30', '', '2007', '', '242', 'pct', 'year', '', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '', '5343', 'mln', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totaled', 'EUR', '55', 'mn', '', 'EUR', '07', 'mn', '']
# Sentence after removing stopwords: ['The', 'services', 'also', 'give', 'supplier', 'opportunity', 'keyin', 'invoices', '', 'receive', 'orders', 'electronically', '', 'send', 'order', 'confirmations', 'upload', 'create', 'electronic', 'catalogues', '']
# Sentence after removing stopwords: ['The', 'energyefficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'stateoftheart', 'technology', '']
# Sentence after removing stopwords: ['', 'Following', 'last', 'year', 'good', 'profit', 'development', '', 'entered', 'current', 'year', 'good', 'position', '']
# Sentence after removing stopwords: ['According', 'report', 'Neomarkka', '', 'Kuitu', 'Finland', 'customers', 'interested', 'buying', 'company', 'products', 'restarts', 'production', '']
# Sentence after removing stopwords: ['', 'The', 'margarine', 'business', 'put', 'good', 'shape', 'last', 'two', 'years', '', 'making', 'natural', 'addition', 'Bunge', '', 'looking', 'leverage', 'position', 'Central', 'Northern', 'European', 'markets', '', '', 'Raisio', 'CEO', 'Matti', 'Rihko', 'said', 'statement', '']
# Sentence after removing stopwords: ['The', 'Brazilian', 'unit', 'Finnish', 'security', 'solutions', 'provider', 'FSecure', 'signed', '1500', 'new', 'clients', 'last', 'year', '', 'online', 'news', 'source', 'Reseller', 'Web', 'quoted', 'division', 'commercial', 'director', '', 'Vladimir', 'Brando', '', 'saying', '']
# Sentence after removing stopwords: ['Unit', 'costs', 'flight', 'operations', 'fell', '64', 'percent', '']
# Sentence after removing stopwords: ['The', 'respondents', 'praised', 'Finnair', 'reliability', '', 'Finnishness', '', 'understanding', 'target', 'group', '']
# Sentence after removing stopwords: ['In', 'September', '2010', '', 'Finnish', 'group', 'agreed', 'buy', 'Danish', 'company', 'Rose', 'Poultry', 'AS', 'EUR23', '9', 'combination', 'cash', 'stock', '']
# Sentence after removing stopwords: ['It', 'leading', 'private', 'road', 'ambulance', 'service', 'company', 'Finland', '']
# Sentence after removing stopwords: ['In', 'second', 'quarter', '2010', '', 'Raute', 'net', 'loss', 'narrowed', 'EUR', '123000', 'EUR', '15', 'million', 'period', '2009', '']
# Sentence after removing stopwords: ['3', 'January', '2011', '', 'Finnish', 'flag', 'carrier', 'Finnair', 'Oyj', '', 'HEL', '', 'FIA1S', '', 'said', 'today', 'sealed', 'nineyear', 'sale', 'leaseback', 'agreement', 'newest', 'Airbus', 'A330', 'aircraft', 'syndication', 'Japanese', 'operating', 'lease', 'market', '']
# Sentence after removing stopwords: ['The', 'production', 'capacity', 'tripled', 'without', 'major', 'additional', 'investments', '', 'company', 'said', '']
# Sentence after removing stopwords: ['Israeli', 'cable', 'network', 'operator', 'HOT', 'Telecom', 'chosen', 'Teleste', '', 'international', 'technology', 'group', '', 'exclusive', 'provider', 'FTTx', 'equipment', 'Israel', '', 'according', 'Teleste', 'today', '']
# Sentence after removing stopwords: ['The', 'company', 'aims', 'maintain', 'trend', 'profitability', 'current', 'year', '']
# Sentence after removing stopwords: ['The', 'terms', 'financing', 'approved', 'Annual', 'General', 'Meeting', 'Company', 'held', 'June', '30', '', '2010', '']
# Sentence after removing stopwords: ['The', 'refining', 'margin', 'year', '', '1339', '', 'bbl', '', 'compared', '', '1046', '', 'bbl', 'prior', 'year', '']
# Sentence after removing stopwords: ['Altimo', 'TeliaSonera', 'said', 'yesterday', 'Usmanov', 'would', 'welcome', 'join', 'new', 'company', '']
# Sentence after removing stopwords: ['With', 'appointment', 'Kaupthing', 'Bank', 'aims', 'coordinate', 'Capital', 'Markets', 'activities', 'within', 'Group', 'improve', 'overall', 'service', 'clients', '']
# Sentence after removing stopwords: ['EBIT', 'excluding', 'nonrecurring', 'items', 'estimated', 'increase', '2009', '']
# Sentence after removing stopwords: ['The', 'company', 'said', 'supply', 'WCDMA', '3GHSPA', 'radio', 'network', '', 'including', 'modular', '', 'high', 'capacity', 'Nokia', 'Flexi', 'WCDMA', 'base', 'station', 'East', 'Java', '', 'Bali', '', 'Sumatra', 'Batam', '']
# Sentence after removing stopwords: ['Brazilian', 'mobile', 'player', 'Telemig', 'Celular', 'yesterday', 'announced', 'selected', 'Finnish', 'software', 'developer', 'Tecnomen', 'Oyj', 'expand', 'prepaid', 'billing', 'system', '']
# Sentence after removing stopwords: ['Finnish', 'forest', 'machinery', 'manufacturer', 'Ponsse', 'agreed', 'Volvo', 'start', 'cooperation', 'Latin', 'America', '']
# Sentence after removing stopwords: ['The', 'divestment', 'Raisio', 'margarine', 'business', 'May', '2009', 'gave', 'company', 'clearer', 'focus', 'grainbased', 'products', '']
# Sentence after removing stopwords: ['TeliaSonera', 'secured', 'deliveries', '4G', 'modems', 'support', '3G', '2G', 'second', 'quarter', '2010', '']
# Sentence after removing stopwords: ['Mobile', 'phone', 'shipments', 'jumped', '26', 'percent', 'almost', '112', 'million', 'units', '', 'Finnish', 'company', 'global', 'market', 'share', 'rose', '39', 'percent', '36', 'percent', '']
# Sentence after removing stopwords: ['Finnish', 'elevators', 'escalators', 'maker', 'KONE', 'Corporation', 'said', 'Tuesday', '', '18', 'March', '', 'received', 'major', 'order', 'Sir', 'Robert', 'McAlpine', 'supply', 'elevators', 'escalators', 'Watermark', 'Place', 'project', 'City', 'London', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totalled', 'EUR', '830', 'mn', '', 'EUR', '235', 'mn', 'yearonyear', '']
# Sentence after removing stopwords: ['At', 'first', 'contract', 'envisaged', 'construction', 'three', 'ferryboats', 'option', 'two', 'units', '', 'confirmed', 'total', 'value', '500', 'mln', 'euro', '', '', '6458', 'mln', '', '']
# Sentence after removing stopwords: ['', 'The', 'Government', 'professional', 'approach', 'assessing', 'offer', '']
# Sentence after removing stopwords: ['Kone', 'net', 'sales', 'rose', '14', '', 'yearonyear', 'first', 'nine', 'months', '2008', '']
# Sentence after removing stopwords: ['Nyrstar', 'also', 'agreed', 'supply', 'Talvivaara', '150000', 'tonnes', 'sulphuric', 'acid', 'per', 'annum', 'use', 'Talvivaara', 'leaching', 'process', 'period', 'supply', 'zinc', 'concentrate', '']
# Sentence after removing stopwords: ['', 'We', 'delighted', 'move', '', 'says', 'Morna', 'Cowie', '', 'coowner', '', '', '', 'double', 'size', 'current', 'shop', 'lovely', 'feel', '', '']
# Sentence after removing stopwords: ['Finnish', 'Vacon', 'signed', 'significant', 'deals', 'Norwegian', 'Scandinavian', 'Electric', 'Systems', '', 'SES', '', 'supply', 'AC', 'drives', '']
# Sentence after removing stopwords: ['Finnish', 'metal', 'products', 'company', 'Componenta', 'Oyj', 'net', 'profit', 'rose', '261', 'mln', 'euro', '', '', '359', 'mln', '', 'first', 'quarter', '2007', '53', 'mln', 'euro', '', '', '73', 'mln', '', 'period', '2006', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Nov', '28', '', '2008', '', 'Finnish', 'powersupply', 'solutions', 'provider', 'Efore', 'Oyj', '', 'OMX', '', 'EFO1V', '', 'announced', 'today', 'launch', 'OPUS', 'DC', '', 'latest', 'power', 'system', 'OPUS', 'product', 'line', '']
# Sentence after removing stopwords: ['Sales', 'rose', '10', 'pct', '566', 'mln', 'eur', 'back', 'strong', 'volume', 'favourable', 'currency', 'effects', '']
# Sentence after removing stopwords: ['', 'We', 'lowest', 'bidders', 'final', 'approval', 'awaited', '', '']
# Sentence after removing stopwords: ['The', 'transactions', 'would', 'increase', 'earnings', 'per', 'share', 'first', 'quarter', 'EUR0', '28', '']
# Sentence after removing stopwords: ['Xerox', 'Stora', 'Enso', 'teamed', 'tailor', 'iGen3', 'shortrun', '', 'ondemand', 'packaging', 'market', '']
# Sentence after removing stopwords: ['He', 'believes', 'soyoats', 'good', 'chance', 'entering', 'UK', 'market', '']
# Sentence after removing stopwords: ['The', 'parties', 'agreed', 'negotiate', 'definitive', 'distribution', 'license', 'agreements', 'end', 'June', '2010', '']
# Sentence after removing stopwords: ['We', 'pleased', 'fine', 'cooperation', 'two', 'countries', 'recent', 'times', '', 'said', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'saw', 'net', 'profit', 'jump', 'EUR2', '1', 'last', 'quarter', '2010', 'EUR995', '000', 'period', '2009', '']
# Sentence after removing stopwords: ['New', 'product', 'launches', 'Finland', 'double', '2005', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'Kalmar', 'received', 'significant', 'order', 'US', 'Department', 'Defense', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '278', 'mn', 'EUR', '175', 'mn', '2008', '']
# Sentence after removing stopwords: ['Airvana', 'UMTS', 'Home', 'Base', 'Station', 'femto', 'cell', 'uses', 'softwarebased', 'functionality', 'offtheshelf', 'silicon', 'accelerate', 'feature', 'development', 'reduce', 'product', 'cost', '']
# Sentence after removing stopwords: ['Diluted', 'earnings', 'per', 'share', '', 'EPS', '', 'rose', 'EUR', '368', 'EUR', '050', '']
# Sentence after removing stopwords: ['Sales', 'security', 'system', 'packaging', 'increased', 'slightly', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'Asian', 'plants', 'grew', 'markedly', '']
# Sentence after removing stopwords: ['The', 'bank', 'sees', 'potential', 'Getinge', 'share', 'rise', '']
# Sentence after removing stopwords: ['Net', 'sales', 'went', '1', '', 'yearonyear', 'EUR', '29', 'million', '', 'affected', 'business', 'acquisitions', '', 'realized', 'previous', 'financial', 'period', '', 'effect', 'EUR', '51', 'million', 'review', 'period', '']
# Sentence after removing stopwords: ['21', 'October', '2010', '', 'Finnish', 'fishing', 'tackle', 'company', 'Rapala', 'VMC', 'Corp', '', 'HEL', '', 'RAP1V', '', 'said', 'today', 'net', 'profit', 'rose', 'EUR18', '9', 'first', 'nine', 'months', '2010', 'EUR15', '1', 'period', 'year', 'earlier', '']
# Sentence after removing stopwords: ['OUTOTEC', 'OYJ', 'PRESS', 'RELEASE', 'DECEMBER', '4', '', '2009', '1030', 'AM', 'Outotec', 'establishes', 'new', 'subsidiary', 'Kolkata', 'Outotec', 'established', 'subsidiary', 'India', 'order', 'better', 'serve', 'Indian', 'customers', 'increase', 'business', 'growing', 'Indian', 'market', '']
# Sentence after removing stopwords: ['In', 'AsiaPacific', 'region', '', 'Visa', 'Wave', 'available', 'Malaysia', '', 'Taiwan', 'South', 'Korea', 'expanded', 'Japan', 'Southeast', 'Asia', 'year', '', 'Jung', 'added', '']
# Sentence after removing stopwords: ['The', 'cooperation', 'double', 'The', 'Switch', 'converter', 'capacity', '']
# Sentence after removing stopwords: ['Luxembourgregistered', 'investment', 'fund', 'Amber', 'Trust', 'II', 'final', 'approval', 'Lithuania', 'Competition', 'Council', 'acquire', '296', 'percent', 'Sanitas', '', 'country', 'largest', 'pharmaceutical', 'producer', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'EUR', '114', 'mn', '', 'EUR', '75', 'mn', '']
# Sentence after removing stopwords: ['1', 'November', '2010', '', 'Finnish', 'textile', 'clothing', 'company', 'Marimekko', 'Oyj', '', 'HEL', '', 'MMO1V', '', 'announced', 'Friday', 'opening', 'first', 'concept', 'store', 'Seoul', 'cooperation', 'Japanese', 'sector', 'player', 'Look', 'Inc', '', 'TYO', '', '8029', '', '']
# Sentence after removing stopwords: ['All', 'Raisio', 'divisions', 'recorded', 'operating', 'profit', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'threemonth', 'period', 'increased', 'EUR1', '2', '', 'revenue', 'increased', 'EUR20', '2', '', 'compared', 'corresponding', 'period', '2005', '']
# Sentence after removing stopwords: ['The', 'solutions', 'used', 'upgrading', 'networks', 'Russian', 'MSO', '37', 'different', 'cities', 'Russia', '']
# Sentence after removing stopwords: ['In', 'JulySeptember', '2008', '', 'YIT', 'net', 'sales', 'increased', 'EUR', '9708', 'mn', '', 'compared', 'EUR', '9068', 'mn', 'corresponding', 'period', '2007', '']
# Sentence after removing stopwords: ['', 'The', 'acquisition', 'Sampo', 'Bank', 'makes', 'strategic', 'sense', 'DB', '', '', 'says', 'Lindsey', 'Liddell', '', 'director', 'Fitch', 'Ratings', 'Financial', 'Institutions', 'Group', '']
# Sentence after removing stopwords: ['In', '2007', '', 'Marimekko', 'also', 'opened', 'concept', 'stores', 'Yokohama', 'Nagoya', '', 'central', 'Japan', '', 'Silver', 'Spring', 'metropolitan', 'Washington', 'DC', '', 'USA', '', 'Graz', '', 'central', 'Austria', '', 'Aalborg', '', 'northern', 'Denmark', '']
# Sentence after removing stopwords: ['The', 'fair', 'value', 'investment', 'properties', 'totalled', 'EUR', '22999', 'mn', '', 'compared', 'EUR', '22295', 'mn', 'corresponding', 'period', '2009', '']
# Sentence after removing stopwords: ['The', 'agreement', 'strengthens', 'longterm', 'partnership', 'Nokia', 'Siemens', 'Networks', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'rose', 'EUR', '5mn', 'EUR', '28', 'mn', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'stock', 'new', 'machines', 'reasonably', 'small', 'new', 'orders', 'bring', 'work', '']
# Sentence after removing stopwords: ['The', 'third', 'order', 'awarded', 'Outokumpu', 'Technology', 'Shalkiya', 'Zinc', 'Kazakhstan', 'Shalkiya', 'zinclead', 'project', 'Kazakhstan', '']
# Sentence after removing stopwords: ['LONDON', 'MarketWatch', '', 'Nokia', 'nok', 'said', 'fiveyear', 'services', 'contract', 'run', 'Hutchison', 'Essar', 'network', 'operations', 'nine', 'locations', 'India', '']
# Sentence after removing stopwords: ['Outotec', 'net', 'profit', 'second', 'quarter', '2007', 'jumped', '168', 'mln', 'euro', '', '', '231', 'mln', '', '46', 'mln', 'euro', '', '', '63', 'mln', '', 'year', 'ago', '']
# Sentence after removing stopwords: ['Industry', 'Investment', 'interested', 'Glaston', 'solar', 'energy', 'projects', '']
# Sentence after removing stopwords: ['planning', 'expand', 'product', 'portfolio', 'harbor', 'segment', '', 'chief', 'executive', 'Pekka', 'Lundmark', 'told', 'Financial', 'Times', 'Deutschland', '']
# Sentence after removing stopwords: ['The', 'Lithuanian', 'beer', 'market', 'made', '1441', 'million', 'liters', 'January', '', 'rise', '08', 'percent', 'yearearlier', 'figure', '', 'Lithuanian', 'Brewers', '', 'Association', 'reporting', 'citing', 'results', 'members', '']
# Sentence after removing stopwords: ['In', 'reporting', 'period', '', 'company', 'operating', 'profit', 'grew', '432', '', 'EUR', '6', 'million', '']
# Sentence after removing stopwords: ['According', 'company', '', 'operating', 'profit', '', 'excluding', 'nonrecurring', 'items', '', 'fourth', 'quarter', '2009', 'significantly', 'better', 'expected', '', 'also', 'better', 'figures', 'fourth', 'quarter', '2008', '']
# Sentence after removing stopwords: ['The', 'company', 'established', '3G', 'base', 'station', '17000', 'feet', 'foot', 'Mount', 'Everest', 'enable', 'mountain', 'climbers', '29035foot', 'summit', 'surf', 'Internet', 'even', 'send', 'videos', 'exploits', '']
# Sentence after removing stopwords: ['For', 'Telenor', '', 'three', 'half', 'year', 'contract', 'worth', 'estimated', '126', 'YIT', 'chosen', 'Telenor', 'Elisa', 'principal', 'suppliers', 'ICT', 'solutions', 'Norway', '', 'Sweden', '', 'Denmark', 'Finland', '']
# Sentence after removing stopwords: ['Cooper', 'SH', '', 'UK', 'distributor', 'lift', 'equipment', 'manufacturer', 'Konecranes', '', 'fiveyear', 'deal', 'involves', 'low', 'maintenance', 'fuel', 'saving', 'technologies', '']
# Sentence after removing stopwords: ['Affecto', 'expects', 'net', 'sales', 'whole', '2010', 'increase', '2009', 'level', 'reached', 'EUR', '103', 'million', '']
# Sentence after removing stopwords: ['Finnish', 'Cargotec', 'awarded', 'significant', 'order', 'total', '292', 'Hiab', 'loader', 'cranes', 'BAE', 'Systems', 'US', '']
# Sentence after removing stopwords: ['According', 'ARehu', 'Managing', 'Director', '', 'Jouko', 'Lahtinen', '', 'project', 'stabilise', 'costs', 'improve', 'supply', 'security', '']
# Sentence after removing stopwords: ['Acquisitions', 'made', 'businesses', 'well', 'integrated', '']
# Sentence after removing stopwords: ['', 'Our', 'design', 'team', 'long', 'admired', 'Marimekko', 'vivid', 'patterns', 'colors', '']
# Sentence after removing stopwords: ['In', 'Middle', 'East', '', 'North', 'Africa', '', 'Tecnotree', 'grown', 'considerably', 'recent', 'years', '']
# Sentence after removing stopwords: ['The', 'company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230000', 'tonnes', 'copper', '']
# Sentence after removing stopwords: ['SvyturysUtenos', 'Alus', '', 'controlled', 'Nordic', 'group', 'Baltic', 'Beverages', 'Holding', '', 'BBH', '', '', 'posted', '47percent', 'growth', 'beer', 'sales', 'JanuaryMay', '4622', 'million', 'litres', '']
# Sentence after removing stopwords: ['It', 'also', 'turned', 'earnings', 'per', 'share', '', 'EPS', '', 'EUR', '044', 'versus', 'loss', 'per', 'share', 'EUR', '226', '']
# Sentence after removing stopwords: ['Sony', 'Ericsson', 'Nokia', 'dominated', 'list', 'bestselling', 'handsets', 'five', 'models', '']
# Sentence after removing stopwords: ['However', '', 'net', 'sales', '2010', 'seen', 'grown', 'EUR598', '3', 'EUR582', '3', '2009', '']
# Sentence after removing stopwords: ['Again', '', 'significant', 'sales', 'increase', '186', '', 'Russia', '']
# Sentence after removing stopwords: ['Ixonos', 'estimates', 'hire', '20', 'specialists', 'mechanical', 'engineering', '', 'electronics', 'design', '', 'RD', 'new', 'unit', 'Jyvaeskylae', 'end', '2009', '']
# Sentence after removing stopwords: ['Both', 'operating', 'profit', 'net', 'sales', '12month', 'period', 'increased', '', 'respectively', 'EUR10', '5', 'EUR28', '8', '', 'compared', 'financial', 'year', '2004', '']
# Sentence after removing stopwords: ['The', 'negotiations', 'carried', 'constructive', 'manner', '', 'parties', 'tried', 'find', 'solution', 'situation', '']
# Sentence after removing stopwords: ['Metso', 'supply', 'equipment', 'two', 'process', 'lines', 'Northland', 'Resources', '', 'new', 'Kaunisvaara', 'iron', 'ore', 'project', 'Sweden', 'exploits', 'Tapuli', 'Sahavaara', 'iron', 'ore', 'deposits', '']
# Sentence after removing stopwords: ['More', 'staff', 'recruited', 'Japan', 'complement', 'network', 'close', '50', 'service', 'locations', '20', 'countries', 'worldwide', '']
# Sentence after removing stopwords: ['Finnish', 'dental', 'care', 'group', 'Oral', 'Hammaslaakarit', 'Oyj', 'posted', 'total', 'net', 'profit', '849000', 'euro', '', '11', 'mln', 'first', 'nine', 'months', '2006', 'versus', 'net', 'loss', '331000', 'euro', '', '421000', 'period', '2005', '']
# Sentence after removing stopwords: ['In', 'addition', 'deal', 'includes', 'call', 'option', 'enable', 'Maritim', 'Food', 'AS', 'increase', 'holding', 'Sandanger', 'AS', '51', '', 'future', '']
# Sentence after removing stopwords: ['Finnish', 'steel', 'maker', 'Rautaruukki', 'Oyj', '', 'Ruukki', '', 'said', 'July', '7', '', '2008', '90', 'mln', 'euro', '', '', '141', 'mln', '', 'contract', 'supply', 'install', 'steel', 'superstructures', 'Partihallsforbindelsen', 'bridge', 'project', 'Gothenburg', '', 'western', 'Sweden', '']
# Sentence after removing stopwords: ['Sales', 'clothing', 'developed', 'best', '']
# Sentence after removing stopwords: ['Profit', 'period', 'totaled', 'EUR', '394', 'mn', '', 'EUR', '339', 'mn', 'corresponding', 'period', '2006', '']
# Sentence after removing stopwords: ['Other', 'carriers', 'handset', 'makers', 'spin', 'positive', 'event', 'raise', 'interest', 'higherend', 'phones', 'pricier', 'data', 'plans', '']
# Sentence after removing stopwords: ['Shareholders', 'Rakvere', 'Lihakombinaat', 'decided', 'favor', 'buyout', 'minority', 'shares', 'midJuly', '']
# Sentence after removing stopwords: ['The', 'acquisition', 'immediate', 'positive', 'impact', 'Aspocomp', 'financial', 'result', '']
# Sentence after removing stopwords: ['Furthermore', '', 'efficiency', 'improvement', 'measures', 'initiated', 'earlier', 'bearing', 'fruit', '', '', 'CEO', 'Jan', 'Lang', 'said', '']
# Sentence after removing stopwords: ['Having', 'China', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', '', 'also', 'strengthen', 'capability', 'offer', 'industryleading', 'products', 'customers', 'China', '', '']
# Sentence after removing stopwords: ['', 'Demand', 'sports', 'equipment', 'good', '2005', '']
# Sentence after removing stopwords: ['SOUTHFIELD', '', 'Mich', '', 'Central', 'Corporate', 'Credit', 'Union', 'distribute', 'patronage', 'dividends', 'members', 'waiving', 'service', 'fees', 'incurred', 'months', 'July', 'November', '2008', '', 'tune', 'estimated', '', '1', 'million', '']
# Sentence after removing stopwords: ['Revenue', 'July', 'September', 'grew', '14', 'percent', '', 'EURO', '', '467', 'million', 'year', 'earlier', '', 'company', 'said', 'Thursday', '']
# Sentence after removing stopwords: ['Shares', 'Standard', 'Chartered', '', 'STAN', '', 'rose', '12', '', 'FTSE', '100', '', 'Royal', 'Bank', 'Scotland', '', 'RBS', '', 'shares', 'rose', '2', '', 'Barclays', 'shares', '', 'BARC', '', '', 'BCS', '', '17', '', '']
# Sentence after removing stopwords: ['The', 'German', 'company', 'also', 'signed', 'code', 'share', 'agreement', 'another', 'Oneworld', 'member', '', 'American', 'Airlines', 'Inc', '', 'part', 'USbased', 'AMR', 'Corp', '', 'NYSE', '', 'AMR', '', '']
# Sentence after removing stopwords: ['TietoEnator', 'uses', 'Nokia', 'Intellisync', 'Mobile', 'Suite', 'wireless', 'email', '', 'calendar', '', 'device', 'management', 'capabilities', '', 'company', 'extend', 'services', 'customers', '']
# Sentence after removing stopwords: ['Both', 'loans', 'used', 'finance', 'strategic', 'investments', 'shopping', 'center', 'redevelopment', 'projects', 'refinancing', 'maturing', 'debt', '']
# Sentence after removing stopwords: ['The', 'new', 'agreement', '', 'expands', 'longestablished', 'cooperation', 'companies', '', 'involves', 'transfer', 'certain', 'engineering', 'documentation', 'functions', 'Larox', 'Etteplan', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'broadband', 'data', 'communication', 'systems', 'provider', 'Teleste', 'Oyj', 'HEL', '', 'TLT1V', 'said', 'Wednesday', 'net', 'profit', 'rocketed', 'EUR4', '8', '2010', 'EUR416', '000', '2009', 'lifted', 'dividend', 'proposal', '']
# Sentence after removing stopwords: ['NAVTEQ', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'North', 'American', 'vehicles', 'may', 'leader', 'turnbyturn', 'navigation', 'data', 'offered', 'services', 'OnStar', 'North', 'America', '', 'said', 'analyst', 'Phil', 'Magney', 'Telematics', 'Research', 'Group', 'Minnetonka', '', 'Minn', '']
# Sentence after removing stopwords: ['Jawad', 'Williams', 'scored', '23', 'points', 'impressive', 'debut', 'Jerusalem', '', 'Jason', 'Rich', 'adding', '18', 'Yuval', 'Naimi', 'chipping', '16', 'points', 'Hapoel', '', 'visits', 'yellowandblue', 'next', 'week', '']
# Sentence after removing stopwords: ['', 'ADP', 'News', '', '', 'Finnish', 'handling', 'systems', 'provider', 'Cargotec', 'Oyj', '', 'HEL', '', 'CGCBV', '', 'announced', 'Friday', 'orders', 'worth', 'EUR', '10', 'million', '', 'USD', '132', '', 'deliver', 'linkspans', 'Jordan', '', 'Morocco', 'Ireland', '']
# Sentence after removing stopwords: ['Nokian', 'Capacitors', '', 'equipment', 'used', 'raise', 'capacity', 'reliability', 'Indian', 'grid', '']
# Sentence after removing stopwords: ['Finnish', 'food', 'industry', 'companies', 'HK', 'Ruokatalo', 'Atria', 'form', 'joint', 'venture', 'company', 'called', 'LÆnsiKalkkuna', 'produce', 'turkey', 'meat', '']
# Sentence after removing stopwords: ['Sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season', '']
# Sentence after removing stopwords: ['Speaking', 'justdrinks', 'today', '', 'spokesperson', 'Olvi', 'said', '', '', 'We', 'performed', 'well', 'four', 'countries', 'operate', '', 'namely', '', 'Finland', '', 'Estonia', '', 'Latvia', 'Lithuania', '', '']
# Sentence after removing stopwords: ['TELE2', 'Affarsvarlden', 'gave', '', 'buy', '', 'recommendation', 'mobile', 'operator', 'Tele2', 'AB', 'share', 'price', 'target', '142', 'crowns', '', '', '2354', '', '1519', 'euro', '', '']
# Sentence after removing stopwords: ['Excluding', 'nonrecurring', 'items', '', 'pretax', 'profit', 'surged', '45', '', 'EUR80m', '']
# Sentence after removing stopwords: ['Finnish', 'P¦yry', 'awarded', 'engineering', 'contract', 'CFR', '', 'national', 'railway', 'company', 'Romania', '']
# Sentence after removing stopwords: ['The', 'airline', 'ordered', 'nine', 'Airbus', 'A350900', 'aircraft', 'deliveries', '2011', '', 'becomes', 'lead', 'airline', 'latest', 'variant', 'RollsRoyce', 'Trent', 'series', 'engines', '', 'called', '1700', '']
# ...
# Sentence after removing stopwords: ['', 'A', 'spokesperson', 'told', 'WWD', 'expect', '5050', 'mix', 'clothing', 'home', 'decor', '', '']
# Sentence after removing stopwords: ['Two', 'contracts', 'turntable', 'anode', 'vibrocompactors', 'delivered', 'Gansu', 'Hualu', 'Aluminum', 'Co', 'Ltd', 'another', 'unnamed', 'costumer', '']
# Sentence after removing stopwords: ['The', 'carrier', 'said', 'Area', 'travel', 'agency', 'sell', 'outlets', 'sister', 'chain', 'Suomen', 'Matkatoimisto', 'SMTand', 'use', 'remaining', 'bricksandmortar', 'presence', 'primarily', 'target', 'business', 'customers', 'going', 'forward', '']
# Sentence after removing stopwords: ['The', 'new', 'company', 'likely', 'hold', 'IPO', 'NYSE', 'another', 'international', 'stock', 'exchange', '', 'according', 'Altimo', 'manages', 'Alfa', 'Group', 'telecommunications', 'assets', 'TeliaSonera', 'agreement', '', 'published', 'website', 'US', 'Securities', 'Exchange', 'Commission', '']
# Sentence after removing stopwords: ['The', 'order', 'also', 'includes', 'startup', 'commissioning', 'services', '']
# Sentence after removing stopwords: ['The', 'challenge', 'company', '', 'however', '', 'finding', 'new', 'sources', 'raw', 'material', '', 'said', 'Risto', 'Rinne', '', 'CEO', 'Neste', 'Oil', '']
# Sentence after removing stopwords: ['Protalix', 'developing', 'genetically', 'engineered', 'proteins', 'plant', 'cells', '']
# Sentence after removing stopwords: ['It', 'grew', 'Finland', '', 'Norway', '', 'Denmark', 'Baltic', 'countries', '']
# Sentence after removing stopwords: ['Operating', 'profit', 'totaled', 'EUR', '186', 'mn', '83', '', 'net', 'sales', '']
# Sentence after removing stopwords: ['Citigroup', '', 'Inc', 'NYSE', '', 'C', '', 'Deutsche', 'Bank', 'NYSE', '', 'DB', 'Pohjola', 'Bank', 'lead', 'managers', 'sale', '']
# Sentence after removing stopwords: ['Medical', 'Devices', '', 'Russia', 'This', 'brandnew', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'medical', 'device', 'market', 'Russia', '']
# Sentence after removing stopwords: ['Also', '', 'sevenyear', 'historic', 'analysis', 'provided', 'markets', '']
# Sentence after removing stopwords: ['Fiskars', 'R', '', 'founded', '1649', '', 'one', 'oldest', 'companies', 'world', 'largest', 'manufacturer', 'lightweight', 'stainless', 'steel', 'scissors', 'US', '']
# Sentence after removing stopwords: ['In', '2007', '', 'Contempus', 'generated', 'revenue', 'NOK', '693', '', 'approx', '']
# Sentence after removing stopwords: ['According', 'FinnishRussian', 'Chamber', 'Commerce', '', 'major', 'construction', 'companies', 'Finland', 'operating', 'Russia', '']
# Sentence after removing stopwords: ['Tikkurila', 'Powder', 'Coatings', '50', 'employees', 'four', 'paint', 'plants', '', 'generated', 'revenues', 'EUR2', '4', 'USD3', '3', '2010', '']
# Sentence after removing stopwords: ['Neither', 'companies', 'use', 'genetically', 'engineered', 'soy', 'moment', '']
# Sentence after removing stopwords: ['The', 'Division', 'also', 'includes', 'joint', 'sales', '', 'marketing', 'controlling', 'functions', 'units', '']
# Sentence after removing stopwords: ['The', 'identity', 'buyer', 'yet', 'known', '']
# Sentence after removing stopwords: ['It', 'comes', 'complete', 'LCD', 'touch', 'screen', 'system', 'selection', 'chosen', 'function', 'prices', 'start', 'around', 'pounds', '4805', 'mark', '']
# Sentence after removing stopwords: ['CompaniesandMarketscom', 'provides', 'wide', 'range', 'research', 'reports', '', 'industry', 'statistics', 'competitive', 'intelligence', 'industrial', 'sector', '']
# Sentence after removing stopwords: ['However', '', 'production', 'almost', 'entirely', 'labor', 'intensive', 'based', 'small', 'investments', '']
# Sentence after removing stopwords: ['Mr', 'Koistinen', 'joins', 'Nokia', 'Siemens', 'Networks', 'held', 'various', 'senior', 'sales', 'management', 'business', 'development', 'positions', 'since', '1997', '']
# Sentence after removing stopwords: ['Finnish', 'consumers', 'prefer', 'buy', 'cheapest', 'beer', 'brand', '']
# Sentence after removing stopwords: ['SRV', 'also', 'build', 'aqua', 'park', 'wellness', 'area', '', 'restaurant', 'multifunctional', 'ice', 'arena', '']
# Sentence after removing stopwords: ['The', 'ecommerce', 'site', 'flagship', 'managed', 'Marimekko', 'North', 'America', 'Retail', 'LLC', '', 'subsidiary', 'established', 'US', 'last', 'year', '']
# Sentence after removing stopwords: ['The', 'product', 'range', 'includes', 'marinated', 'olives', '', 'cold', 'cuts', '', 'pates', '', 'example', '']
# Sentence after removing stopwords: ['After', 'buying', 'Eukor', 'Car', 'Carriers', '50', 'percent', 'stake', '', 'Grimaldi', 'Group', 'sole', 'owner', 'Swedish', 'rollon', '', 'rolloff', 'port', 'Wallhamn', '']
# Sentence after removing stopwords: ['BasWare', 'Invoice', 'Processing', '', 'BasWare', 'Contract', 'Matching', '', 'BasWare', 'Order', 'Matching', 'BasWare', 'KPI', 'Reporting', 'Tool', 'part', 'BasWare', 'Enterprise', 'Purchase', 'Pay', 'product', 'suite', '']
# Sentence after removing stopwords: ['The', 'net', 'sales', 'Healthcare', 'Trade', 'business', '2009', 'EUR', '1451', 'million', 'EUR', '1552', 'million', 'operating', 'profit', 'EUR', '89', 'million', 'EUR', '79', 'million', '']
# Sentence after removing stopwords: ['After', 'transaction', '', 'Tikkurila', 'powder', 'coatings', 'related', 'operations', '']
# Sentence after removing stopwords: ['In', '2008', '', 'AVC', 'Systemhaus', 'net', 'sales', 'EUR', '10', 'million', 'USD', '71', '']
# Sentence after removing stopwords: ['The', 'process', '', 'technology', '', 'project', 'management', '', 'basic', 'engineering', 'quality', 'assurance', 'within', 'Forest', 'Industry', 'consolidated', 'Vantaa', '', 'southern', 'Finland', '']
# Sentence after removing stopwords: ['The', 'Bank', 'land', 'acquired', 'private', 'banking', 'business', '', 'asset', 'management', '', 'share', 'brokerage', 'business', 'Kaupthing', 'Sweden', 'early', '2009', '']
# Sentence after removing stopwords: ['Swedish', 'Wallenberg', 'family', 'controlled', 'Investor', 'bought', 'large', 'stake', 'C', 'shares', 'Swedish', 'retail', 'bank', 'SEB', '']
# Sentence after removing stopwords: ['The', 'Segu', 'companies', 'PKC', 'Polish', 'unit', 'form', 'business', 'servicing', 'western', 'European', 'markets', '', 'annual', 'sales', 'hundred', 'million', '', '2500', 'employees', '', 'Finnish', 'company', 'CEO', '', 'Harri', 'Suutari', '', 'said', '']
# Sentence after removing stopwords: ['4', 'February', '2011', '', 'Finnish', 'privacy', 'security', 'software', 'developer', 'Tectia', 'Oyj', '', 'HEL', '', 'TEC1V', '', 'said', 'Wednesday', 'set', 'two', 'strategic', 'business', 'units', '', 'managed', 'security', 'mobile', 'authentication', '']
# Sentence after removing stopwords: ['Mursula', 'said', 'tried', 'gather', 'macroeconomic', 'perspective', 'see', 'Malaysia', '']
# Sentence after removing stopwords: ['Finnish', 'silicon', 'wafers', 'maker', 'Okmetic', 'Oyj', 'said', 'September', '17', '', '2008', 'invest', 'total', '15', 'mln', 'euro', '', '213', 'mln', 'sensor', 'wafer', 'business', '']
# Sentence after removing stopwords: ['Sunrise', 'Resources', 'operates', 'Russian', 'nearshore', 'development', 'markets', 'whollyowned', 'Russian', 'subsidiary', '80', '', 'personnel', 'Russia', '']
# Sentence after removing stopwords: ['Performance', 'based', 'values', 'sustainability', '']
# Sentence after removing stopwords: ['Under', 'agreement', 'Benefon', 'forthcoming', 'range', 'TWIG', 'integrated', 'GPS', 'navigation', 'mobile', 'phone', 'devices', 'use', 'jointly', 'developed', 'webbased', 'tracking', 'location', 'technology', '', 'consumer', 'commercial', 'applications', '']
# Sentence after removing stopwords: ['GeoSentric', 'acquiring', 'extra', 'financing', 'issuing', 'maximum', '220000', 'new', 'shares', 'convertible', 'bond', 'subscription', 'rights', '880000', 'shares', '', 'fully', 'subscribed', '']
# Sentence after removing stopwords: ['The', 'divested', 'activities', 'net', 'sales', 'EUR', '1451', 'million', '2009', 'operating', 'profit', 'EUR', '89', 'million', '']
# Sentence after removing stopwords: ['The', 'final', 'price', 'specified', '14', 'May', '2010', '', 'acquiring', 'company', 'said', '']
# Sentence after removing stopwords: ['Honkarakenne', 'customer', 'project', 'one', 'biggest', 'real', 'estate', 'companies', 'Kazakhstan', '', 'according', 'company', '']
# Sentence after removing stopwords: ['', 'These', 'patronage', 'refunds', 'reward', 'members', 'use', 'feebased', 'services', 'make', 'positive', 'contribution', 'CenCorp', 'operating', 'results', '', '', 'said', 'Bill', 'Walby', '', 'CenCorp', 'CEO', '']
# Sentence after removing stopwords: ['Shareholders', 'right', 'put', 'agenda', 'AGM', 'items', 'within', 'competence', 'general', 'meeting', '']
# Sentence after removing stopwords: ['The', 'front', 'surfaces', 'valve', 'plates', 'directed', 'towards', '']
# Sentence after removing stopwords: ['Subjectmatter', 'invention', 'furthermore', 'use', 'cyclone', 'separating', 'partly', 'molten', 'particles', '', '']
# Sentence after removing stopwords: ['The', 'dualfuel', 'engines', 'vessel', 'operate', 'liquefied', 'natural', 'gas', 'LNG', 'low', 'emissions', '']
# Sentence after removing stopwords: ['The', 'expansion', 'finalized', 'autumn', '2009', '']
# Sentence after removing stopwords: ['MetsaBotnia', 'sell', '821', '', 'stake', 'Uruguayan', 'companies', 'Metsaliitto', '', '55', '', '']
# Sentence after removing stopwords: ['Unit', 'prices', 'straddle', 'carriers', 'vary', 'EUR700', '000', 'EUR900', '000', '', 'company', 'added', '']
# Sentence after removing stopwords: ['The', 'company', 'board', 'directors', 'would', 'propose', 'dividend', 'EUR1', '00', 'per', 'share', '2005', '']
# Sentence after removing stopwords: ['ALEXANDRIA', '', 'Va', '', 'Oct', '3', '', 'Markka', 'A', 'Oksanen', 'Harald', 'Kaaja', '', 'Helsinki', '', 'Finland', '', 'Juha', 'Salokannel', 'Kangasala', '', 'Finland', '', 'Arto', 'Palin', 'Viiala', '', 'Finland', '', 'developed', 'system', 'providing', 'communications', 'security', '']
# Sentence after removing stopwords: ['BG', 'Crane', 'strong', 'customer', 'base', 'onroad', 'load', 'handling', 'related', 'installation', 'service', 'businesses', '']
# Sentence after removing stopwords: ['Connectivity', 'Services', 'include', 'outsourced', 'Scan', 'Capture', 'transfers', 'paper', 'invoices', 'electronic', 'format', 'Basware', 'Business', 'Transactions', 'Service', 'enables', 'customer', 'receive', 'send', 'invoices', 'electronic', 'format', '']
# Sentence after removing stopwords: ['The', 'Extraordinary', 'General', 'Meeting', 'expected', 'take', 'place', 'later', '18', 'February', '2011', '']
# Sentence after removing stopwords: ['The', 'shares', 'subscribed', 'stock', 'options', 'registered', 'Trade', 'Register', '20', 'January', '2011', '', 'date', 'new', 'shares', 'establish', 'shareholder', 'rights', '']
# Sentence after removing stopwords: ['In', 'addition', 'verification', 'identity', 'digital', 'signatures', '', 'new', 'stateapproved', 'Mobile', 'ID', 'enables', 'cast', 'votes', 'elections', 'well', '']
# Sentence after removing stopwords: ['The', 'contract', 'includes', 'design', '', 'construction', '', 'delivery', 'equipment', '', 'installation', 'commissioning', '']
# Sentence after removing stopwords: ['The', 'total', 'restructuring', 'costs', 'expected', 'EUR', '30mn', '', 'EUR', '135', 'mn', 'booked', 'December', '2008', '']
# Sentence after removing stopwords: ['IonPhasE', 'second', 'major', 'owner', 'venture', 'capital', 'firm', 'Aura', 'Capital', '']
# Sentence after removing stopwords: ['Any', 'investment', 'investment', 'activity', 'communication', 'relates', 'available', 'relevant', 'persons', 'engaged', 'relevant', 'persons', '']
# Sentence after removing stopwords: ['Pharmaceuticals', '', 'Belgium', 'This', 'brandnew', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'pharmaceutical', 'market', 'Belgium', '']
# Sentence after removing stopwords: ['Risto', 'Jalo', '', 'chief', 'executive', 'Dormus', 'Print', 'also', 'owner', 'remainder', 'company', '', 'keep', 'position', 'acquisition', '']
# Sentence after removing stopwords: ['It', 'first', 'oil', 'company', 'join', 'RSPO', 'commits', 'fully', 'sustainable', 'sourcing', 'feedstocks', 'production', 'NExBTL', 'biodiesel', '', 'said', '']
# Sentence after removing stopwords: ['Sarantel', '', 'based', 'Wellingborough', '', 'UK', '', 'designs', 'highperformance', 'antennas', 'portable', 'wireless', 'devices', '']
# Sentence after removing stopwords: ['The', 'energy', 'shot', 'packed', '100millilitre', 'bag', 'screw', 'cap', '']
# Sentence after removing stopwords: ['Its', 'product', 'portfolio', 'comprises', 'harvesters', '', 'forwarders', '', 'harvester', 'heads', '', 'well', 'cranes', 'loaders', '']
# Sentence after removing stopwords: ['Remote', 'Phone', 'Management', 'demonstrates', 'SysOpen', 'Digia', 'unique', 'endtoend', 'offering', 'operators', '', 'handset', 'manufacturers', 'enterprise', 'customers', '']
# Sentence after removing stopwords: ['Mobile', 'data', 'transfer', 'expected', 'increase', 'explosively', 'LTE', 'era', '']
# Sentence after removing stopwords: ['Previously', '', 'company', 'expected', '2008', 'financial', 'performance', 'remain', 'level', '2008', '']
# Sentence after removing stopwords: ['These', 'module', 'products', 'available', 'trials', '3Q07', 'volume', 'deliveries', '4Q07', '']
# Sentence after removing stopwords: ['Glaston', 'share', 'GLA1V', 'listed', 'NASDAQ', 'OMX', 'Helsinki', '', 'Mid', 'Cap', 'List', '']
# Sentence after removing stopwords: ['A', 'Le', 'Coq', 'market', 'share', '413', 'percent', 'rival', 'beverage', 'group', 'Saku', '321', 'percent', '']
# Sentence after removing stopwords: ['The', 'business', 'idea', 'Budget', 'Sport', 'offer', 'customers', 'wide', 'range', 'highquality', 'sports', 'equipment', 'clothing', 'low', 'prices', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'talks', 'involved', 'Food', 'Ingredients', 'Divisions', '', 'well', 'group', 'service', 'functions', '', 'company', 'said', '']
# Sentence after removing stopwords: ['The', 'agreement', 'must', 'approved', 'Russian', 'competition', 'authorities', 'enters', 'force', '']
# Sentence after removing stopwords: ['Water', 'Treatment', 'Products', 'In', 'Australia', 'Today', '', 'Global', 'Research', '', 'Data', 'Services', 'going', 'publish', 'market', 'analysis', 'market', 'chemical', 'water', 'treatment', 'products', 'Australia', '']
# Sentence after removing stopwords: ['The', 'company', 'issue', 'inaugural', 'Eurobond', 'deal', 'near', 'future', 'subject', 'market', 'conditions', '']
# Sentence after removing stopwords: ['', 'That', 'high', 'figure', 'European', 'scale', '', '', 'Noop', 'said', '', 'recalling', 'however', 'also', 'includes', 'beer', 'bought', 'Finnish', 'tourists', '']
# Sentence after removing stopwords: ['The', 'aim', 'CEO', 'QA', 'sessions', 'give', 'clarity', 'information', '', 'made', 'public', 'already', 'earlier', '']
# Sentence after removing stopwords: ['These', 'sections', 'put', 'place', 'form', 'loadbearing', 'steel', 'structure', 'bridge', '', '', 'says', 'Sami', 'Eronen', '', 'Senior', 'Vice', 'President', '', 'Infrastructure', 'Northern', 'Europe', '', 'Ruukki', 'Construction', '']
# Sentence after removing stopwords: ['The', 'use', 'validation', 'rule', 'base', 'enables', 'verifying', 'processing', 'rule', 'bases', 'managed', 'different', 'administrators', 'fulfil', 'set', 'requirements', '']
# Sentence after removing stopwords: ['The', 'plant', 'collect', 'raw', 'material', 'Baltic', 'Sea', 'region', '']
# Sentence after removing stopwords: ['Yvonne', 'Jones', 'owner', 'Chameleon', 'Interiors', '']
# Sentence after removing stopwords: ['M2', 'Communications', 'disclaims', 'liability', 'information', 'provided', 'within', 'information', 'world', 'wide', 'web', '']

# %%
#focus on more frequently occuring words for every sentiment=>
#sort in DO wrt 2nd column in each of positiveValues,negativeValues and neutralValues

df_positive3=pd.DataFrame(sorted(positiveValues3.items(),key=lambda x:x[1],reverse=True))
df_negative3=pd.DataFrame(sorted(negativeValues3.items(),key=lambda x:x[1],reverse=True))
df_neutral3=pd.DataFrame(sorted(neutralValues3.items(),key=lambda x:x[1],reverse=True))

# %%
pd1tri=df_positive3[0][:10]
pd2tri=df_positive3[1][:10]

ned1tri=df_negative3[0][:10]
ned2tri=df_negative3[1][:10]

nud1tri=df_neutral3[0][:10]
nud2tri=df_neutral3[1][:10]

plt.figure(1,figsize=(16,4))

plt.bar(pd1tri,pd2tri, color ='green',
        width = 0.4)
 
plt.xlabel("Words in positive dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in positive dataframe-TRIGRAM ANALYSIS")

plt.savefig("positive-trigram.png")
plt.show()

# %%
df_positive3.head(10)
# Out:
#                          0   1
# 0                mln euro   28
# 1            year earlier   20
# 2          profit rose EUR  18
# 3  mn corresponding period  18
# 4                   euro    18
# 5        first nine months  14
# 6               said today  13
# 7                  mn  EUR  13
# 8            quarter 2010   12
# 9            2010  Finnish  12

# %%
plt.figure(1,figsize=(16,4))

plt.bar(ned1tri,ned2tri, color ='red',
        width = 0.4)
 
plt.xlabel("Words in negative dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in negative dataframe-TRIGRAM ANALYSIS")

plt.savefig("negative-trigram.png")
plt.show()

# %%
df_negative3.head(10)
# Out:
#                          0   1
# 0  mn corresponding period  18
# 1                  mn  EUR  16
# 2             mn  compared  15
# 3      compared profit EUR  15
# 4                mln euro   13
# 5            year earlier   11
# 6          compared profit  10
# 7                   euro     9
# 8             period 2007    9
# 9            quarter 2008    9

# %%
plt.figure(1,figsize=(16,4))

plt.bar(nud1tri,nud2tri, color ='yellow',
        width = 0.4)
 
plt.xlabel("Words in neutral dataframe")
plt.ylabel("Count")
plt.title("Top 10 words in neutral dataframe-TRIGRAM ANALYSIS")

plt.savefig("neutral-trigram.png")
plt.show()

# %%
df_neutral3.head(10)
# Out:
#                 0   1
# 0        Finland   38
# 1       mln euro   24
# 2  ALEXANDRIA  Va  15
# 3             Va   15
# 4   company said   14
# 5    company said  13
# 6   OMX Helsinki   12
# 7           2007   10
# 8          euro    10
# 9  Espoo  Finland  10

# %% [markdown]
# **Using CountVectorizer()**
#
# -can also b used to check the most common bigrams
